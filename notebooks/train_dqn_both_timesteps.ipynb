# %% [markdown]
# ### Import packages

# %%
import os
import sys
import warnings

import datetime
import math
import numpy as np
import pandas as pd
import platform
import re
import subprocess
import torch as th

import os
import pickle

import gymnasium as gym
import matplotlib.pyplot as plt

from datetime import datetime
from scripts.utils import *
from scripts.visualizations import *
from src.config import *
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.logger import configure  # Import the configure function
from stable_baselines3.common.utils import polyak_update, set_random_seed
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv

from scripts.utils import NumpyEncoder
from scripts.logger import *

import json


import seaborn as sns
sns.set(style="darkgrid", font_scale=1.5)

# %% [markdown]
# ### Hyperparameters

# %%
# In train_dqn_both_timesteps.ipynb:
if 'MAX_TOTAL_TIMESTEPS' not in globals():
    MAX_TOTAL_TIMESTEPS = 1000000
if 'TRAINING_FOLDERS_PATH' not in globals():
    TRAINING_FOLDERS_PATH = "../data/Training/3ac-100-mixed/"
if 'SEEDS' not in globals():
    SEEDS = [0, 1, 2]
if 'brute_force_flag' not in globals():
    brute_force_flag = False




# Constants and Training Settings
LEARNING_RATE = 0.0001
GAMMA = 0.99
BUFFER_SIZE = 100000
BATCH_SIZE = 128
TARGET_UPDATE_INTERVAL = 1000
NEURAL_NET_STRUCTURE = dict(net_arch=[256, 256])
LEARNING_STARTS = 10000
TRAIN_FREQ = 4

EPSILON_START = 1.0
EPSILON_MIN = 0.025
PERCENTAGE_MIN = 95

# EXPLORATION_PHASE = 1000
EPSILON_TYPE = "exponential"
# EPSILON_TYPE = "linear"
if EPSILON_TYPE == "linear":
    EPSILON_MIN = 0

N_EPISODES = 50 # DOESNT MATTER
cross_val_flag = False
CROSS_VAL_INTERVAL = N_EPISODES/100

# TRAINING_FOLDERS_PATH = "../data/Locked/alpha/"
# TRAINING_FOLDERS_PATH = "../data/Training/3ac-10/"
# TRAINING_FOLDERS_PATH = "../data/Training/temp/"
TESTING_FOLDERS_PATH = "../data/Training/3ac-10-deterministic/"


stripped_scenario_folder = TRAINING_FOLDERS_PATH.split("/")[-2]
print(f"Training on {stripped_scenario_folder}")
# extract number of scenarios in training and testing folders
num_scenarios_training = len(os.listdir(TRAINING_FOLDERS_PATH))
# Out:
# Training on 3ac-100-mixed

# %% [markdown]
# ## ESTIMATED VALUES

# %%
import numpy as np
import matplotlib.pyplot as plt


# based on MAX_TOTAL_TIMESTEPS and EPSILON_START = 1.0 andEPSILON_MIN = 0.025 andPERCENTAGE_MIN = 95, calculate EPSILON_DECAY_RATE
EPSILON_DECAY_RATE = calculate_epsilon_decay_rate(
    MAX_TOTAL_TIMESTEPS, EPSILON_START, EPSILON_MIN, PERCENTAGE_MIN, EPSILON_TYPE
)
print("EPSILON DECAY RATE: ", EPSILON_DECAY_RATE)
# Out:
# Calculated EPSILON_DECAY_RATE: 3.883031004330459e-06
# EPSILON DECAY RATE:  3.883031004330459e-06

# %%
# Initialize device
device = initialize_device()

# Check device capabilities
check_device_capabilities()

# Get device-specific information
device_info = get_device_info(device)
print(f"Device info: {device_info}")

# Verify training folders and gather training data
training_folders = verify_training_folders(TRAINING_FOLDERS_PATH)
# print(f"Training folders: {training_folders}")

# Calculate training days and model naming
num_days_trained_on = calculate_training_days(N_EPISODES, training_folders)
print(f"Training on {num_days_trained_on} days of data "
        f"({N_EPISODES} episodes of {len(training_folders)} scenarios)")

formatted_days = format_days(num_days_trained_on)
MODEL_SAVE_PATH = f'../trained_models/dqn/'

# Create results directory
results_dir = create_results_directory(append_to_name='dqn')
print(f"Results directory created at: {results_dir}")
# Out:
# Using device: mps
# CUDA available: False
# Number of GPUs available: 0
# cuDNN enabled: True
# Device: mps
# Using MacBook M1
# Device info: {'device_type': 'MacBook M1'}
# Training on 5000 days of data (50 episodes of 100 scenarios)
# Results directory created at: ../results/dqn/20241207-04-03

# %% [markdown]
# # Reinforcement Learning

# %% [markdown]
# ## Training

# %%
from scripts.logger import create_new_id, get_config_variables
import src.config as config

all_logs = {}
# Training both agents: myopic and proactive

def train_dqn_agent(env_type):
    log_data = {}  # Main dictionary to store all logs

    config_variables = get_config_variables(config)

    # Generate unique ID for training
    training_id = create_new_id("training")
    runtime_start_in_seconds = time.time()

    if env_type == "myopic":
        model_path = f"../trained_models/dqn/myopic-{training_id}.zip"
        print(f"Models will be saved to: {model_path}")
        model_path_and_name = model_path
    elif env_type == "proactive":
        model_path = f"../trained_models/dqn/proactive-{training_id}.zip"
        print(f"Models will be saved to: {model_path}")
        model_path_and_name = model_path
    # Metadata for logging
    training_metadata = {
        "myopic_or_proactive": env_type,
        "model_type": "dqn",
        "training_id": training_id,
        "MODEL_SAVE_PATH": model_path,
        "N_EPISODES": N_EPISODES,
        "num_scenarios_training": num_scenarios_training,
        "results_dir": results_dir,
        "CROSS_VAL_FLAG": cross_val_flag,
        "CROSS_VAL_INTERVAL": CROSS_VAL_INTERVAL,
        **config_variables,
        "LEARNING_RATE": LEARNING_RATE,
        "GAMMA": GAMMA,
        "BUFFER_SIZE": BUFFER_SIZE,
        "BATCH_SIZE": BATCH_SIZE,
        "TARGET_UPDATE_INTERVAL": TARGET_UPDATE_INTERVAL,
        "EPSILON_START": EPSILON_START,
        "EPSILON_MIN": EPSILON_MIN,
        "EPSILON_DECAY_RATE": EPSILON_DECAY_RATE,
        "LEARNING_STARTS": LEARNING_STARTS,
        "TRAIN_FREQ": TRAIN_FREQ,
        "NEURAL_NET_STRUCTURE": NEURAL_NET_STRUCTURE,
        "device_info": str(get_device_info(device)),
        "TRAINING_FOLDERS_PATH": TRAINING_FOLDERS_PATH,
        "TESTING_FOLDERS_PATH": TESTING_FOLDERS_PATH,
        "runtime_start": datetime.utcnow().isoformat() + "Z",
        "runtime_start_in_seconds": runtime_start_in_seconds,
    }

    log_data['metadata'] = training_metadata
    log_data['episodes'] = {}
    log_data['cross_validation'] = {}

    best_reward_avg = float('-inf')
    # Initialize variables
    rewards = {}
    good_rewards = {}
    test_rewards = []
    epsilon_values = []
    total_timesteps = 0  # Added to track total timesteps
    consecutive_drops = 0  # Track consecutive performance drops
    best_test_reward = float('-inf')  # Track best test performance
    action_sequences = {
        os.path.join(TRAINING_FOLDERS_PATH, folder): {
            "best_actions": [],
            "best_reward": float('-inf'),
            "worst_actions": [],
            "worst_reward": float('inf')
        }
        for folder in training_folders
    }
    
    def cross_validate_on_test_data(model, current_episode, log_data):
        cross_val_data = {
            "episode": current_episode,
            "scenarios": [],
            "avg_test_reward": 0,
        }

        test_scenario_folders = [
            os.path.join(TESTING_FOLDERS_PATH, folder)
            for folder in os.listdir(TESTING_FOLDERS_PATH)
            if os.path.isdir(os.path.join(TESTING_FOLDERS_PATH, folder))
        ]
        total_test_reward = 0
        for test_scenario_folder in test_scenario_folders:
            scenario_data = {
                "scenario_folder": test_scenario_folder,
                "total_reward": 0,
                "steps": []
            }
            # Load data
            data_dict = load_scenario_data(test_scenario_folder)
            aircraft_dict = data_dict['aircraft']
            flights_dict = data_dict['flights']
            rotations_dict = data_dict['rotations']
            alt_aircraft_dict = data_dict['alt_aircraft']
            config_dict = data_dict['config']

            # Update the environment with the new scenario (by reinitializing it)
            from src.environment import AircraftDisruptionEnv
            env = AircraftDisruptionEnv(
                aircraft_dict,
                flights_dict,
                rotations_dict,
                alt_aircraft_dict,
                config_dict,
                env_type=env_type
            )
            model.set_env(env)  # Update the model's environment with the new instance

            # Evaluate the model on the test scenario without training
            obs, _ = env.reset()

            done_flag = False
            total_reward = 0
            timesteps = 0

            while not done_flag:
                # Get the action mask from the environment
                action_mask = obs['action_mask']

                # Convert observation to float32
                obs = {key: np.array(value, dtype=np.float32) for key, value in obs.items()}

                # Preprocess observation and get Q-values
                obs_tensor = model.policy.obs_to_tensor(obs)[0]
                q_values = model.policy.q_net(obs_tensor).detach().cpu().numpy().squeeze()

                # Apply the action mask (set invalid actions to -np.inf)
                masked_q_values = q_values.copy()
                masked_q_values[action_mask == 0] = -np.inf

                # Select the action with the highest masked Q-value
                action = np.argmax(masked_q_values)

                # Take the selected action in the environment
                result = env.step(action)

                # Unpack the result
                obs_next, reward, terminated, truncated, info = result

                done_flag = terminated or truncated

                # Accumulate the reward
                total_reward += reward

                # Update the current observation
                obs = obs_next

                scenario_data["steps"].append({
                    "step_number": timesteps + 1,
                    "action": action,
                    "flight_action": env.map_index_to_action(action)[0],
                    "aircraft_action": env.map_index_to_action(action)[1],
                    "reward": reward,
                    "total_timestep": total_timesteps,
                    "time_in_scenario": timesteps,
                    "epsilon": "1.0 at cross-validation",
                    "action_reason": "exploitation at cross-validation",
                    "action_mask": action_mask,
                    "action_mask_sum": np.sum(action_mask),
                    "len_action_mask": len(action_mask),
                    "masked_q_values": masked_q_values,
                    "q_values": q_values,
                    "info_after_step": env.info_after_step,
                    # Assuming impact_of_action is defined elsewhere
                    # "impact_of_action": impact_of_action,
                })

                timesteps += 1
                if done_flag:
                    break

            total_test_reward += total_reward

            scenario_data["total_reward"] = total_reward
            cross_val_data["scenarios"].append(scenario_data)

        # Compute average test reward
        avg_test_reward = total_test_reward / len(test_scenario_folders)
        cross_val_data["avg_test_reward"] = avg_test_reward
        test_rewards.append((current_episode, avg_test_reward))
        print(f"cross-val done at episode {current_episode}")

        # Store cross-validation data in log_data
        log_data['cross_validation'][current_episode] = cross_val_data

        return avg_test_reward  # Return the average test reward

    # List all the scenario folders in Data/Training
    scenario_folders = [
        os.path.join(TRAINING_FOLDERS_PATH, folder)
        for folder in os.listdir(TRAINING_FOLDERS_PATH)
        if os.path.isdir(os.path.join(TRAINING_FOLDERS_PATH, folder))
    ]

    epsilon = EPSILON_START
    total_timesteps = 0  # Reset total_timesteps for each agent

    # Initialize the DQN
    dummy_scenario_folder = scenario_folders[0]
    data_dict = load_scenario_data(dummy_scenario_folder)
    aircraft_dict = data_dict['aircraft']
    flights_dict = data_dict['flights']
    rotations_dict = data_dict['rotations']
    alt_aircraft_dict = data_dict['alt_aircraft']
    config_dict = data_dict['config']

    from src.environment import AircraftDisruptionEnv

    env = AircraftDisruptionEnv(
        aircraft_dict,
        flights_dict,
        rotations_dict,
        alt_aircraft_dict,
        config_dict,
        env_type=env_type
    )

    model = DQN(
        policy='MultiInputPolicy',
        env=env,
        learning_rate=LEARNING_RATE,
        gamma=GAMMA,
        buffer_size=BUFFER_SIZE,
        learning_starts=LEARNING_STARTS,
        batch_size=BATCH_SIZE,
        target_update_interval=TARGET_UPDATE_INTERVAL,
        verbose=0,
        policy_kwargs=NEURAL_NET_STRUCTURE,
        device=device
    )

    logger = configure()
    model._logger = logger

    # Training loop over the number of episodes
    # for episode in range(N_EPISODES):

    episode = 0
    while total_timesteps < MAX_TOTAL_TIMESTEPS:    
        # create a dictionary in the rewards dictionary for the current episode
        rewards[episode] = {}
        # create a dictionary in the action_sequences dictionary for the current episode
        action_sequences[episode] = {}
        # Log the start of the episode
        episode_data = {
            "episode_number": episode + 1,
            "epsilon_start": epsilon,
            "scenarios": {},
        }
        # Cycle through all the scenario folders
        for scenario_folder in scenario_folders:
            scenario_data = {
                "scenario_folder": scenario_folder,
                "steps": [],
                "total_reward": 0,
            }
            # create a dictionary in the rewards dictionary for the current scenario
            rewards[episode][scenario_folder] = {}
            # create a dictionary in the action_sequences dictionary for the current scenario
            action_sequences[episode][scenario_folder] = []
            best_reward = float('-inf')
            best_action_sequence = []
            # Load the data for the current scenario
            data_dict = load_scenario_data(scenario_folder)
            aircraft_dict = data_dict['aircraft']
            flights_dict = data_dict['flights']
            rotations_dict = data_dict['rotations']
            alt_aircraft_dict = data_dict['alt_aircraft']
            config_dict = data_dict['config']

            # Update the environment with the new scenario (by reinitializing it)
            env = AircraftDisruptionEnv(
                aircraft_dict,
                flights_dict,
                rotations_dict,
                alt_aircraft_dict,
                config_dict,
                env_type=env_type
            )
            model.set_env(env)  # Update the model's environment with the new instance

            # Reset the environment
            obs, _ = env.reset()  # Extract the observation (obs) and ignore the info (_)

            done_flag = False
            total_reward = 0
            timesteps = 0
            action_sequence = []

            while not done_flag:

                # Get cancelled flights
                num_cancelled_flights_before_step = len(env.cancelled_flights)  # Returns a set of flight IDs

                # Get delayed flights and their delays (in minutes)
                num_delayed_flights_before_step = len(env.environment_delayed_flights)  # Returns a dict of {flight_id: delay_minutes}

                # Get flights that have already been penalized for delays
                num_penalized_delays_before_step = len(env.penalized_delays)  # Returns a dict of {flight_id: delay_minutes}

                # Get flights that have already been penalized for being cancelled
                num_penalized_cancelled_before_step = len(env.penalized_cancelled_flights)  # Returns a set of flight IDs

                model.exploration_rate = epsilon

                # Get the action mask from the environment
                action_mask = obs['action_mask']

                # Convert observation to float32
                obs = {key: np.array(value, dtype=np.float32) for key, value in obs.items()}

                # Preprocess observation and get Q-values
                obs_tensor = model.policy.obs_to_tensor(obs)[0]
                q_values = model.policy.q_net(obs_tensor).detach().cpu().numpy().squeeze()

                # Apply the action mask (set invalid actions to -np.inf)
                masked_q_values = q_values.copy()
                masked_q_values[action_mask == 0] = -np.inf

                current_seed = int(time.time() * 1e9) % (2**32 - 1)
                # print(current_seed)
                np.random.seed(current_seed)
                
                
                # Select an action
                action_reason = "None"
                if np.random.rand() < epsilon or brute_force_flag:
                    # Exploration: choose a random valid action
                    valid_actions = np.where(action_mask == 1)[0]
                    action = np.random.choice(valid_actions)
                    action_reason = "exploration"
                else:
                    # Exploitation: choose the action with the highest masked Q-value
                    action = np.argmax(masked_q_values)
                    action_reason = "exploitation"

                # Take the selected action in the environment
                result = env.step(action)

                # Unpack the result (5 values)
                obs_next, reward, terminated, truncated, info = result

                # Store the reward for the current timestep
                rewards[episode][scenario_folder][timesteps] = reward
                action_sequences[episode][scenario_folder].append(action)

                # Combine the terminated and truncated flags into a single done flag
                done_flag = terminated or truncated

                # Store the action
                action_sequence.append(action)

                # Add the transition to the replay buffer
                model.replay_buffer.add(
                    obs=obs,
                    next_obs=obs_next,
                    action=action,
                    reward=reward,
                    done=done_flag,
                    infos=[info]
                )

                # Update the current observation
                obs = obs_next

                epsilon = max(EPSILON_MIN, epsilon * (1 - EPSILON_DECAY_RATE))
                    
                epsilon_values.append((episode + 1, epsilon))

                timesteps += 1
                total_timesteps += 1  # Update total_timesteps

                # Training
                if total_timesteps > model.learning_starts and total_timesteps % TRAIN_FREQ == 0:
                    # Perform a training step
                    model.train(gradient_steps=1, batch_size=BATCH_SIZE)

                # Update target network
                if total_timesteps % model.target_update_interval == 0:
                    polyak_update(model.q_net.parameters(), model.q_net_target.parameters(), model.tau)
                    # Copy batch norm stats
                    polyak_update(model.batch_norm_stats, model.batch_norm_stats_target, 1.0)

                num_cancelled_flights_after_step = len(env.cancelled_flights)
                num_delayed_flights_after_step = len(env.environment_delayed_flights)
                num_penalized_delays_after_step = len(env.penalized_delays)
                num_penalized_cancelled_after_step = len(env.penalized_cancelled_flights)

                impact_of_action = {
                    "num_cancelled_flights": num_cancelled_flights_after_step - num_cancelled_flights_before_step,
                    "num_delayed_flights": num_delayed_flights_after_step - num_delayed_flights_before_step,
                    "num_penalized_delays": num_penalized_delays_after_step - num_penalized_delays_before_step,
                    "num_penalized_cancelled": num_penalized_cancelled_after_step - num_penalized_cancelled_before_step,
                }

                scenario_data["steps"].append({
                    "step_number": timesteps,
                    "action": action,
                    "flight_action": env.map_index_to_action(action)[0],
                    "aircraft_action": env.map_index_to_action(action)[1],
                    "reward": reward,
                    "total_timestep": total_timesteps,
                    "time_in_scenario": timesteps,
                    "epsilon": epsilon,
                    "action_reason": action_reason,
                    "impact_of_action": impact_of_action,
                    "done_flag": done_flag,
                    "action_mask_sum": np.sum(action_mask),
                    "len_action_mask": len(action_mask),
                    "info_after_step": env.info_after_step,
                    "masked_q_values": masked_q_values,
                    "q_values": q_values,
                    "action_mask": action_mask,
                })
                
                # Check if the episode is done
                if done_flag:
                    break
            
            total_reward = 0
            for _, reward in rewards[episode][scenario_folder].items():
                total_reward += reward
            # Store the total reward for the episode with the scenario specified while also keeping the step rewards
            rewards[episode][scenario_folder]["total"] = total_reward
            

            # save the action sequence
            action_sequences[episode][scenario_folder] = action_sequence

            # Summarize scenario
            scenario_data["total_reward"] = total_reward
            episode_data["scenarios"][scenario_folder] = scenario_data

        # Perform cross-validation at specified intervals
        if cross_val_flag:
            # Initialize best_test_reward and current_test_reward at first cross validation
            if (episode + 1) % CROSS_VAL_INTERVAL == 0:
                current_test_reward = cross_validate_on_test_data(model, episode + 1, log_data)
                if not hasattr(train_dqn_agent, 'best_test_reward'):
                    train_dqn_agent.best_test_reward = current_test_reward
                best_test_reward = train_dqn_agent.best_test_reward
            
                # Early stopping logic
                if current_test_reward < best_test_reward:
                    consecutive_drops += 1
                    print(f"Performance drop {consecutive_drops}/5 (current: {current_test_reward:.2f}, best: {best_test_reward:.2f})")
                    if consecutive_drops >= 500:
                        print(f"Early stopping triggered at episode {episode + 1} due to 5 consecutive drops in test performance")
                        break
                else:
                    consecutive_drops = 0
                    train_dqn_agent.best_test_reward = current_test_reward
                    best_test_reward = current_test_reward

        # Calculate the average reward for this batch of episodes
        avg_reward_for_this_batch = 0
        for i in range(len(scenario_folders)):
            avg_reward_for_this_batch += rewards[episode][scenario_folders[i]]["total"]
        avg_reward_for_this_batch /= len(scenario_folders)

        # Store avg_reward and total_timesteps in the current episode's dictionary:
        rewards[episode]["avg_reward"] = avg_reward_for_this_batch
        rewards[episode]["total_timesteps"] = total_timesteps

        print(f"({total_timesteps}/{MAX_TOTAL_TIMESTEPS}) {env_type} - episode {episode + 1} - epsilon {epsilon:.2f} - reward this episode: {avg_reward_for_this_batch:.2f}")
        # print(f"Total avg rewards for this batch: {avg_reward_for_this_batch}")

        # Summarize episode
        episode_data["avg_reward"] = avg_reward_for_this_batch
        log_data['episodes'][episode + 1] = episode_data
        episode += 1

    # Save the model after training
    if env_type == "myopic":
        model.save(f"../trained_models/dqn/myopic-{training_id}.zip")
    else:
        model.save(f"../trained_models/dqn/proactive-{training_id}.zip")

    runtime_end_in_seconds = time.time()
    runtime_in_seconds = runtime_end_in_seconds - runtime_start_in_seconds

    actual_total_timesteps = total_timesteps

    training_summary = {
        "runtime_seconds": runtime_in_seconds,
        "total_timesteps": total_timesteps,
        "final_rewards": good_rewards,
        "episodes_trained": episode + 1,
        "actual_total_timesteps": actual_total_timesteps,
    }
    log_data['training_summary'] = training_summary

    # Include all other relevant data
    log_data['average_batch_episode_rewards'] = good_rewards
    log_data['test_rewards'] = test_rewards
    log_data['epsilon_values'] = epsilon_values
    log_data['action_sequences'] = action_sequences
    log_data['rewards'] = rewards

    # Write all data to the log file at once
    log_file_path = os.path.join("../logs", "training", f"training_{training_id}.json")
    
    # make log_data serializable
    log_data = convert_to_serializable(log_data)
    with open(log_file_path, 'w') as log_file:
        json.dump(log_data, log_file, indent=4, cls=NumpyEncoder)


    finalize_training_log(training_id, training_summary, model_path)

    all_logs[training_id] = log_data
    # Return collected data
    return rewards, test_rewards, total_timesteps, epsilon_values, good_rewards, action_sequences, model_path_and_name

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# Define your seeds

# Lists to store the results from all seeds
all_myopic_runs = []
all_proactive_runs = []
all_myopic_steps_runs = []
all_proactive_steps_runs = []

def run_training_for_seed(seed):
    import random
    import numpy as np
    import torch as th

    random.seed(seed)
    np.random.seed(seed)
    if th.cuda.is_available():
        th.cuda.manual_seed_all(seed)
    th.manual_seed(seed)

    # Train myopic agent
    (rewards_myopic, test_rewards_myopic, total_timesteps_myopic, 
     epsilon_values_myopic, good_rewards_myopic, action_sequences_myopic, 
     model_path_and_name_myopic) = train_dqn_agent('myopic')

    # Train proactive agent
    (rewards_proactive, test_rewards_proactive, total_timesteps_proactive, 
     epsilon_values_proactive, good_rewards_proactive, action_sequences_proactive, 
     model_path_and_name_proactive) = train_dqn_agent('proactive')

    return (rewards_myopic, rewards_proactive)


# Run training for each seed and store results
for s in SEEDS:
    print(f"Running DQN training for seed {s}...")
    rewards_myopic, rewards_proactive = run_training_for_seed(s)

    # Extract episode rewards and steps for myopic
    # episodes in rewards_myopic are keys like 0,1,2,... up to final trained episode
    # Check "avg_reward" and "total_timesteps" exist for that episode
    myopic_episode_rewards = [
        rewards_myopic[e]["avg_reward"] for e in sorted(rewards_myopic.keys())
        if "avg_reward" in rewards_myopic[e]
    ]
    myopic_episode_steps = [
        rewards_myopic[e]["total_timesteps"] for e in sorted(rewards_myopic.keys())
        if "total_timesteps" in rewards_myopic[e]
    ]

    # Extract episode rewards and steps for proactive
    proactive_episode_rewards = [
        rewards_proactive[e]["avg_reward"] for e in sorted(rewards_proactive.keys())
        if "avg_reward" in rewards_proactive[e]
    ]
    proactive_episode_steps = [
        rewards_proactive[e]["total_timesteps"] for e in sorted(rewards_proactive.keys())
        if "total_timesteps" in rewards_proactive[e]
    ]

    # Append these arrays to the main lists
    all_myopic_runs.append(myopic_episode_rewards)
    all_proactive_runs.append(proactive_episode_rewards)
    all_myopic_steps_runs.append(myopic_episode_steps)
    all_proactive_steps_runs.append(proactive_episode_steps)


# Ensure all runs are trimmed to the same length
# (In case different runs have different episode lengths)
print(f"episode lengths:")
for i in range(len(all_myopic_runs)):
    print(f"Myopic seed {i}: {len(all_myopic_runs[i])}")
for i in range(len(all_proactive_runs)):
    print(f"Proactive seed {i}: {len(all_proactive_runs[i])}")

min_length_myopic = min(len(run) for run in all_myopic_runs if len(run) > 0)
min_length_proactive = min(len(run) for run in all_proactive_runs if len(run) > 0)

all_myopic_runs = [run[:min_length_myopic] for run in all_myopic_runs]
all_proactive_runs = [run[:min_length_proactive] for run in all_proactive_runs]
all_myopic_steps_runs = [steps[:min_length_myopic] for steps in all_myopic_steps_runs]
all_proactive_steps_runs = [steps[:min_length_proactive] for steps in all_proactive_steps_runs]

# Convert to numpy arrays
all_myopic_runs = np.array(all_myopic_runs)              # shape: (num_seeds, num_episodes)
all_proactive_runs = np.array(all_proactive_runs)        # shape: (num_seeds, num_episodes)
all_myopic_steps_runs = np.array(all_myopic_steps_runs)  # shape: (num_seeds, num_episodes)
all_proactive_steps_runs = np.array(all_proactive_steps_runs)

# Calculate mean and std across seeds
myopic_mean = all_myopic_runs.mean(axis=0)
myopic_std = all_myopic_runs.std(axis=0)
proactive_mean = all_proactive_runs.mean(axis=0)
proactive_std = all_proactive_runs.std(axis=0)

myopic_steps_mean = all_myopic_steps_runs.mean(axis=0).astype(int)
proactive_steps_mean = all_proactive_steps_runs.mean(axis=0).astype(int)
# Out:
# Running DQN training for seed 0...
# Models will be saved to: ../trained_models/dqn/myopic-0753.zip
# Device: mps
# Using MacBook M1
# Logging to /var/folders/m6/gwyqzldd12bg_s3mrl40tp6r0000gn/T/SB3-2024-12-07-04-03-24-763937
# (591/1000000) myopic - episode 1 - epsilon 1.00 - reward this episode: 4801.77
# (1214/1000000) myopic - episode 2 - epsilon 1.00 - reward this episode: 7088.09
# (1838/1000000) myopic - episode 3 - epsilon 0.99 - reward this episode: 6765.77
# (2448/1000000) myopic - episode 4 - epsilon 0.99 - reward this episode: 7480.22
# (3092/1000000) myopic - episode 5 - epsilon 0.99 - reward this episode: 7472.35
# (3725/1000000) myopic - episode 6 - epsilon 0.99 - reward this episode: 7789.54
# (4325/1000000) myopic - episode 7 - epsilon 0.98 - reward this episode: 6692.20
# (4944/1000000) myopic - episode 8 - epsilon 0.98 - reward this episode: 6560.92
# (5554/1000000) myopic - episode 9 - epsilon 0.98 - reward this episode: 5853.67
# (6141/1000000) myopic - episode 10 - epsilon 0.98 - reward this episode: 7730.30
# (6749/1000000) myopic - episode 11 - epsilon 0.97 - reward this episode: 7336.67
# (7388/1000000) myopic - episode 12 - epsilon 0.97 - reward this episode: 6001.35
# (7985/1000000) myopic - episode 13 - epsilon 0.97 - reward this episode: 7068.43
# (8577/1000000) myopic - episode 14 - epsilon 0.97 - reward this episode: 7397.21
# (9187/1000000) myopic - episode 15 - epsilon 0.96 - reward this episode: 7302.86
# (9838/1000000) myopic - episode 16 - epsilon 0.96 - reward this episode: 6908.12
# (10496/1000000) myopic - episode 17 - epsilon 0.96 - reward this episode: 6670.61
# (11156/1000000) myopic - episode 18 - epsilon 0.96 - reward this episode: 6854.06
# (11780/1000000) myopic - episode 19 - epsilon 0.96 - reward this episode: 8170.30
# (12446/1000000) myopic - episode 20 - epsilon 0.95 - reward this episode: 6598.59
# (13105/1000000) myopic - episode 21 - epsilon 0.95 - reward this episode: 5642.44
# (13712/1000000) myopic - episode 22 - epsilon 0.95 - reward this episode: 6296.95
# (14303/1000000) myopic - episode 23 - epsilon 0.95 - reward this episode: 8076.21
# (14918/1000000) myopic - episode 24 - epsilon 0.94 - reward this episode: 6291.15
# (15472/1000000) myopic - episode 25 - epsilon 0.94 - reward this episode: 5086.58
# (16086/1000000) myopic - episode 26 - epsilon 0.94 - reward this episode: 9529.06
# (16691/1000000) myopic - episode 27 - epsilon 0.94 - reward this episode: 7007.46
# (17299/1000000) myopic - episode 28 - epsilon 0.94 - reward this episode: 7593.58
# (17903/1000000) myopic - episode 29 - epsilon 0.93 - reward this episode: 7901.82
# (18516/1000000) myopic - episode 30 - epsilon 0.93 - reward this episode: 7848.06
# (19189/1000000) myopic - episode 31 - epsilon 0.93 - reward this episode: 7493.74
# (19808/1000000) myopic - episode 32 - epsilon 0.93 - reward this episode: 7867.58
# (20463/1000000) myopic - episode 33 - epsilon 0.92 - reward this episode: 7395.59
# (21063/1000000) myopic - episode 34 - epsilon 0.92 - reward this episode: 7965.61
# (21684/1000000) myopic - episode 35 - epsilon 0.92 - reward this episode: 7198.15
# (22304/1000000) myopic - episode 36 - epsilon 0.92 - reward this episode: 7770.42
# (22923/1000000) myopic - episode 37 - epsilon 0.91 - reward this episode: 7191.99
# (23543/1000000) myopic - episode 38 - epsilon 0.91 - reward this episode: 7151.93
# (24136/1000000) myopic - episode 39 - epsilon 0.91 - reward this episode: 7917.20
# (24769/1000000) myopic - episode 40 - epsilon 0.91 - reward this episode: 8136.30
# (25358/1000000) myopic - episode 41 - epsilon 0.91 - reward this episode: 8405.40
# (25994/1000000) myopic - episode 42 - epsilon 0.90 - reward this episode: 6591.18
# (26634/1000000) myopic - episode 43 - epsilon 0.90 - reward this episode: 6436.91
# (27281/1000000) myopic - episode 44 - epsilon 0.90 - reward this episode: 6332.51
# (27892/1000000) myopic - episode 45 - epsilon 0.90 - reward this episode: 8813.24
# (28518/1000000) myopic - episode 46 - epsilon 0.90 - reward this episode: 8970.02
# (29170/1000000) myopic - episode 47 - epsilon 0.89 - reward this episode: 5611.60
# (29769/1000000) myopic - episode 48 - epsilon 0.89 - reward this episode: 8585.58
# (30379/1000000) myopic - episode 49 - epsilon 0.89 - reward this episode: 7676.65
# (30999/1000000) myopic - episode 50 - epsilon 0.89 - reward this episode: 8200.06
# (31625/1000000) myopic - episode 51 - epsilon 0.88 - reward this episode: 6520.61
# (32233/1000000) myopic - episode 52 - epsilon 0.88 - reward this episode: 8743.10
# (32825/1000000) myopic - episode 53 - epsilon 0.88 - reward this episode: 7478.40
# (33446/1000000) myopic - episode 54 - epsilon 0.88 - reward this episode: 8690.85
# (34081/1000000) myopic - episode 55 - epsilon 0.88 - reward this episode: 7502.66
# (34691/1000000) myopic - episode 56 - epsilon 0.87 - reward this episode: 7444.38
# (35316/1000000) myopic - episode 57 - epsilon 0.87 - reward this episode: 8920.03
# (35939/1000000) myopic - episode 58 - epsilon 0.87 - reward this episode: 7526.10
# (36522/1000000) myopic - episode 59 - epsilon 0.87 - reward this episode: 8322.15
# (37113/1000000) myopic - episode 60 - epsilon 0.87 - reward this episode: 8223.81
# (37729/1000000) myopic - episode 61 - epsilon 0.86 - reward this episode: 8449.91
# (38319/1000000) myopic - episode 62 - epsilon 0.86 - reward this episode: 8197.61
# (38942/1000000) myopic - episode 63 - epsilon 0.86 - reward this episode: 8909.87
# (39583/1000000) myopic - episode 64 - epsilon 0.86 - reward this episode: 9000.62
# (40216/1000000) myopic - episode 65 - epsilon 0.86 - reward this episode: 8122.52
# (40812/1000000) myopic - episode 66 - epsilon 0.85 - reward this episode: 8296.19
# (41384/1000000) myopic - episode 67 - epsilon 0.85 - reward this episode: 9359.37
# (41988/1000000) myopic - episode 68 - epsilon 0.85 - reward this episode: 8355.17
# (42619/1000000) myopic - episode 69 - epsilon 0.85 - reward this episode: 7744.74
# (43251/1000000) myopic - episode 70 - epsilon 0.85 - reward this episode: 7182.60
# (43873/1000000) myopic - episode 71 - epsilon 0.84 - reward this episode: 7011.18
# (44501/1000000) myopic - episode 72 - epsilon 0.84 - reward this episode: 7941.66
# (45159/1000000) myopic - episode 73 - epsilon 0.84 - reward this episode: 7977.07
# (45796/1000000) myopic - episode 74 - epsilon 0.84 - reward this episode: 8580.63
# (46443/1000000) myopic - episode 75 - epsilon 0.83 - reward this episode: 7795.76
# (47023/1000000) myopic - episode 76 - epsilon 0.83 - reward this episode: 8065.85
# (47638/1000000) myopic - episode 77 - epsilon 0.83 - reward this episode: 8185.48
# (48278/1000000) myopic - episode 78 - epsilon 0.83 - reward this episode: 8200.30
# (48885/1000000) myopic - episode 79 - epsilon 0.83 - reward this episode: 8944.94
# (49487/1000000) myopic - episode 80 - epsilon 0.83 - reward this episode: 8592.97
# (50078/1000000) myopic - episode 81 - epsilon 0.82 - reward this episode: 8236.39
# (50720/1000000) myopic - episode 82 - epsilon 0.82 - reward this episode: 7551.03
# (51315/1000000) myopic - episode 83 - epsilon 0.82 - reward this episode: 8994.31
# (51914/1000000) myopic - episode 84 - epsilon 0.82 - reward this episode: 9406.13
# (52564/1000000) myopic - episode 85 - epsilon 0.82 - reward this episode: 7868.00
# (53192/1000000) myopic - episode 86 - epsilon 0.81 - reward this episode: 7675.06
# (53814/1000000) myopic - episode 87 - epsilon 0.81 - reward this episode: 7350.37
# (54418/1000000) myopic - episode 88 - epsilon 0.81 - reward this episode: 9842.93
# (55030/1000000) myopic - episode 89 - epsilon 0.81 - reward this episode: 8766.99
# (55660/1000000) myopic - episode 90 - epsilon 0.81 - reward this episode: 7377.80
# (56270/1000000) myopic - episode 91 - epsilon 0.80 - reward this episode: 9103.63
# (56918/1000000) myopic - episode 92 - epsilon 0.80 - reward this episode: 8522.40
# (57534/1000000) myopic - episode 93 - epsilon 0.80 - reward this episode: 7404.06
# (58156/1000000) myopic - episode 94 - epsilon 0.80 - reward this episode: 8685.79
# (58805/1000000) myopic - episode 95 - epsilon 0.80 - reward this episode: 8493.01
# (59419/1000000) myopic - episode 96 - epsilon 0.79 - reward this episode: 11193.94
# (60022/1000000) myopic - episode 97 - epsilon 0.79 - reward this episode: 8396.64
# (60632/1000000) myopic - episode 98 - epsilon 0.79 - reward this episode: 7161.00
# (61282/1000000) myopic - episode 99 - epsilon 0.79 - reward this episode: 8602.78
# (61930/1000000) myopic - episode 100 - epsilon 0.79 - reward this episode: 8152.85
# (62591/1000000) myopic - episode 101 - epsilon 0.78 - reward this episode: 7184.42
# (63200/1000000) myopic - episode 102 - epsilon 0.78 - reward this episode: 9594.85
# (63849/1000000) myopic - episode 103 - epsilon 0.78 - reward this episode: 9253.35
# (64500/1000000) myopic - episode 104 - epsilon 0.78 - reward this episode: 7529.04
# (65125/1000000) myopic - episode 105 - epsilon 0.78 - reward this episode: 10064.20
# (65697/1000000) myopic - episode 106 - epsilon 0.77 - reward this episode: 8926.55
# (66305/1000000) myopic - episode 107 - epsilon 0.77 - reward this episode: 9449.52
# (66937/1000000) myopic - episode 108 - epsilon 0.77 - reward this episode: 8773.43
# (67535/1000000) myopic - episode 109 - epsilon 0.77 - reward this episode: 10483.61
# (68141/1000000) myopic - episode 110 - epsilon 0.77 - reward this episode: 9171.11
# (68728/1000000) myopic - episode 111 - epsilon 0.77 - reward this episode: 9535.27
# (69346/1000000) myopic - episode 112 - epsilon 0.76 - reward this episode: 9937.37
# (69956/1000000) myopic - episode 113 - epsilon 0.76 - reward this episode: 9036.37
# (70562/1000000) myopic - episode 114 - epsilon 0.76 - reward this episode: 8756.21
# (71168/1000000) myopic - episode 115 - epsilon 0.76 - reward this episode: 9386.62
# (71782/1000000) myopic - episode 116 - epsilon 0.76 - reward this episode: 8891.42
# (72406/1000000) myopic - episode 117 - epsilon 0.75 - reward this episode: 8979.16
# (73010/1000000) myopic - episode 118 - epsilon 0.75 - reward this episode: 9019.85
# (73624/1000000) myopic - episode 119 - epsilon 0.75 - reward this episode: 8664.92
# (74224/1000000) myopic - episode 120 - epsilon 0.75 - reward this episode: 8535.68
# (74870/1000000) myopic - episode 121 - epsilon 0.75 - reward this episode: 8475.57
# (75484/1000000) myopic - episode 122 - epsilon 0.75 - reward this episode: 8991.67
# (76078/1000000) myopic - episode 123 - epsilon 0.74 - reward this episode: 10284.70
# (76718/1000000) myopic - episode 124 - epsilon 0.74 - reward this episode: 9951.94
# (77354/1000000) myopic - episode 125 - epsilon 0.74 - reward this episode: 10504.07
# (78001/1000000) myopic - episode 126 - epsilon 0.74 - reward this episode: 9328.85
# (78678/1000000) myopic - episode 127 - epsilon 0.74 - reward this episode: 9389.70
# (79282/1000000) myopic - episode 128 - epsilon 0.74 - reward this episode: 10697.42
# (79913/1000000) myopic - episode 129 - epsilon 0.73 - reward this episode: 9290.88
# (80496/1000000) myopic - episode 130 - epsilon 0.73 - reward this episode: 9522.80
# (81097/1000000) myopic - episode 131 - epsilon 0.73 - reward this episode: 9989.27
# (81722/1000000) myopic - episode 132 - epsilon 0.73 - reward this episode: 8023.80
# (82325/1000000) myopic - episode 133 - epsilon 0.73 - reward this episode: 9645.37
# (82954/1000000) myopic - episode 134 - epsilon 0.72 - reward this episode: 9255.95
# (83577/1000000) myopic - episode 135 - epsilon 0.72 - reward this episode: 9976.53
# (84206/1000000) myopic - episode 136 - epsilon 0.72 - reward this episode: 9971.07
# (84783/1000000) myopic - episode 137 - epsilon 0.72 - reward this episode: 8597.91
# (85378/1000000) myopic - episode 138 - epsilon 0.72 - reward this episode: 10570.53
# (85999/1000000) myopic - episode 139 - epsilon 0.72 - reward this episode: 9256.94
# (86612/1000000) myopic - episode 140 - epsilon 0.71 - reward this episode: 10999.51
# (87213/1000000) myopic - episode 141 - epsilon 0.71 - reward this episode: 10311.90
# (87805/1000000) myopic - episode 142 - epsilon 0.71 - reward this episode: 11124.08
# (88406/1000000) myopic - episode 143 - epsilon 0.71 - reward this episode: 9071.63
# (89037/1000000) myopic - episode 144 - epsilon 0.71 - reward this episode: 9907.01
# (89679/1000000) myopic - episode 145 - epsilon 0.71 - reward this episode: 8777.58
# (90308/1000000) myopic - episode 146 - epsilon 0.70 - reward this episode: 10672.46
# (90951/1000000) myopic - episode 147 - epsilon 0.70 - reward this episode: 8029.37
# (91580/1000000) myopic - episode 148 - epsilon 0.70 - reward this episode: 10986.13
# (92193/1000000) myopic - episode 149 - epsilon 0.70 - reward this episode: 9280.50
# (92819/1000000) myopic - episode 150 - epsilon 0.70 - reward this episode: 9216.20
# (93450/1000000) myopic - episode 151 - epsilon 0.70 - reward this episode: 8300.08
# (94046/1000000) myopic - episode 152 - epsilon 0.69 - reward this episode: 10566.04
# (94638/1000000) myopic - episode 153 - epsilon 0.69 - reward this episode: 10031.56
# (95222/1000000) myopic - episode 154 - epsilon 0.69 - reward this episode: 9376.56
# (95858/1000000) myopic - episode 155 - epsilon 0.69 - reward this episode: 9571.27
# (96472/1000000) myopic - episode 156 - epsilon 0.69 - reward this episode: 10004.21
# (97074/1000000) myopic - episode 157 - epsilon 0.69 - reward this episode: 10064.09
# (97709/1000000) myopic - episode 158 - epsilon 0.68 - reward this episode: 9258.56
# (98337/1000000) myopic - episode 159 - epsilon 0.68 - reward this episode: 10168.70
# (98947/1000000) myopic - episode 160 - epsilon 0.68 - reward this episode: 10120.56
# (99558/1000000) myopic - episode 161 - epsilon 0.68 - reward this episode: 9072.68
# (100200/1000000) myopic - episode 162 - epsilon 0.68 - reward this episode: 10247.75
# (100820/1000000) myopic - episode 163 - epsilon 0.68 - reward this episode: 10013.60
# (101441/1000000) myopic - episode 164 - epsilon 0.67 - reward this episode: 9113.77
# (102055/1000000) myopic - episode 165 - epsilon 0.67 - reward this episode: 9712.81
# (102726/1000000) myopic - episode 166 - epsilon 0.67 - reward this episode: 7818.48
# (103347/1000000) myopic - episode 167 - epsilon 0.67 - reward this episode: 9654.09
# (103909/1000000) myopic - episode 168 - epsilon 0.67 - reward this episode: 9304.37
# (104537/1000000) myopic - episode 169 - epsilon 0.67 - reward this episode: 11089.83
# (105170/1000000) myopic - episode 170 - epsilon 0.66 - reward this episode: 8749.70
# (105794/1000000) myopic - episode 171 - epsilon 0.66 - reward this episode: 9071.41
# (106435/1000000) myopic - episode 172 - epsilon 0.66 - reward this episode: 8797.99
# (107018/1000000) myopic - episode 173 - epsilon 0.66 - reward this episode: 9976.11
# (107697/1000000) myopic - episode 174 - epsilon 0.66 - reward this episode: 9506.83
# (108296/1000000) myopic - episode 175 - epsilon 0.66 - reward this episode: 10262.32
# (108936/1000000) myopic - episode 176 - epsilon 0.66 - reward this episode: 8497.51
# (109533/1000000) myopic - episode 177 - epsilon 0.65 - reward this episode: 9881.21
# (110151/1000000) myopic - episode 178 - epsilon 0.65 - reward this episode: 8446.77
# (110802/1000000) myopic - episode 179 - epsilon 0.65 - reward this episode: 8919.51
# (111411/1000000) myopic - episode 180 - epsilon 0.65 - reward this episode: 10399.47
# (112042/1000000) myopic - episode 181 - epsilon 0.65 - reward this episode: 9462.66
# (112659/1000000) myopic - episode 182 - epsilon 0.65 - reward this episode: 10688.81
# (113260/1000000) myopic - episode 183 - epsilon 0.64 - reward this episode: 9816.71
# (113879/1000000) myopic - episode 184 - epsilon 0.64 - reward this episode: 10542.01
# (114520/1000000) myopic - episode 185 - epsilon 0.64 - reward this episode: 8723.92
# (115121/1000000) myopic - episode 186 - epsilon 0.64 - reward this episode: 11422.19
# (115739/1000000) myopic - episode 187 - epsilon 0.64 - reward this episode: 9497.32
# (116368/1000000) myopic - episode 188 - epsilon 0.64 - reward this episode: 9354.36
# (116952/1000000) myopic - episode 189 - epsilon 0.64 - reward this episode: 10293.76
# (117592/1000000) myopic - episode 190 - epsilon 0.63 - reward this episode: 9694.59
# (118173/1000000) myopic - episode 191 - epsilon 0.63 - reward this episode: 9830.70
# (118793/1000000) myopic - episode 192 - epsilon 0.63 - reward this episode: 9984.21
# (119448/1000000) myopic - episode 193 - epsilon 0.63 - reward this episode: 10205.34
# (120060/1000000) myopic - episode 194 - epsilon 0.63 - reward this episode: 9587.13
# (120690/1000000) myopic - episode 195 - epsilon 0.63 - reward this episode: 10388.45
# (121320/1000000) myopic - episode 196 - epsilon 0.62 - reward this episode: 9728.87
# (121935/1000000) myopic - episode 197 - epsilon 0.62 - reward this episode: 10108.43
# (122563/1000000) myopic - episode 198 - epsilon 0.62 - reward this episode: 10320.69
# (123169/1000000) myopic - episode 199 - epsilon 0.62 - reward this episode: 9317.32
# (123779/1000000) myopic - episode 200 - epsilon 0.62 - reward this episode: 9801.69
# (124413/1000000) myopic - episode 201 - epsilon 0.62 - reward this episode: 9331.99
# (125015/1000000) myopic - episode 202 - epsilon 0.62 - reward this episode: 10445.37
# (125638/1000000) myopic - episode 203 - epsilon 0.61 - reward this episode: 9765.23
# (126249/1000000) myopic - episode 204 - epsilon 0.61 - reward this episode: 9484.41
# (126842/1000000) myopic - episode 205 - epsilon 0.61 - reward this episode: 9217.69
# (127479/1000000) myopic - episode 206 - epsilon 0.61 - reward this episode: 9315.30
# (128145/1000000) myopic - episode 207 - epsilon 0.61 - reward this episode: 8682.11
# (128761/1000000) myopic - episode 208 - epsilon 0.61 - reward this episode: 9457.00
# (129396/1000000) myopic - episode 209 - epsilon 0.61 - reward this episode: 9699.53
# (129998/1000000) myopic - episode 210 - epsilon 0.60 - reward this episode: 9646.53
# (130650/1000000) myopic - episode 211 - epsilon 0.60 - reward this episode: 10306.66
# (131265/1000000) myopic - episode 212 - epsilon 0.60 - reward this episode: 10348.77
# (131878/1000000) myopic - episode 213 - epsilon 0.60 - reward this episode: 10878.42
# (132494/1000000) myopic - episode 214 - epsilon 0.60 - reward this episode: 10123.56
# (133114/1000000) myopic - episode 215 - epsilon 0.60 - reward this episode: 10540.15
# (133739/1000000) myopic - episode 216 - epsilon 0.59 - reward this episode: 9865.36
# (134410/1000000) myopic - episode 217 - epsilon 0.59 - reward this episode: 9629.81
# (135029/1000000) myopic - episode 218 - epsilon 0.59 - reward this episode: 9895.85
# (135679/1000000) myopic - episode 219 - epsilon 0.59 - reward this episode: 9964.04
# (136271/1000000) myopic - episode 220 - epsilon 0.59 - reward this episode: 10236.22
# (136871/1000000) myopic - episode 221 - epsilon 0.59 - reward this episode: 10446.31
# (137521/1000000) myopic - episode 222 - epsilon 0.59 - reward this episode: 10445.42
# (138168/1000000) myopic - episode 223 - epsilon 0.58 - reward this episode: 9832.78
# (138821/1000000) myopic - episode 224 - epsilon 0.58 - reward this episode: 9576.43
# (139407/1000000) myopic - episode 225 - epsilon 0.58 - reward this episode: 10682.80
# (140011/1000000) myopic - episode 226 - epsilon 0.58 - reward this episode: 11122.80
# (140661/1000000) myopic - episode 227 - epsilon 0.58 - reward this episode: 10856.68
# (141298/1000000) myopic - episode 228 - epsilon 0.58 - reward this episode: 10331.74
# (141944/1000000) myopic - episode 229 - epsilon 0.58 - reward this episode: 10466.66
# (142537/1000000) myopic - episode 230 - epsilon 0.57 - reward this episode: 10115.49
# (143152/1000000) myopic - episode 231 - epsilon 0.57 - reward this episode: 12010.27
# (143796/1000000) myopic - episode 232 - epsilon 0.57 - reward this episode: 10512.86
# (144413/1000000) myopic - episode 233 - epsilon 0.57 - reward this episode: 10183.25
# (145028/1000000) myopic - episode 234 - epsilon 0.57 - reward this episode: 11679.45
# (145659/1000000) myopic - episode 235 - epsilon 0.57 - reward this episode: 9385.08
# (146284/1000000) myopic - episode 236 - epsilon 0.57 - reward this episode: 11338.97
# (146868/1000000) myopic - episode 237 - epsilon 0.57 - reward this episode: 10546.86
# (147524/1000000) myopic - episode 238 - epsilon 0.56 - reward this episode: 9448.98
# (148107/1000000) myopic - episode 239 - epsilon 0.56 - reward this episode: 10992.72
# (148724/1000000) myopic - episode 240 - epsilon 0.56 - reward this episode: 11186.50
# (149336/1000000) myopic - episode 241 - epsilon 0.56 - reward this episode: 10996.04
# (149946/1000000) myopic - episode 242 - epsilon 0.56 - reward this episode: 10454.64
# (150511/1000000) myopic - episode 243 - epsilon 0.56 - reward this episode: 10053.67
# (151174/1000000) myopic - episode 244 - epsilon 0.56 - reward this episode: 10101.60
# (151769/1000000) myopic - episode 245 - epsilon 0.55 - reward this episode: 9891.76
# (152428/1000000) myopic - episode 246 - epsilon 0.55 - reward this episode: 10293.74
# (153020/1000000) myopic - episode 247 - epsilon 0.55 - reward this episode: 12063.91
# (153668/1000000) myopic - episode 248 - epsilon 0.55 - reward this episode: 9680.20
# (154286/1000000) myopic - episode 249 - epsilon 0.55 - reward this episode: 10071.68
# (154908/1000000) myopic - episode 250 - epsilon 0.55 - reward this episode: 9810.38
# (155515/1000000) myopic - episode 251 - epsilon 0.55 - reward this episode: 10943.84
# (156169/1000000) myopic - episode 252 - epsilon 0.55 - reward this episode: 11366.60
# (156785/1000000) myopic - episode 253 - epsilon 0.54 - reward this episode: 11464.07
# (157399/1000000) myopic - episode 254 - epsilon 0.54 - reward this episode: 10703.70
# (157997/1000000) myopic - episode 255 - epsilon 0.54 - reward this episode: 11583.89
# (158605/1000000) myopic - episode 256 - epsilon 0.54 - reward this episode: 12426.34
# (159214/1000000) myopic - episode 257 - epsilon 0.54 - reward this episode: 10194.87
# (159821/1000000) myopic - episode 258 - epsilon 0.54 - reward this episode: 11833.64
# (160439/1000000) myopic - episode 259 - epsilon 0.54 - reward this episode: 11745.11
# (161062/1000000) myopic - episode 260 - epsilon 0.54 - reward this episode: 10640.17
# (161684/1000000) myopic - episode 261 - epsilon 0.53 - reward this episode: 10193.19
# (162318/1000000) myopic - episode 262 - epsilon 0.53 - reward this episode: 11775.90
# (162959/1000000) myopic - episode 263 - epsilon 0.53 - reward this episode: 10853.01
# (163586/1000000) myopic - episode 264 - epsilon 0.53 - reward this episode: 10760.63
# (164239/1000000) myopic - episode 265 - epsilon 0.53 - reward this episode: 9529.81
# (164883/1000000) myopic - episode 266 - epsilon 0.53 - reward this episode: 10796.72
# (165527/1000000) myopic - episode 267 - epsilon 0.53 - reward this episode: 11222.19
# (166145/1000000) myopic - episode 268 - epsilon 0.52 - reward this episode: 11038.15
# (166786/1000000) myopic - episode 269 - epsilon 0.52 - reward this episode: 9950.10
# (167405/1000000) myopic - episode 270 - epsilon 0.52 - reward this episode: 11022.90
# (167986/1000000) myopic - episode 271 - epsilon 0.52 - reward this episode: 11827.34
# (168632/1000000) myopic - episode 272 - epsilon 0.52 - reward this episode: 10538.81
# (169260/1000000) myopic - episode 273 - epsilon 0.52 - reward this episode: 10898.01
# (169881/1000000) myopic - episode 274 - epsilon 0.52 - reward this episode: 11087.25
# (170515/1000000) myopic - episode 275 - epsilon 0.52 - reward this episode: 11329.36
# (171128/1000000) myopic - episode 276 - epsilon 0.51 - reward this episode: 9486.53
# (171821/1000000) myopic - episode 277 - epsilon 0.51 - reward this episode: 10397.76
# (172428/1000000) myopic - episode 278 - epsilon 0.51 - reward this episode: 10779.52
# (173077/1000000) myopic - episode 279 - epsilon 0.51 - reward this episode: 11420.91
# (173733/1000000) myopic - episode 280 - epsilon 0.51 - reward this episode: 10303.79
# (174353/1000000) myopic - episode 281 - epsilon 0.51 - reward this episode: 10374.86
# (174940/1000000) myopic - episode 282 - epsilon 0.51 - reward this episode: 10673.02
# (175583/1000000) myopic - episode 283 - epsilon 0.51 - reward this episode: 10855.94
# (176219/1000000) myopic - episode 284 - epsilon 0.50 - reward this episode: 12128.12
# (176868/1000000) myopic - episode 285 - epsilon 0.50 - reward this episode: 11390.17
# (177510/1000000) myopic - episode 286 - epsilon 0.50 - reward this episode: 10849.97
# (178104/1000000) myopic - episode 287 - epsilon 0.50 - reward this episode: 10998.64
# (178714/1000000) myopic - episode 288 - epsilon 0.50 - reward this episode: 10831.54
# (179319/1000000) myopic - episode 289 - epsilon 0.50 - reward this episode: 11308.49
# (179952/1000000) myopic - episode 290 - epsilon 0.50 - reward this episode: 11402.39
# (180579/1000000) myopic - episode 291 - epsilon 0.50 - reward this episode: 11632.98
# (181211/1000000) myopic - episode 292 - epsilon 0.49 - reward this episode: 11127.82
# (181826/1000000) myopic - episode 293 - epsilon 0.49 - reward this episode: 10609.84
# (182398/1000000) myopic - episode 294 - epsilon 0.49 - reward this episode: 13694.02
# (183057/1000000) myopic - episode 295 - epsilon 0.49 - reward this episode: 10194.68
# (183668/1000000) myopic - episode 296 - epsilon 0.49 - reward this episode: 11755.08
# (184307/1000000) myopic - episode 297 - epsilon 0.49 - reward this episode: 10883.95
# (184962/1000000) myopic - episode 298 - epsilon 0.49 - reward this episode: 12322.59
# (185578/1000000) myopic - episode 299 - epsilon 0.49 - reward this episode: 10577.22
# (186193/1000000) myopic - episode 300 - epsilon 0.49 - reward this episode: 11765.05
# (186797/1000000) myopic - episode 301 - epsilon 0.48 - reward this episode: 10903.00
# (187398/1000000) myopic - episode 302 - epsilon 0.48 - reward this episode: 11412.45
# (187995/1000000) myopic - episode 303 - epsilon 0.48 - reward this episode: 11490.79
# (188613/1000000) myopic - episode 304 - epsilon 0.48 - reward this episode: 11380.71
# (189248/1000000) myopic - episode 305 - epsilon 0.48 - reward this episode: 9995.59
# (189865/1000000) myopic - episode 306 - epsilon 0.48 - reward this episode: 11136.65
# (190485/1000000) myopic - episode 307 - epsilon 0.48 - reward this episode: 10973.73
# (191108/1000000) myopic - episode 308 - epsilon 0.48 - reward this episode: 10927.17
# (191709/1000000) myopic - episode 309 - epsilon 0.48 - reward this episode: 12072.62
# (192316/1000000) myopic - episode 310 - epsilon 0.47 - reward this episode: 12497.88
# (192906/1000000) myopic - episode 311 - epsilon 0.47 - reward this episode: 11679.68
# (193515/1000000) myopic - episode 312 - epsilon 0.47 - reward this episode: 12108.33
# (194151/1000000) myopic - episode 313 - epsilon 0.47 - reward this episode: 11396.96
# (194751/1000000) myopic - episode 314 - epsilon 0.47 - reward this episode: 12234.92
# (195388/1000000) myopic - episode 315 - epsilon 0.47 - reward this episode: 11023.22
# (195980/1000000) myopic - episode 316 - epsilon 0.47 - reward this episode: 11566.23
# (196615/1000000) myopic - episode 317 - epsilon 0.47 - reward this episode: 12150.66
# (197266/1000000) myopic - episode 318 - epsilon 0.46 - reward this episode: 11095.51
# (197886/1000000) myopic - episode 319 - epsilon 0.46 - reward this episode: 12174.99
# (198552/1000000) myopic - episode 320 - epsilon 0.46 - reward this episode: 11349.23
# (199208/1000000) myopic - episode 321 - epsilon 0.46 - reward this episode: 11755.54
# (199836/1000000) myopic - episode 322 - epsilon 0.46 - reward this episode: 11640.54
# (200449/1000000) myopic - episode 323 - epsilon 0.46 - reward this episode: 11304.58
# (201096/1000000) myopic - episode 324 - epsilon 0.46 - reward this episode: 12086.98
# (201736/1000000) myopic - episode 325 - epsilon 0.46 - reward this episode: 11008.55
# (202325/1000000) myopic - episode 326 - epsilon 0.46 - reward this episode: 11299.21
# (202956/1000000) myopic - episode 327 - epsilon 0.45 - reward this episode: 11936.57
# (203588/1000000) myopic - episode 328 - epsilon 0.45 - reward this episode: 12766.80
# (204221/1000000) myopic - episode 329 - epsilon 0.45 - reward this episode: 10774.59
# (204845/1000000) myopic - episode 330 - epsilon 0.45 - reward this episode: 10943.35
# (205455/1000000) myopic - episode 331 - epsilon 0.45 - reward this episode: 11599.18
# (206100/1000000) myopic - episode 332 - epsilon 0.45 - reward this episode: 10865.64
# (206734/1000000) myopic - episode 333 - epsilon 0.45 - reward this episode: 11688.48
# (207390/1000000) myopic - episode 334 - epsilon 0.45 - reward this episode: 10926.31
# (207997/1000000) myopic - episode 335 - epsilon 0.45 - reward this episode: 11822.27
# (208601/1000000) myopic - episode 336 - epsilon 0.44 - reward this episode: 11141.62
# (209243/1000000) myopic - episode 337 - epsilon 0.44 - reward this episode: 11266.12
# (209859/1000000) myopic - episode 338 - epsilon 0.44 - reward this episode: 11531.74
# (210430/1000000) myopic - episode 339 - epsilon 0.44 - reward this episode: 12285.40
# (211081/1000000) myopic - episode 340 - epsilon 0.44 - reward this episode: 11568.37
# (211726/1000000) myopic - episode 341 - epsilon 0.44 - reward this episode: 11949.00
# (212363/1000000) myopic - episode 342 - epsilon 0.44 - reward this episode: 11193.79
# (212945/1000000) myopic - episode 343 - epsilon 0.44 - reward this episode: 11803.46
# (213574/1000000) myopic - episode 344 - epsilon 0.44 - reward this episode: 11910.97
# (214252/1000000) myopic - episode 345 - epsilon 0.44 - reward this episode: 12171.10
# (214878/1000000) myopic - episode 346 - epsilon 0.43 - reward this episode: 13078.15
# (215492/1000000) myopic - episode 347 - epsilon 0.43 - reward this episode: 10836.45
# (216127/1000000) myopic - episode 348 - epsilon 0.43 - reward this episode: 11079.51
# (216740/1000000) myopic - episode 349 - epsilon 0.43 - reward this episode: 12380.96
# (217322/1000000) myopic - episode 350 - epsilon 0.43 - reward this episode: 13911.12
# (217930/1000000) myopic - episode 351 - epsilon 0.43 - reward this episode: 12491.10
# (218611/1000000) myopic - episode 352 - epsilon 0.43 - reward this episode: 13215.94
# (219253/1000000) myopic - episode 353 - epsilon 0.43 - reward this episode: 11770.88
# (219910/1000000) myopic - episode 354 - epsilon 0.43 - reward this episode: 12050.17
# (220570/1000000) myopic - episode 355 - epsilon 0.42 - reward this episode: 12415.57
# (221192/1000000) myopic - episode 356 - epsilon 0.42 - reward this episode: 11724.90
# (221850/1000000) myopic - episode 357 - epsilon 0.42 - reward this episode: 12656.37
# (222443/1000000) myopic - episode 358 - epsilon 0.42 - reward this episode: 12549.75
# (223050/1000000) myopic - episode 359 - epsilon 0.42 - reward this episode: 12599.78
# (223718/1000000) myopic - episode 360 - epsilon 0.42 - reward this episode: 11511.39
# (224333/1000000) myopic - episode 361 - epsilon 0.42 - reward this episode: 12476.93
# (224944/1000000) myopic - episode 362 - epsilon 0.42 - reward this episode: 11647.82
# (225570/1000000) myopic - episode 363 - epsilon 0.42 - reward this episode: 12476.55
# (226163/1000000) myopic - episode 364 - epsilon 0.42 - reward this episode: 12453.63
# (226787/1000000) myopic - episode 365 - epsilon 0.41 - reward this episode: 11566.36
# (227400/1000000) myopic - episode 366 - epsilon 0.41 - reward this episode: 11642.26
# (228007/1000000) myopic - episode 367 - epsilon 0.41 - reward this episode: 13467.05
# (228617/1000000) myopic - episode 368 - epsilon 0.41 - reward this episode: 12432.38
# (229241/1000000) myopic - episode 369 - epsilon 0.41 - reward this episode: 11866.22
# (229847/1000000) myopic - episode 370 - epsilon 0.41 - reward this episode: 12670.74
# (230502/1000000) myopic - episode 371 - epsilon 0.41 - reward this episode: 10900.46
# (231140/1000000) myopic - episode 372 - epsilon 0.41 - reward this episode: 12848.81
# (231770/1000000) myopic - episode 373 - epsilon 0.41 - reward this episode: 11835.09
# (232394/1000000) myopic - episode 374 - epsilon 0.41 - reward this episode: 12576.58
# (232986/1000000) myopic - episode 375 - epsilon 0.40 - reward this episode: 11934.04
# (233625/1000000) myopic - episode 376 - epsilon 0.40 - reward this episode: 12123.95
# (234247/1000000) myopic - episode 377 - epsilon 0.40 - reward this episode: 12316.36
# (234858/1000000) myopic - episode 378 - epsilon 0.40 - reward this episode: 12291.61
# (235487/1000000) myopic - episode 379 - epsilon 0.40 - reward this episode: 12494.91
# (236106/1000000) myopic - episode 380 - epsilon 0.40 - reward this episode: 12942.11
# (236742/1000000) myopic - episode 381 - epsilon 0.40 - reward this episode: 13341.75
# (237375/1000000) myopic - episode 382 - epsilon 0.40 - reward this episode: 12615.20
# (237995/1000000) myopic - episode 383 - epsilon 0.40 - reward this episode: 13082.54
# (238622/1000000) myopic - episode 384 - epsilon 0.40 - reward this episode: 13233.21
# (239291/1000000) myopic - episode 385 - epsilon 0.39 - reward this episode: 12661.66
# (239958/1000000) myopic - episode 386 - epsilon 0.39 - reward this episode: 11496.81
# (240600/1000000) myopic - episode 387 - epsilon 0.39 - reward this episode: 12479.83
# (241211/1000000) myopic - episode 388 - epsilon 0.39 - reward this episode: 11935.42
# (241835/1000000) myopic - episode 389 - epsilon 0.39 - reward this episode: 12016.41
# (242427/1000000) myopic - episode 390 - epsilon 0.39 - reward this episode: 12666.05
# (243024/1000000) myopic - episode 391 - epsilon 0.39 - reward this episode: 11138.84
# (243636/1000000) myopic - episode 392 - epsilon 0.39 - reward this episode: 12865.88
# (244212/1000000) myopic - episode 393 - epsilon 0.39 - reward this episode: 12303.85
# (244842/1000000) myopic - episode 394 - epsilon 0.39 - reward this episode: 13783.64
# (245446/1000000) myopic - episode 395 - epsilon 0.39 - reward this episode: 12687.04
# (246079/1000000) myopic - episode 396 - epsilon 0.38 - reward this episode: 11569.32
# (246738/1000000) myopic - episode 397 - epsilon 0.38 - reward this episode: 12138.84
# (247386/1000000) myopic - episode 398 - epsilon 0.38 - reward this episode: 12012.82
# (248010/1000000) myopic - episode 399 - epsilon 0.38 - reward this episode: 12666.56
# (248632/1000000) myopic - episode 400 - epsilon 0.38 - reward this episode: 12234.88
# (249277/1000000) myopic - episode 401 - epsilon 0.38 - reward this episode: 14303.27
# (249916/1000000) myopic - episode 402 - epsilon 0.38 - reward this episode: 12556.43
# (250562/1000000) myopic - episode 403 - epsilon 0.38 - reward this episode: 11339.86
# (251242/1000000) myopic - episode 404 - epsilon 0.38 - reward this episode: 12592.81
# (251852/1000000) myopic - episode 405 - epsilon 0.38 - reward this episode: 12603.59
# (252465/1000000) myopic - episode 406 - epsilon 0.38 - reward this episode: 12802.46
# (253110/1000000) myopic - episode 407 - epsilon 0.37 - reward this episode: 12587.51
# (253736/1000000) myopic - episode 408 - epsilon 0.37 - reward this episode: 12890.43
# (254388/1000000) myopic - episode 409 - epsilon 0.37 - reward this episode: 12180.59
# (255016/1000000) myopic - episode 410 - epsilon 0.37 - reward this episode: 12836.52
# (255624/1000000) myopic - episode 411 - epsilon 0.37 - reward this episode: 12583.96
# (256295/1000000) myopic - episode 412 - epsilon 0.37 - reward this episode: 13680.99
# (256909/1000000) myopic - episode 413 - epsilon 0.37 - reward this episode: 11841.76
# (257547/1000000) myopic - episode 414 - epsilon 0.37 - reward this episode: 12369.63
# (258180/1000000) myopic - episode 415 - epsilon 0.37 - reward this episode: 11665.96
# (258792/1000000) myopic - episode 416 - epsilon 0.37 - reward this episode: 13747.59
# (259401/1000000) myopic - episode 417 - epsilon 0.37 - reward this episode: 12561.29
# (260034/1000000) myopic - episode 418 - epsilon 0.36 - reward this episode: 13032.40
# (260677/1000000) myopic - episode 419 - epsilon 0.36 - reward this episode: 12555.82
# (261319/1000000) myopic - episode 420 - epsilon 0.36 - reward this episode: 12359.97
# (261944/1000000) myopic - episode 421 - epsilon 0.36 - reward this episode: 12038.58
# (262575/1000000) myopic - episode 422 - epsilon 0.36 - reward this episode: 12395.51
# (263179/1000000) myopic - episode 423 - epsilon 0.36 - reward this episode: 12745.33
# (263832/1000000) myopic - episode 424 - epsilon 0.36 - reward this episode: 12337.15
# (264432/1000000) myopic - episode 425 - epsilon 0.36 - reward this episode: 11305.77
# (265051/1000000) myopic - episode 426 - epsilon 0.36 - reward this episode: 13124.94
# (265652/1000000) myopic - episode 427 - epsilon 0.36 - reward this episode: 12578.88
# (266296/1000000) myopic - episode 428 - epsilon 0.36 - reward this episode: 13616.16
# (266909/1000000) myopic - episode 429 - epsilon 0.35 - reward this episode: 12543.56
# (267545/1000000) myopic - episode 430 - epsilon 0.35 - reward this episode: 12754.17
# (268154/1000000) myopic - episode 431 - epsilon 0.35 - reward this episode: 12617.68
# (268750/1000000) myopic - episode 432 - epsilon 0.35 - reward this episode: 13761.70
# (269366/1000000) myopic - episode 433 - epsilon 0.35 - reward this episode: 13031.37
# (270006/1000000) myopic - episode 434 - epsilon 0.35 - reward this episode: 12541.52
# (270567/1000000) myopic - episode 435 - epsilon 0.35 - reward this episode: 12495.71
# (271160/1000000) myopic - episode 436 - epsilon 0.35 - reward this episode: 13214.03
# (271792/1000000) myopic - episode 437 - epsilon 0.35 - reward this episode: 12624.14
# (272430/1000000) myopic - episode 438 - epsilon 0.35 - reward this episode: 12291.21
# (273072/1000000) myopic - episode 439 - epsilon 0.35 - reward this episode: 13309.65
# (273684/1000000) myopic - episode 440 - epsilon 0.35 - reward this episode: 13114.98
# (274322/1000000) myopic - episode 441 - epsilon 0.34 - reward this episode: 12064.26
# (274954/1000000) myopic - episode 442 - epsilon 0.34 - reward this episode: 12515.86
# (275543/1000000) myopic - episode 443 - epsilon 0.34 - reward this episode: 13750.18
# (276154/1000000) myopic - episode 444 - epsilon 0.34 - reward this episode: 13742.73
# (276803/1000000) myopic - episode 445 - epsilon 0.34 - reward this episode: 13010.79
# (277462/1000000) myopic - episode 446 - epsilon 0.34 - reward this episode: 12023.11
# (278088/1000000) myopic - episode 447 - epsilon 0.34 - reward this episode: 13249.55
# (278685/1000000) myopic - episode 448 - epsilon 0.34 - reward this episode: 12972.37
# (279300/1000000) myopic - episode 449 - epsilon 0.34 - reward this episode: 12848.85
# (279949/1000000) myopic - episode 450 - epsilon 0.34 - reward this episode: 13073.81
# (280601/1000000) myopic - episode 451 - epsilon 0.34 - reward this episode: 11650.58
# (281183/1000000) myopic - episode 452 - epsilon 0.34 - reward this episode: 12962.47
# (281858/1000000) myopic - episode 453 - epsilon 0.33 - reward this episode: 11455.53
# (282516/1000000) myopic - episode 454 - epsilon 0.33 - reward this episode: 13018.69
# (283126/1000000) myopic - episode 455 - epsilon 0.33 - reward this episode: 12805.06
# (283764/1000000) myopic - episode 456 - epsilon 0.33 - reward this episode: 13338.12
# (284376/1000000) myopic - episode 457 - epsilon 0.33 - reward this episode: 12442.15
# (285023/1000000) myopic - episode 458 - epsilon 0.33 - reward this episode: 13525.08
# (285677/1000000) myopic - episode 459 - epsilon 0.33 - reward this episode: 13413.35
# (286329/1000000) myopic - episode 460 - epsilon 0.33 - reward this episode: 13168.06
# (286936/1000000) myopic - episode 461 - epsilon 0.33 - reward this episode: 12837.06
# (287612/1000000) myopic - episode 462 - epsilon 0.33 - reward this episode: 12544.44
# (288251/1000000) myopic - episode 463 - epsilon 0.33 - reward this episode: 12907.91
# (288886/1000000) myopic - episode 464 - epsilon 0.33 - reward this episode: 13010.90
# (289511/1000000) myopic - episode 465 - epsilon 0.32 - reward this episode: 11820.24
# (290133/1000000) myopic - episode 466 - epsilon 0.32 - reward this episode: 13430.16
# (290785/1000000) myopic - episode 467 - epsilon 0.32 - reward this episode: 12522.97
# (291421/1000000) myopic - episode 468 - epsilon 0.32 - reward this episode: 13543.13
# (292017/1000000) myopic - episode 469 - epsilon 0.32 - reward this episode: 12342.54
# (292644/1000000) myopic - episode 470 - epsilon 0.32 - reward this episode: 12678.51
# (293244/1000000) myopic - episode 471 - epsilon 0.32 - reward this episode: 14071.63
# (293847/1000000) myopic - episode 472 - epsilon 0.32 - reward this episode: 13438.85
# (294443/1000000) myopic - episode 473 - epsilon 0.32 - reward this episode: 12641.76
# (295045/1000000) myopic - episode 474 - epsilon 0.32 - reward this episode: 13698.56
# (295705/1000000) myopic - episode 475 - epsilon 0.32 - reward this episode: 12631.53
# (296346/1000000) myopic - episode 476 - epsilon 0.32 - reward this episode: 13520.15
# (296966/1000000) myopic - episode 477 - epsilon 0.32 - reward this episode: 13173.46
# (297572/1000000) myopic - episode 478 - epsilon 0.31 - reward this episode: 13097.37
# (298171/1000000) myopic - episode 479 - epsilon 0.31 - reward this episode: 13315.32
# (298807/1000000) myopic - episode 480 - epsilon 0.31 - reward this episode: 12996.28
# (299424/1000000) myopic - episode 481 - epsilon 0.31 - reward this episode: 13161.76
# (300031/1000000) myopic - episode 482 - epsilon 0.31 - reward this episode: 13672.94
# (300662/1000000) myopic - episode 483 - epsilon 0.31 - reward this episode: 14358.18
# (301283/1000000) myopic - episode 484 - epsilon 0.31 - reward this episode: 13135.82
# (301922/1000000) myopic - episode 485 - epsilon 0.31 - reward this episode: 13173.34
# (302545/1000000) myopic - episode 486 - epsilon 0.31 - reward this episode: 13970.26
# (303197/1000000) myopic - episode 487 - epsilon 0.31 - reward this episode: 13192.89
# (303772/1000000) myopic - episode 488 - epsilon 0.31 - reward this episode: 13288.27
# (304383/1000000) myopic - episode 489 - epsilon 0.31 - reward this episode: 14141.86
# (305005/1000000) myopic - episode 490 - epsilon 0.31 - reward this episode: 12801.57
# (305626/1000000) myopic - episode 491 - epsilon 0.31 - reward this episode: 14436.42
# (306297/1000000) myopic - episode 492 - epsilon 0.30 - reward this episode: 12929.34
# (306915/1000000) myopic - episode 493 - epsilon 0.30 - reward this episode: 13659.60
# (307552/1000000) myopic - episode 494 - epsilon 0.30 - reward this episode: 12992.10
# (308227/1000000) myopic - episode 495 - epsilon 0.30 - reward this episode: 13534.21
# (308865/1000000) myopic - episode 496 - epsilon 0.30 - reward this episode: 13129.49
# (309477/1000000) myopic - episode 497 - epsilon 0.30 - reward this episode: 13470.64
# (310136/1000000) myopic - episode 498 - epsilon 0.30 - reward this episode: 12740.96
# (310790/1000000) myopic - episode 499 - epsilon 0.30 - reward this episode: 13005.82
# (311428/1000000) myopic - episode 500 - epsilon 0.30 - reward this episode: 13597.61
# (312073/1000000) myopic - episode 501 - epsilon 0.30 - reward this episode: 13302.19
# (312697/1000000) myopic - episode 502 - epsilon 0.30 - reward this episode: 13920.60
# (313332/1000000) myopic - episode 503 - epsilon 0.30 - reward this episode: 14123.83
# (313992/1000000) myopic - episode 504 - epsilon 0.30 - reward this episode: 13175.84
# (314623/1000000) myopic - episode 505 - epsilon 0.29 - reward this episode: 14300.38
# (315270/1000000) myopic - episode 506 - epsilon 0.29 - reward this episode: 13069.29
# (315882/1000000) myopic - episode 507 - epsilon 0.29 - reward this episode: 13952.49
# (316526/1000000) myopic - episode 508 - epsilon 0.29 - reward this episode: 12892.59
# (317107/1000000) myopic - episode 509 - epsilon 0.29 - reward this episode: 14927.10
# (317743/1000000) myopic - episode 510 - epsilon 0.29 - reward this episode: 13728.04
# (318354/1000000) myopic - episode 511 - epsilon 0.29 - reward this episode: 14164.48
# (319014/1000000) myopic - episode 512 - epsilon 0.29 - reward this episode: 14420.20
# (319657/1000000) myopic - episode 513 - epsilon 0.29 - reward this episode: 13094.91
# (320289/1000000) myopic - episode 514 - epsilon 0.29 - reward this episode: 13311.60
# (320929/1000000) myopic - episode 515 - epsilon 0.29 - reward this episode: 14105.79
# (321589/1000000) myopic - episode 516 - epsilon 0.29 - reward this episode: 14408.23
# (322236/1000000) myopic - episode 517 - epsilon 0.29 - reward this episode: 13786.92
# (322902/1000000) myopic - episode 518 - epsilon 0.29 - reward this episode: 13189.08
# (323514/1000000) myopic - episode 519 - epsilon 0.28 - reward this episode: 13542.21
# (324133/1000000) myopic - episode 520 - epsilon 0.28 - reward this episode: 13430.17
# (324802/1000000) myopic - episode 521 - epsilon 0.28 - reward this episode: 14471.76
# (325427/1000000) myopic - episode 522 - epsilon 0.28 - reward this episode: 13662.94
# (326077/1000000) myopic - episode 523 - epsilon 0.28 - reward this episode: 14833.06
# (326680/1000000) myopic - episode 524 - epsilon 0.28 - reward this episode: 14423.80
# (327311/1000000) myopic - episode 525 - epsilon 0.28 - reward this episode: 14002.79
# (327955/1000000) myopic - episode 526 - epsilon 0.28 - reward this episode: 14828.21
# (328639/1000000) myopic - episode 527 - epsilon 0.28 - reward this episode: 13904.66
# (329269/1000000) myopic - episode 528 - epsilon 0.28 - reward this episode: 14299.30
# (329972/1000000) myopic - episode 529 - epsilon 0.28 - reward this episode: 13176.97
# (330622/1000000) myopic - episode 530 - epsilon 0.28 - reward this episode: 14629.71
# (331262/1000000) myopic - episode 531 - epsilon 0.28 - reward this episode: 14309.14
# (331907/1000000) myopic - episode 532 - epsilon 0.28 - reward this episode: 14390.14
# (332544/1000000) myopic - episode 533 - epsilon 0.27 - reward this episode: 14584.64
# (333185/1000000) myopic - episode 534 - epsilon 0.27 - reward this episode: 14355.17
# (333791/1000000) myopic - episode 535 - epsilon 0.27 - reward this episode: 14583.62
# (334447/1000000) myopic - episode 536 - epsilon 0.27 - reward this episode: 14040.10
# (335091/1000000) myopic - episode 537 - epsilon 0.27 - reward this episode: 14855.89
# (335721/1000000) myopic - episode 538 - epsilon 0.27 - reward this episode: 14528.91
# (336355/1000000) myopic - episode 539 - epsilon 0.27 - reward this episode: 14081.03
# (337033/1000000) myopic - episode 540 - epsilon 0.27 - reward this episode: 13552.54
# (337671/1000000) myopic - episode 541 - epsilon 0.27 - reward this episode: 13755.75
# (338330/1000000) myopic - episode 542 - epsilon 0.27 - reward this episode: 14465.54
# (338992/1000000) myopic - episode 543 - epsilon 0.27 - reward this episode: 13738.83
# (339625/1000000) myopic - episode 544 - epsilon 0.27 - reward this episode: 13473.64
# (340242/1000000) myopic - episode 545 - epsilon 0.27 - reward this episode: 14133.34
# (340914/1000000) myopic - episode 546 - epsilon 0.27 - reward this episode: 13849.85
# (341555/1000000) myopic - episode 547 - epsilon 0.27 - reward this episode: 14752.46
# (342199/1000000) myopic - episode 548 - epsilon 0.26 - reward this episode: 14477.98
# (342877/1000000) myopic - episode 549 - epsilon 0.26 - reward this episode: 14250.30
# (343525/1000000) myopic - episode 550 - epsilon 0.26 - reward this episode: 13905.78
# (344147/1000000) myopic - episode 551 - epsilon 0.26 - reward this episode: 14796.25
# (344817/1000000) myopic - episode 552 - epsilon 0.26 - reward this episode: 13837.12
# (345449/1000000) myopic - episode 553 - epsilon 0.26 - reward this episode: 14916.06
# (346091/1000000) myopic - episode 554 - epsilon 0.26 - reward this episode: 14128.09
# (346749/1000000) myopic - episode 555 - epsilon 0.26 - reward this episode: 13868.62
# (347438/1000000) myopic - episode 556 - epsilon 0.26 - reward this episode: 12536.57
# (348052/1000000) myopic - episode 557 - epsilon 0.26 - reward this episode: 14494.09
# (348703/1000000) myopic - episode 558 - epsilon 0.26 - reward this episode: 14471.91
# (349359/1000000) myopic - episode 559 - epsilon 0.26 - reward this episode: 14091.68
# (350016/1000000) myopic - episode 560 - epsilon 0.26 - reward this episode: 14408.17
# (350659/1000000) myopic - episode 561 - epsilon 0.26 - reward this episode: 14581.37
# (351333/1000000) myopic - episode 562 - epsilon 0.26 - reward this episode: 13652.15
# (352003/1000000) myopic - episode 563 - epsilon 0.25 - reward this episode: 13890.95
# (352647/1000000) myopic - episode 564 - epsilon 0.25 - reward this episode: 14168.91
# (353231/1000000) myopic - episode 565 - epsilon 0.25 - reward this episode: 14913.05
# (353875/1000000) myopic - episode 566 - epsilon 0.25 - reward this episode: 14612.78
# (354528/1000000) myopic - episode 567 - epsilon 0.25 - reward this episode: 15281.60
# ...
# (868864/1000000) proactive - episode 1314 - epsilon 0.03 - reward this episode: 18447.29
# (869622/1000000) proactive - episode 1315 - epsilon 0.03 - reward this episode: 18380.63
# (870363/1000000) proactive - episode 1316 - epsilon 0.03 - reward this episode: 18291.05
# (871119/1000000) proactive - episode 1317 - epsilon 0.03 - reward this episode: 18273.61
# (871870/1000000) proactive - episode 1318 - epsilon 0.03 - reward this episode: 18295.18
# (872592/1000000) proactive - episode 1319 - epsilon 0.03 - reward this episode: 18580.00
# (873303/1000000) proactive - episode 1320 - epsilon 0.03 - reward this episode: 18687.02
# (874049/1000000) proactive - episode 1321 - epsilon 0.03 - reward this episode: 18038.70
# (874855/1000000) proactive - episode 1322 - epsilon 0.03 - reward this episode: 18930.55
# (875589/1000000) proactive - episode 1323 - epsilon 0.03 - reward this episode: 18365.94
# (876366/1000000) proactive - episode 1324 - epsilon 0.03 - reward this episode: 18670.21
# (877122/1000000) proactive - episode 1325 - epsilon 0.03 - reward this episode: 18474.83
# (877907/1000000) proactive - episode 1326 - epsilon 0.03 - reward this episode: 18727.29
# (878638/1000000) proactive - episode 1327 - epsilon 0.03 - reward this episode: 18775.63
# (879383/1000000) proactive - episode 1328 - epsilon 0.03 - reward this episode: 18656.13
# (880135/1000000) proactive - episode 1329 - epsilon 0.03 - reward this episode: 18724.18
# (880897/1000000) proactive - episode 1330 - epsilon 0.03 - reward this episode: 19127.72
# (881660/1000000) proactive - episode 1331 - epsilon 0.03 - reward this episode: 18447.10
# (882403/1000000) proactive - episode 1332 - epsilon 0.03 - reward this episode: 18438.65
# (883141/1000000) proactive - episode 1333 - epsilon 0.03 - reward this episode: 17950.90
# (883921/1000000) proactive - episode 1334 - epsilon 0.03 - reward this episode: 18738.12
# (884698/1000000) proactive - episode 1335 - epsilon 0.03 - reward this episode: 18639.23
# (885457/1000000) proactive - episode 1336 - epsilon 0.03 - reward this episode: 18565.10
# (886217/1000000) proactive - episode 1337 - epsilon 0.03 - reward this episode: 18801.36
# (886966/1000000) proactive - episode 1338 - epsilon 0.03 - reward this episode: 18704.21
# (887704/1000000) proactive - episode 1339 - epsilon 0.03 - reward this episode: 19091.75
# (888436/1000000) proactive - episode 1340 - epsilon 0.03 - reward this episode: 18962.96
# (889183/1000000) proactive - episode 1341 - epsilon 0.03 - reward this episode: 18624.43
# (889920/1000000) proactive - episode 1342 - epsilon 0.03 - reward this episode: 18492.66
# (890655/1000000) proactive - episode 1343 - epsilon 0.03 - reward this episode: 18582.65
# (891376/1000000) proactive - episode 1344 - epsilon 0.03 - reward this episode: 19104.04
# (892108/1000000) proactive - episode 1345 - epsilon 0.03 - reward this episode: 18922.38
# (892870/1000000) proactive - episode 1346 - epsilon 0.03 - reward this episode: 18328.62
# (893608/1000000) proactive - episode 1347 - epsilon 0.03 - reward this episode: 18756.89
# (894358/1000000) proactive - episode 1348 - epsilon 0.03 - reward this episode: 18821.19
# (895103/1000000) proactive - episode 1349 - epsilon 0.03 - reward this episode: 18842.27
# (895816/1000000) proactive - episode 1350 - epsilon 0.03 - reward this episode: 18843.33
# (896599/1000000) proactive - episode 1351 - epsilon 0.03 - reward this episode: 18887.77
# (897349/1000000) proactive - episode 1352 - epsilon 0.03 - reward this episode: 18300.48
# (898081/1000000) proactive - episode 1353 - epsilon 0.03 - reward this episode: 18736.49
# (898843/1000000) proactive - episode 1354 - epsilon 0.03 - reward this episode: 18094.04
# (899581/1000000) proactive - episode 1355 - epsilon 0.03 - reward this episode: 18385.36
# (900314/1000000) proactive - episode 1356 - epsilon 0.03 - reward this episode: 18420.51
# (901062/1000000) proactive - episode 1357 - epsilon 0.03 - reward this episode: 18580.95
# (901795/1000000) proactive - episode 1358 - epsilon 0.03 - reward this episode: 18429.17
# (902523/1000000) proactive - episode 1359 - epsilon 0.03 - reward this episode: 18621.54
# (903248/1000000) proactive - episode 1360 - epsilon 0.03 - reward this episode: 18644.60
# (904013/1000000) proactive - episode 1361 - epsilon 0.03 - reward this episode: 18840.22
# (904746/1000000) proactive - episode 1362 - epsilon 0.03 - reward this episode: 18434.77
# (905494/1000000) proactive - episode 1363 - epsilon 0.03 - reward this episode: 18333.20
# (906259/1000000) proactive - episode 1364 - epsilon 0.03 - reward this episode: 18895.21
# (906985/1000000) proactive - episode 1365 - epsilon 0.03 - reward this episode: 18962.06
# (907746/1000000) proactive - episode 1366 - epsilon 0.03 - reward this episode: 18862.77
# (908465/1000000) proactive - episode 1367 - epsilon 0.03 - reward this episode: 18418.37
# (909216/1000000) proactive - episode 1368 - epsilon 0.03 - reward this episode: 19343.20
# (909960/1000000) proactive - episode 1369 - epsilon 0.03 - reward this episode: 18806.69
# (910697/1000000) proactive - episode 1370 - epsilon 0.03 - reward this episode: 18480.41
# (911450/1000000) proactive - episode 1371 - epsilon 0.03 - reward this episode: 18486.18
# (912202/1000000) proactive - episode 1372 - epsilon 0.03 - reward this episode: 18987.39
# (912959/1000000) proactive - episode 1373 - epsilon 0.03 - reward this episode: 19097.38
# (913701/1000000) proactive - episode 1374 - epsilon 0.03 - reward this episode: 18512.59
# (914428/1000000) proactive - episode 1375 - epsilon 0.03 - reward this episode: 19115.59
# (915150/1000000) proactive - episode 1376 - epsilon 0.03 - reward this episode: 18212.66
# (915865/1000000) proactive - episode 1377 - epsilon 0.03 - reward this episode: 18384.83
# (916591/1000000) proactive - episode 1378 - epsilon 0.03 - reward this episode: 18856.41
# (917327/1000000) proactive - episode 1379 - epsilon 0.03 - reward this episode: 18715.40
# (918059/1000000) proactive - episode 1380 - epsilon 0.03 - reward this episode: 19027.85
# (918792/1000000) proactive - episode 1381 - epsilon 0.03 - reward this episode: 18644.67
# (919530/1000000) proactive - episode 1382 - epsilon 0.03 - reward this episode: 18503.96
# (920259/1000000) proactive - episode 1383 - epsilon 0.03 - reward this episode: 18900.27
# (920970/1000000) proactive - episode 1384 - epsilon 0.03 - reward this episode: 18784.67
# (921736/1000000) proactive - episode 1385 - epsilon 0.03 - reward this episode: 18944.05
# (922489/1000000) proactive - episode 1386 - epsilon 0.03 - reward this episode: 18826.58
# (923236/1000000) proactive - episode 1387 - epsilon 0.03 - reward this episode: 18742.23
# (924005/1000000) proactive - episode 1388 - epsilon 0.03 - reward this episode: 18908.29
# (924787/1000000) proactive - episode 1389 - epsilon 0.03 - reward this episode: 18710.31
# (925514/1000000) proactive - episode 1390 - epsilon 0.03 - reward this episode: 18994.12
# (926238/1000000) proactive - episode 1391 - epsilon 0.03 - reward this episode: 18958.37
# (926966/1000000) proactive - episode 1392 - epsilon 0.03 - reward this episode: 19028.35
# (927688/1000000) proactive - episode 1393 - epsilon 0.03 - reward this episode: 18846.64
# (928439/1000000) proactive - episode 1394 - epsilon 0.03 - reward this episode: 18037.13
# (929152/1000000) proactive - episode 1395 - epsilon 0.03 - reward this episode: 18613.07
# (929898/1000000) proactive - episode 1396 - epsilon 0.03 - reward this episode: 18804.82
# (930619/1000000) proactive - episode 1397 - epsilon 0.03 - reward this episode: 18931.91
# (931360/1000000) proactive - episode 1398 - epsilon 0.03 - reward this episode: 18781.32
# (932088/1000000) proactive - episode 1399 - epsilon 0.03 - reward this episode: 18907.50
# (932845/1000000) proactive - episode 1400 - epsilon 0.03 - reward this episode: 19056.73
# (933581/1000000) proactive - episode 1401 - epsilon 0.03 - reward this episode: 19151.48
# (934365/1000000) proactive - episode 1402 - epsilon 0.03 - reward this episode: 19529.59
# (935151/1000000) proactive - episode 1403 - epsilon 0.03 - reward this episode: 19340.22
# (935920/1000000) proactive - episode 1404 - epsilon 0.03 - reward this episode: 19189.73
# (936667/1000000) proactive - episode 1405 - epsilon 0.03 - reward this episode: 19343.14
# (937416/1000000) proactive - episode 1406 - epsilon 0.03 - reward this episode: 19166.72
# (938175/1000000) proactive - episode 1407 - epsilon 0.03 - reward this episode: 19022.26
# (938916/1000000) proactive - episode 1408 - epsilon 0.03 - reward this episode: 19457.60
# (939640/1000000) proactive - episode 1409 - epsilon 0.03 - reward this episode: 19280.91
# (940399/1000000) proactive - episode 1410 - epsilon 0.03 - reward this episode: 19376.50
# (941137/1000000) proactive - episode 1411 - epsilon 0.03 - reward this episode: 19134.45
# (941837/1000000) proactive - episode 1412 - epsilon 0.03 - reward this episode: 18970.50
# (942573/1000000) proactive - episode 1413 - epsilon 0.03 - reward this episode: 19448.78
# (943305/1000000) proactive - episode 1414 - epsilon 0.03 - reward this episode: 19052.05
# (944054/1000000) proactive - episode 1415 - epsilon 0.03 - reward this episode: 19530.01
# (944774/1000000) proactive - episode 1416 - epsilon 0.03 - reward this episode: 19121.17
# (945508/1000000) proactive - episode 1417 - epsilon 0.03 - reward this episode: 19327.33
# (946231/1000000) proactive - episode 1418 - epsilon 0.03 - reward this episode: 19192.16
# (946964/1000000) proactive - episode 1419 - epsilon 0.03 - reward this episode: 18891.75
# (947692/1000000) proactive - episode 1420 - epsilon 0.03 - reward this episode: 19528.28
# (948436/1000000) proactive - episode 1421 - epsilon 0.03 - reward this episode: 18755.75
# (949180/1000000) proactive - episode 1422 - epsilon 0.03 - reward this episode: 19133.53
# (949932/1000000) proactive - episode 1423 - epsilon 0.03 - reward this episode: 19411.15
# (950700/1000000) proactive - episode 1424 - epsilon 0.03 - reward this episode: 19610.11
# (951449/1000000) proactive - episode 1425 - epsilon 0.03 - reward this episode: 19512.21
# (952214/1000000) proactive - episode 1426 - epsilon 0.03 - reward this episode: 18965.91
# (952967/1000000) proactive - episode 1427 - epsilon 0.03 - reward this episode: 19246.75
# (953694/1000000) proactive - episode 1428 - epsilon 0.03 - reward this episode: 18641.67
# (954421/1000000) proactive - episode 1429 - epsilon 0.03 - reward this episode: 19512.55
# (955189/1000000) proactive - episode 1430 - epsilon 0.03 - reward this episode: 18949.63
# (955957/1000000) proactive - episode 1431 - epsilon 0.03 - reward this episode: 19421.18
# (956706/1000000) proactive - episode 1432 - epsilon 0.03 - reward this episode: 19480.40
# (957448/1000000) proactive - episode 1433 - epsilon 0.03 - reward this episode: 19239.21
# (958190/1000000) proactive - episode 1434 - epsilon 0.03 - reward this episode: 18665.37
# (958950/1000000) proactive - episode 1435 - epsilon 0.03 - reward this episode: 19013.58
# (959681/1000000) proactive - episode 1436 - epsilon 0.03 - reward this episode: 18912.97
# (960424/1000000) proactive - episode 1437 - epsilon 0.03 - reward this episode: 19285.93
# (961149/1000000) proactive - episode 1438 - epsilon 0.03 - reward this episode: 19412.45
# (961873/1000000) proactive - episode 1439 - epsilon 0.03 - reward this episode: 19483.91
# (962603/1000000) proactive - episode 1440 - epsilon 0.03 - reward this episode: 19120.09
# (963315/1000000) proactive - episode 1441 - epsilon 0.03 - reward this episode: 19111.62
# (964089/1000000) proactive - episode 1442 - epsilon 0.03 - reward this episode: 19287.08
# (964829/1000000) proactive - episode 1443 - epsilon 0.03 - reward this episode: 19291.57
# (965582/1000000) proactive - episode 1444 - epsilon 0.03 - reward this episode: 19188.63
# (966341/1000000) proactive - episode 1445 - epsilon 0.03 - reward this episode: 18860.99
# (967090/1000000) proactive - episode 1446 - epsilon 0.03 - reward this episode: 18616.51
# (967831/1000000) proactive - episode 1447 - epsilon 0.03 - reward this episode: 19301.98
# (968581/1000000) proactive - episode 1448 - epsilon 0.03 - reward this episode: 19071.59
# (969312/1000000) proactive - episode 1449 - epsilon 0.03 - reward this episode: 19418.72
# (970074/1000000) proactive - episode 1450 - epsilon 0.03 - reward this episode: 19241.68
# (970794/1000000) proactive - episode 1451 - epsilon 0.03 - reward this episode: 19262.46
# (971577/1000000) proactive - episode 1452 - epsilon 0.03 - reward this episode: 19498.34
# (972328/1000000) proactive - episode 1453 - epsilon 0.03 - reward this episode: 19251.80
# (973057/1000000) proactive - episode 1454 - epsilon 0.03 - reward this episode: 19199.37
# (973822/1000000) proactive - episode 1455 - epsilon 0.03 - reward this episode: 18731.75
# (974564/1000000) proactive - episode 1456 - epsilon 0.03 - reward this episode: 18998.34
# (975285/1000000) proactive - episode 1457 - epsilon 0.03 - reward this episode: 19314.83
# (976047/1000000) proactive - episode 1458 - epsilon 0.03 - reward this episode: 19469.81
# (976799/1000000) proactive - episode 1459 - epsilon 0.03 - reward this episode: 19263.08
# (977558/1000000) proactive - episode 1460 - epsilon 0.03 - reward this episode: 19351.93
# (978301/1000000) proactive - episode 1461 - epsilon 0.03 - reward this episode: 19554.87
# (979064/1000000) proactive - episode 1462 - epsilon 0.03 - reward this episode: 19097.63
# (979818/1000000) proactive - episode 1463 - epsilon 0.03 - reward this episode: 19342.20
# (980579/1000000) proactive - episode 1464 - epsilon 0.03 - reward this episode: 19141.19
# (981333/1000000) proactive - episode 1465 - epsilon 0.03 - reward this episode: 19130.14
# (982076/1000000) proactive - episode 1466 - epsilon 0.03 - reward this episode: 19428.44
# (982804/1000000) proactive - episode 1467 - epsilon 0.03 - reward this episode: 18767.10
# (983547/1000000) proactive - episode 1468 - epsilon 0.03 - reward this episode: 19308.26
# (984308/1000000) proactive - episode 1469 - epsilon 0.03 - reward this episode: 19319.46
# (985054/1000000) proactive - episode 1470 - epsilon 0.03 - reward this episode: 19447.41
# (985772/1000000) proactive - episode 1471 - epsilon 0.03 - reward this episode: 19489.43
# (986521/1000000) proactive - episode 1472 - epsilon 0.03 - reward this episode: 18838.96
# (987298/1000000) proactive - episode 1473 - epsilon 0.03 - reward this episode: 18826.84
# (988017/1000000) proactive - episode 1474 - epsilon 0.03 - reward this episode: 19380.00
# (988752/1000000) proactive - episode 1475 - epsilon 0.03 - reward this episode: 18580.97
# (989494/1000000) proactive - episode 1476 - epsilon 0.03 - reward this episode: 19109.52
# (990235/1000000) proactive - episode 1477 - epsilon 0.03 - reward this episode: 19466.52
# (990974/1000000) proactive - episode 1478 - epsilon 0.03 - reward this episode: 19122.45
# (991729/1000000) proactive - episode 1479 - epsilon 0.03 - reward this episode: 19514.11
# (992483/1000000) proactive - episode 1480 - epsilon 0.03 - reward this episode: 19039.61
# (993236/1000000) proactive - episode 1481 - epsilon 0.03 - reward this episode: 19332.93
# (993983/1000000) proactive - episode 1482 - epsilon 0.03 - reward this episode: 18854.87
# (994721/1000000) proactive - episode 1483 - epsilon 0.03 - reward this episode: 19191.10
# (995444/1000000) proactive - episode 1484 - epsilon 0.03 - reward this episode: 18980.03
# (996182/1000000) proactive - episode 1485 - epsilon 0.03 - reward this episode: 19535.53
# (996925/1000000) proactive - episode 1486 - epsilon 0.03 - reward this episode: 19419.31
# (997650/1000000) proactive - episode 1487 - epsilon 0.03 - reward this episode: 18946.62
# (998422/1000000) proactive - episode 1488 - epsilon 0.03 - reward this episode: 18581.29
# (999158/1000000) proactive - episode 1489 - epsilon 0.03 - reward this episode: 18969.64
# (999857/1000000) proactive - episode 1490 - epsilon 0.03 - reward this episode: 19364.80
# (1000573/1000000) proactive - episode 1491 - epsilon 0.03 - reward this episode: 19285.10
# Marked logs_id 0758 as finished in ../logs/ids.json
# Training log finalized and summary added to ../logs/training/training_0758.json

# %%
num_seeds_myopic = all_myopic_runs.shape[0]
num_episodes_myopic = all_myopic_runs.shape[1] if num_seeds_myopic > 0 else 0
num_seeds_proactive = all_proactive_runs.shape[0]
num_episodes_proactive = all_proactive_runs.shape[1] if num_seeds_proactive > 0 else 0

for i in range(num_seeds_myopic):
    total_steps_myopic = all_myopic_steps_runs[i].sum()
    print(f"For seed index {i}, Myopic: finished {num_episodes_myopic} episodes, performed {total_steps_myopic} timesteps.")

for i in range(num_seeds_proactive):
    total_steps_proactive = all_proactive_steps_runs[i].sum()
    print(f"For seed index {i}, Proactive: finished {num_episodes_proactive} episodes, performed {total_steps_proactive} timesteps.")
# Out:
# For seed index 0, Myopic: finished 1409 episodes, performed 659576492 timesteps.
# For seed index 1, Myopic: finished 1409 episodes, performed 668628468 timesteps.
# For seed index 2, Myopic: finished 1409 episodes, performed 644610618 timesteps.
# For seed index 0, Proactive: finished 1487 episodes, performed 697942677 timesteps.
# For seed index 1, Proactive: finished 1487 episodes, performed 707051739 timesteps.
# For seed index 2, Proactive: finished 1487 episodes, performed 709625370 timesteps.

# %%
# Define a smoothing function (optional)
def smooth(data, window=10):
    if window > 1 and len(data) >= window:
        return np.convolve(data, np.ones(window)/window, mode='valid')
    return data

# Apply smoothing if desired
smooth_window = 4
myopic_mean_sm = smooth(myopic_mean, smooth_window)
myopic_std_sm = smooth(myopic_std, smooth_window)
myopic_steps_sm = myopic_steps_mean[:len(myopic_mean_sm)]

proactive_mean_sm = smooth(proactive_mean, smooth_window)
proactive_std_sm = smooth(proactive_std, smooth_window)
proactive_steps_sm = proactive_steps_mean[:len(proactive_mean_sm)]

# Plotting the results
plt.figure(figsize=(12,6))
plt.plot(myopic_steps_sm, myopic_mean_sm, label="Myopic", color='blue')
plt.fill_between(myopic_steps_sm, 
                 myopic_mean_sm - myopic_std_sm, 
                 myopic_mean_sm + myopic_std_sm, 
                 alpha=0.2, color='blue')

plt.plot(proactive_steps_sm, proactive_mean_sm, label="Proactive", color='orange')
plt.fill_between(proactive_steps_sm, 
                 proactive_mean_sm - proactive_std_sm, 
                 proactive_mean_sm + proactive_std_sm, 
                 alpha=0.2, color='orange')

plt.xlabel("Environment Steps (Frames)")
plt.ylabel("Episode Reward")
plt.title(f"Averaged Episode Rewards over {len(SEEDS)} Seeds (DQN, {stripped_scenario_folder})")
plt.legend(frameon=False)
plt.grid(True)


results_dir = "./results"
os.makedirs(results_dir, exist_ok=True)

plot_file = os.path.join(results_dir, f"averaged_rewards_over_steps_{stripped_scenario_folder}.png")
plt.savefig(plot_file)
plt.show()

print(f"Averaged reward vs steps plot saved to {plot_file}")
# Out:
# Averaged reward vs steps plot saved to ./results/averaged_rewards_over_steps_3ac-100-mixed.png

# %%
# save the raw rewards
