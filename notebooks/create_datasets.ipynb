# %%
from scripts.create_data import create_data_scenario
import random
from datetime import datetime

# Define hyperparameters for the scenarios
num_scenarios = 1000
aircraft_range = (3,3)  # Range for all scenarios
amount_aircraft_disrupted = 1  # For all scenarios
average_flights_per_aircraft = 4  # For all scenarios

template_folder = "../data/Template"
data_root_folder = "../data/Training/1k-3ac-12f-1dis-F"



airports = ['AMS', 'CDG', 'FRA', 'LHR', 'MAD', 'MUC', 'ORY', 'TXL', 'VIE', 'ZRH', 'BCN', 'BRU', 'CPH', 'DUB', 'IST']
aircraft_types = [
    {'Model': 'B737', 'Family': 'Boeing', 'Config': '10/20/160', 'Dist': 5000, 'Cost/h': 3000.0, 'TurnRound': 75, 'Transit': 50, 'Orig': ['CDG'], 'Maint': ['NULL']},
    {'Model': 'A320', 'Family': 'Airbus', 'Config': '0/0/123', 'Dist': 5000, 'Cost/h': 1800.0, 'TurnRound': 30, 'Transit': 30, 'Orig': ['CFE'], 'Maint': ['NULL']}
]

config_dict = {
    'DelayCosts': [{'Cabin': 'Economy', 'Type': 'ShortHaul', 'Cost': 100.0}],
    'CancellationCostsOutbound': [{'Cabin': 'Economy', 'Type': 'ShortHaul', 'Cost': 500.0}],
    'CancellationCostsInbound': [{'Cabin': 'Economy', 'Type': 'ShortHaul', 'Cost': 600.0}],
    'DowngradingCosts': [{'FromCabin': 'Business', 'ToCabin': 'Economy', 'Type': 'ShortHaul', 'Cost': 200.0}],
    'PenaltyCosts': [200, 300, 400],
    'Weights': [1.0, 0.5, 0.2],
}

# Function to generate scenarios
for i in range(1, num_scenarios + 1):
    scenario_name = f'Scenario_{i:02d}'  # Dynamically generate scenario names
    recovery_start_date = datetime(2024, 9, random.randint(1, 30)).strftime('%d/%m/%y')
    recovery_start_time = f'{random.randint(5, 7)}:00'
    recovery_end_date = recovery_start_date
    recovery_end_time = f'{random.randint(20, 23)}:{random.choice(["00", "30"])}'

    # Call the function for each scenario
    create_data_scenario(
        scenario_name=scenario_name,
        template_folder=template_folder,
        data_root_folder=data_root_folder,
        aircraft_types=aircraft_types,
        total_aircraft_range=aircraft_range,  # Use the defined aircraft range
        amount_aircraft_disrupted=amount_aircraft_disrupted,  # Use the defined disrupted amount
        min_delta_start_unavailability=0,
        max_delta_start_unavailability=120,
        min_period_unavailability=120,
        max_period_unavailability=1020,
        average_flights_per_aircraft=average_flights_per_aircraft,  # Use the defined average flights per aircraft
        std_dev_flights_per_aircraft=1,  # Set a constant standard deviation
        airports=airports,
        config_dict=config_dict,
        recovery_start_date=recovery_start_date,
        recovery_start_time=recovery_start_time,
        recovery_end_date=recovery_end_date,
        recovery_end_time=recovery_end_time,
        clear_one_random_aircraft=False,
    )
# Out:
# Data creation for scenario Scenario_01 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_02 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_03 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_04 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_05 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_06 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_07 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_08 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_09 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_10 completed with 3 aircraft and 12 flights.
# Data creation for scenario Scenario_11 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_12 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_13 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_14 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_15 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_16 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_17 completed with 3 aircraft and 12 flights.
# Data creation for scenario Scenario_18 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_19 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_20 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_21 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_22 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_23 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_24 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_25 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_26 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_27 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_28 completed with 3 aircraft and 3 flights.
# Data creation for scenario Scenario_29 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_30 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_31 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_32 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_33 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_34 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_35 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_36 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_37 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_38 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_39 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_40 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_41 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_42 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_43 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_44 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_45 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_46 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_47 completed with 3 aircraft and 12 flights.
# Data creation for scenario Scenario_48 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_49 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_50 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_51 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_52 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_53 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_54 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_55 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_56 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_57 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_58 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_59 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_60 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_61 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_62 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_63 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_64 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_65 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_66 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_67 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_68 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_69 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_70 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_71 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_72 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_73 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_74 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_75 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_76 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_77 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_78 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_79 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_80 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_81 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_82 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_83 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_84 completed with 3 aircraft and 12 flights.
# Data creation for scenario Scenario_85 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_86 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_87 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_88 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_89 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_90 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario
completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_479 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_480 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_481 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_482 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_483 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_484 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_485 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_486 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_487 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_488 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_489 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_490 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_491 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_492 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_493 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_494 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_495 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_496 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_497 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_498 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_499 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_500 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_501 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_502 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_503 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_504 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_505 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_506 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_507 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_508 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_509 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_510 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_511 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_512 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_513 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_514 completed with 3 aircraft and 3 flights.
# Data creation for scenario Scenario_515 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_516 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_517 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_518 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_519 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_520 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_521 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_522 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_523 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_524 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_525 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_526 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_527 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_528 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_529 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_530 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_531 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_532 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_533 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_534 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_535 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_536 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_537 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_538 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_539 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_540 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_541 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_542 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_543 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_544 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_545 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_546 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_547 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_548 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_549 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_550 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_551 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_552 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_553 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_554 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_555 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_556 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_557 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_558 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_559 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_560 completed with 3 aircraft and 2 flights.
# Data creation for scenario Scenario_561 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_562 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_563 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_564 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_565 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_566 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_567 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_568 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_569 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_570 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_571 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_572 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_573 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_574 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_575 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_576 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_577 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_578 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_579 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_580 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_581 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_582 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_583 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_584 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_585 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_586 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_587 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_588 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_589 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_590 completed with 3 aircraft and 10 flights.
# ...
# Data creation for scenario Scenario_805 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_806 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_807 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_808 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_809 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_810 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_811 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_812 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_813 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_814 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_815 completed with 3 aircraft and 5 flights.
# Data creation for scenario Scenario_816 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_817 completed with 3 aircraft and 12 flights.
# Data creation for scenario Scenario_818 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_819 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_820 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_821 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_822 completed with 3 aircraft and 1 flights.
# Data creation for scenario Scenario_823 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_824 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_825 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_826 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_827 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_828 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_829 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_830 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_831 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_832 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_833 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_834 completed with 3 aircraft and 12 flights.
# Data creation for scenario Scenario_835 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_836 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_837 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_838 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_839 completed with 3 aircraft and 5 flights.
# Data creation for scenario Scenario_840 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_841 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_842 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_843 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_844 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_845 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_846 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_847 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_848 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_849 completed with 3 aircraft and 3 flights.
# Data creation for scenario Scenario_850 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_851 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_852 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_853 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_854 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_855 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_856 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_857 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_858 completed with 3 aircraft and 5 flights.
# Data creation for scenario Scenario_859 completed with 3 aircraft and 12 flights.
# Data creation for scenario Scenario_860 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_861 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_862 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_863 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_864 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_865 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_866 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_867 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_868 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_869 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_870 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_871 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_872 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_873 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_874 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_875 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_876 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_877 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_878 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_879 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_880 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_881 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_882 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_883 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_884 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_885 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_886 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_887 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_888 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_889 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_890 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_891 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_892 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_893 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_894 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_895 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_896 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_897 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_898 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_899 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_900 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_901 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_902 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_903 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_904 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_905 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_906 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_907 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_908 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_909 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_910 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_911 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_912 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_913 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_914 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_915 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_916 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_917 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_918 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_919 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_920 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_921 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_922 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_923 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_924 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_925 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_926 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_927 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_928 completed with 3 aircraft and 12 flights.
# Data creation for scenario Scenario_929 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_930 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_931 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_932 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_933 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_934 completed with 3 aircraft and 5 flights.
# Data creation for scenario Scenario_935 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_936 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_937 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_938 completed with 3 aircraft and 5 flights.
# Data creation for scenario Scenario_939 completed with 3 aircraft and 4 flights.
# Data creation for scenario Scenario_940 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_941 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_942 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_943 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_944 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_945 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_946 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_947 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_948 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_949 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_950 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_951 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_952 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_953 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_954 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_955 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_956 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_957 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_958 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_959 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_960 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_961 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_962 completed with 3 aircraft and 12 flights.
# Data creation for scenario Scenario_963 completed with 3 aircraft and 3 flights.
# Data creation for scenario Scenario_964 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_965 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_966 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_967 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_968 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_969 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_970 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_971 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_972 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_973 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_974 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_975 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_976 completed with 3 aircraft and 5 flights.
# Data creation for scenario Scenario_977 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_978 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_979 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_980 completed with 3 aircraft and 3 flights.
# Data creation for scenario Scenario_981 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_982 completed with 3 aircraft and 5 flights.
# Data creation for scenario Scenario_983 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_984 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_985 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_986 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_987 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_988 completed with 3 aircraft and 6 flights.
# Data creation for scenario Scenario_989 completed with 3 aircraft and 3 flights.
# Data creation for scenario Scenario_990 completed with 3 aircraft and 7 flights.
# Data creation for scenario Scenario_991 completed with 3 aircraft and 8 flights.
# Data creation for scenario Scenario_992 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_993 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_994 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_995 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_996 completed with 3 aircraft and 11 flights.
# Data creation for scenario Scenario_997 completed with 3 aircraft and 9 flights.
# Data creation for scenario Scenario_998 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_999 completed with 3 aircraft and 10 flights.
# Data creation for scenario Scenario_1000 completed with 3 aircraft and 9 flights.
