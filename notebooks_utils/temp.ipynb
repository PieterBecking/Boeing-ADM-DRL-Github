# %% [markdown]
# ### Import packages

# %%
import os
import sys
import warnings

import datetime
import math
import numpy as np
import pandas as pd
import platform
import re
import subprocess
import torch as th

import os
import pickle

import gymnasium as gym
import matplotlib.pyplot as plt

from datetime import datetime
from scripts.utils import *
from scripts.visualizations import *
from src.config import *
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.logger import configure  # Import the configure function
from stable_baselines3.common.utils import polyak_update, set_random_seed
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv

from scripts.utils import NumpyEncoder
from scripts.logger import *

import json

# %% [markdown]
# ### Hyperparameters

# %%
# Constants and Training Settings
LEARNING_RATE = 0.001
GAMMA = 0.99
BUFFER_SIZE = 100000
BATCH_SIZE = 256
TARGET_UPDATE_INTERVAL = 100
MAX_TIMESTEPS = 50000

NEURAL_NET_STRUCTURE = dict(net_arch=[256, 512, 512, 256])
LEARNING_STARTS = 1000
TRAIN_FREQ = 4

EPSILON_START = 1.0
EPSILON_MIN = 0.025
PERCENTAGE_MIN = 90
# EXPLORATION_PHASE = 1000


EPSILON_TYPE = "exponential"
# EPSILON_TYPE = "linear"


if EPSILON_TYPE == "linear":
    EPSILON_MIN = 0

N_EPISODES = 1
cross_val_flag = True
CROSS_VAL_INTERVAL = N_EPISODES/50

# TRAINING_FOLDERS_PATH = "../data/Locked/alpha/"
TRAINING_FOLDERS_PATH = "../data/Training/3ac-1000/"
# TRAINING_FOLDERS_PATH = "../data/Training/temp/"
TESTING_FOLDERS_PATH = "../data/Training/3ac-100/"


# extract number of scenarios in training and testing folders
num_scenarios_training = len(os.listdir(TRAINING_FOLDERS_PATH))
exploration_phase_percentage = 5
num_timesteps_per_scenario = 5

total_timesteps = N_EPISODES * num_scenarios_training * num_timesteps_per_scenario
EXPLORATION_PHASE = int(exploration_phase_percentage / 100 * total_timesteps)
print(f"Exploration phase: {EXPLORATION_PHASE} timesteps")

print(f"Total timesteps: {total_timesteps}")
# Out:
# Exploration phase: 250 timesteps
# Total timesteps: 5000

# %% [markdown]
# ## ESTIMATED VALUES

# %%
import numpy as np
import matplotlib.pyplot as plt
from src.environment import AircraftDisruptionEnv

print("Calculating...")
# Calculate total timesteps 10 times and take the average
total_timesteps_list = [calculate_total_training_timesteps(TRAINING_FOLDERS_PATH, N_EPISODES) for _ in range(1)]
estimated_total_timesteps = sum(total_timesteps_list) / len(total_timesteps_list)

print("Estimated total timesteps: ", estimated_total_timesteps)

# Calculate the decay rate or linear rate
EPSILON_DECAY_RATE = calculate_epsilon_decay_rate(
    estimated_total_timesteps,
    EPSILON_START,
    EPSILON_MIN,
    PERCENTAGE_MIN,
    EPSILON_TYPE
)

print("")
print("Testing...")
simulate_and_plot_epsilon_decay(
    EPSILON_START, EPSILON_MIN, EPSILON_DECAY_RATE, estimated_total_timesteps, EPSILON_TYPE
)

EPSILON_DECAY_RATE = EPSILON_DECAY_RATE
print("EPSILON DECAY RATE: ", EPSILON_DECAY_RATE)
# Out:
# Calculating...
# Estimated total timesteps:  6330.0
# Calculated EPSILON_DECAY_RATE: 0.0006475126301762219
#
# Testing...
# Epsilon reaches its minimum value at 89.97% of total timesteps.
# EPSILON DECAY RATE:  0.0006475126301762219

# %%
# Initialize device
device = initialize_device()

# Check device capabilities
check_device_capabilities()

# Get device-specific information
device_info = get_device_info(device)
print(f"Device info: {device_info}")

# Verify training folders and gather training data
training_folders = verify_training_folders(TRAINING_FOLDERS_PATH)
# print(f"Training folders: {training_folders}")

# Calculate training days and model naming
num_days_trained_on = calculate_training_days(N_EPISODES, training_folders)
print(f"Training on {num_days_trained_on} days of data "
        f"({N_EPISODES} episodes of {len(training_folders)} scenarios)")

formatted_days = format_days(num_days_trained_on)
MODEL_SAVE_PATH = f'../trained_models/dqn/'

# myopic_model_name = "myopic_3ac"
# proactive_model_name = "proactive_3ac"
# myopic_model_version = get_model_version(myopic_model_name, myopic_proactive="myopic", drl_type="dqn")
# proactive_model_version = get_model_version(proactive_model_name, myopic_proactive="proactive", drl_type="dqn")

# myopic_model_path = f"{MODEL_SAVE_PATH}{myopic_model_name}-{myopic_model_version}.zip"
# proactive_model_path = f"{MODEL_SAVE_PATH}{proactive_model_name}-{proactive_model_version}.zip"
# print(f"Models will be saved to:")
# print(f"   {myopic_model_path}")
# print(f"   {proactive_model_path}")

# Create results directory
results_dir = create_results_directory(append_to_name='dqn')
print(f"Results directory created at: {results_dir}")
# Out:
# Using device: mps
# CUDA available: False
# Number of GPUs available: 0
# cuDNN enabled: True
# Device: mps
# Using MacBook M1
# Device info: {'device_type': 'MacBook M1'}
# Training on 1000 days of data (1 episodes of 1000 scenarios)
# Results directory created at: ../results/dqn/20241203-19-29

# %% [markdown]
# # Reinforcement Learning

# %% [markdown]
# ## Training

# %%
from scripts.logger import create_new_id, get_config_variables
import src.config as config

# Training both agents: myopic and proactive

def train_dqn_agent(env_type):
    log_data = {}  # Main dictionary to store all logs

    config_variables = get_config_variables(config)

    # Generate unique ID for training
    training_id = create_new_id("training")
    runtime_start_in_seconds = time.time()

    if env_type == "myopic":
        model_path = f"../trained_models/dqn/myopic-{training_id}.zip"
        print(f"Models will be saved to: {model_path}")
        model_path_and_name = model_path
    elif env_type == "proactive":
        model_path = f"../trained_models/dqn/proactive-{training_id}.zip"
        print(f"Models will be saved to: {model_path}")
        model_path_and_name = model_path
    # Metadata for logging
    training_metadata = {
        "myopic_or_proactive": env_type,
        "model_type": "dqn",
        "training_id": training_id,
        "MODEL_SAVE_PATH": model_path,
        "N_EPISODES": N_EPISODES,
        "num_scenarios_training": num_scenarios_training,
        "results_dir": results_dir,
        "CROSS_VAL_FLAG": cross_val_flag,
        "CROSS_VAL_INTERVAL": CROSS_VAL_INTERVAL,
        **config_variables,
        "LEARNING_RATE": LEARNING_RATE,
        "GAMMA": GAMMA,
        "BUFFER_SIZE": BUFFER_SIZE,
        "BATCH_SIZE": BATCH_SIZE,
        "TARGET_UPDATE_INTERVAL": TARGET_UPDATE_INTERVAL,
        "EPSILON_START": EPSILON_START,
        "EPSILON_MIN": EPSILON_MIN,
        "EPSILON_DECAY_RATE": EPSILON_DECAY_RATE,
        "EXPLORATION_PHASE": EXPLORATION_PHASE,
        "MAX_TIMESTEPS": MAX_TIMESTEPS,
        "LEARNING_STARTS": LEARNING_STARTS,
        "TRAIN_FREQ": TRAIN_FREQ,
        "NEURAL_NET_STRUCTURE": NEURAL_NET_STRUCTURE,
        "device_info": str(get_device_info(device)),
        "TRAINING_FOLDERS_PATH": TRAINING_FOLDERS_PATH,
        "TESTING_FOLDERS_PATH": TESTING_FOLDERS_PATH,
        "runtime_start": datetime.utcnow().isoformat() + "Z",
        "runtime_start_in_seconds": runtime_start_in_seconds,
    }

    log_data['metadata'] = training_metadata
    log_data['episodes'] = {}
    log_data['cross_validation'] = {}

    best_reward_avg = float('-inf')
    # Initialize variables
    rewards = {}
    good_rewards = {}
    test_rewards = []
    epsilon_values = []
    total_timesteps = 0  # Added to track total timesteps
    consecutive_drops = 0  # Track consecutive performance drops
    best_test_reward = float('-inf')  # Track best test performance
    action_sequences = {
        os.path.join(TRAINING_FOLDERS_PATH, folder): {
            "best_actions": [],
            "best_reward": float('-inf'),
            "worst_actions": [],
            "worst_reward": float('inf')
        }
        for folder in training_folders
    }
    
    def cross_validate_on_test_data(model, current_episode, log_data):
        cross_val_data = {
            "episode": current_episode,
            "scenarios": [],
            "avg_test_reward": 0,
        }

        test_scenario_folders = [
            os.path.join(TESTING_FOLDERS_PATH, folder)
            for folder in os.listdir(TESTING_FOLDERS_PATH)
            if os.path.isdir(os.path.join(TESTING_FOLDERS_PATH, folder))
        ]
        total_test_reward = 0
        for test_scenario_folder in test_scenario_folders:
            scenario_data = {
                "scenario_folder": test_scenario_folder,
                "total_reward": 0,
                "steps": []
            }
            # Load data
            data_dict = load_scenario_data(test_scenario_folder)
            aircraft_dict = data_dict['aircraft']
            flights_dict = data_dict['flights']
            rotations_dict = data_dict['rotations']
            alt_aircraft_dict = data_dict['alt_aircraft']
            config_dict = data_dict['config']

            # Update the environment with the new scenario (by reinitializing it)
            from src.environment import AircraftDisruptionEnv
            env = AircraftDisruptionEnv(
                aircraft_dict,
                flights_dict,
                rotations_dict,
                alt_aircraft_dict,
                config_dict,
                env_type=env_type
            )
            model.set_env(env)  # Update the model's environment with the new instance

            # Evaluate the model on the test scenario without training
            obs, _ = env.reset()

            done_flag = False
            total_reward = 0
            timesteps = 0

            while not done_flag and timesteps < MAX_TIMESTEPS:
                # Get the action mask from the environment
                action_mask = obs['action_mask']

                # Convert observation to float32
                obs = {key: np.array(value, dtype=np.float32) for key, value in obs.items()}

                # Preprocess observation and get Q-values
                obs_tensor = model.policy.obs_to_tensor(obs)[0]
                q_values = model.policy.q_net(obs_tensor).detach().cpu().numpy().squeeze()

                # Apply the action mask (set invalid actions to -np.inf)
                masked_q_values = q_values.copy()
                masked_q_values[action_mask == 0] = -np.inf

                # Select the action with the highest masked Q-value
                action = np.argmax(masked_q_values)

                # Take the selected action in the environment
                result = env.step(action)

                # Unpack the result
                obs_next, reward, terminated, truncated, info = result

                done_flag = terminated or truncated

                # Accumulate the reward
                total_reward += reward

                # Update the current observation
                obs = obs_next

                scenario_data["steps"].append({
                    "step_number": timesteps + 1,
                    "action": action,
                    "flight_action": env.map_index_to_action(action)[0],
                    "aircraft_action": env.map_index_to_action(action)[1],
                    "reward": reward,
                    "total_timestep": total_timesteps,
                    "time_in_scenario": timesteps,
                    "epsilon": "1.0 at cross-validation",
                    "action_reason": "exploitation at cross-validation",
                    "action_mask": action_mask,
                    "action_mask_sum": np.sum(action_mask),
                    "len_action_mask": len(action_mask),
                    "masked_q_values": masked_q_values,
                    "q_values": q_values,
                    "info_after_step": env.info_after_step,
                    # Assuming impact_of_action is defined elsewhere
                    # "impact_of_action": impact_of_action,
                })

                timesteps += 1
                if done_flag:
                    break

            total_test_reward += total_reward

            scenario_data["total_reward"] = total_reward
            cross_val_data["scenarios"].append(scenario_data)

        # Compute average test reward
        avg_test_reward = total_test_reward / len(test_scenario_folders)
        cross_val_data["avg_test_reward"] = avg_test_reward
        test_rewards.append((current_episode, avg_test_reward))
        print(f"cross-val done at episode {current_episode}")

        # Store cross-validation data in log_data
        log_data['cross_validation'][current_episode] = cross_val_data

        return avg_test_reward  # Return the average test reward

    # List all the scenario folders in Data/Training
    scenario_folders = [
        os.path.join(TRAINING_FOLDERS_PATH, folder)
        for folder in os.listdir(TRAINING_FOLDERS_PATH)
        if os.path.isdir(os.path.join(TRAINING_FOLDERS_PATH, folder))
    ]

    epsilon = EPSILON_START
    total_timesteps = 0  # Reset total_timesteps for each agent

    # Initialize the DQN
    dummy_scenario_folder = scenario_folders[0]
    data_dict = load_scenario_data(dummy_scenario_folder)
    aircraft_dict = data_dict['aircraft']
    flights_dict = data_dict['flights']
    rotations_dict = data_dict['rotations']
    alt_aircraft_dict = data_dict['alt_aircraft']
    config_dict = data_dict['config']

    from src.environment import AircraftDisruptionEnv

    env = AircraftDisruptionEnv(
        aircraft_dict,
        flights_dict,
        rotations_dict,
        alt_aircraft_dict,
        config_dict,
        env_type=env_type
    )

    model = DQN(
        policy='MultiInputPolicy',
        env=env,
        learning_rate=LEARNING_RATE,
        gamma=GAMMA,
        buffer_size=BUFFER_SIZE,
        learning_starts=LEARNING_STARTS,
        batch_size=BATCH_SIZE,
        target_update_interval=TARGET_UPDATE_INTERVAL,
        verbose=0,
        policy_kwargs=NEURAL_NET_STRUCTURE,
        device=device
    )

    logger = configure()
    model._logger = logger

    # Training loop over the number of episodes
    for episode in range(N_EPISODES):
        # create a dictionary in the rewards dictionary for the current episode
        rewards[episode] = {}
        # create a dictionary in the action_sequences dictionary for the current episode
        action_sequences[episode] = {}
        # Log the start of the episode
        episode_data = {
            "episode_number": episode + 1,
            "epsilon_start": epsilon,
            "scenarios": {},
        }
        # Cycle through all the scenario folders
        for scenario_folder in scenario_folders:
            scenario_data = {
                "scenario_folder": scenario_folder,
                "steps": [],
                "total_reward": 0,
            }
            # create a dictionary in the rewards dictionary for the current scenario
            rewards[episode][scenario_folder] = {}
            # create a dictionary in the action_sequences dictionary for the current scenario
            action_sequences[episode][scenario_folder] = []
            best_reward = float('-inf')
            best_action_sequence = []
            # Load the data for the current scenario
            data_dict = load_scenario_data(scenario_folder)
            aircraft_dict = data_dict['aircraft']
            flights_dict = data_dict['flights']
            rotations_dict = data_dict['rotations']
            alt_aircraft_dict = data_dict['alt_aircraft']
            config_dict = data_dict['config']

            # Update the environment with the new scenario (by reinitializing it)
            env = AircraftDisruptionEnv(
                aircraft_dict,
                flights_dict,
                rotations_dict,
                alt_aircraft_dict,
                config_dict,
                env_type=env_type
            )
            model.set_env(env)  # Update the model's environment with the new instance

            # Reset the environment
            obs, _ = env.reset()  # Extract the observation (obs) and ignore the info (_)

            done_flag = False
            total_reward = 0
            timesteps = 0
            action_sequence = []

            print(f"Current scenario: {scenario_folder}")

            while not done_flag and timesteps < MAX_TIMESTEPS:

                # Get cancelled flights
                num_cancelled_flights_before_step = len(env.cancelled_flights)  # Returns a set of flight IDs

                # Get delayed flights and their delays (in minutes)
                num_delayed_flights_before_step = len(env.environment_delayed_flights)  # Returns a dict of {flight_id: delay_minutes}

                # Get flights that have already been penalized for delays
                num_penalized_delays_before_step = len(env.penalized_delays)  # Returns a dict of {flight_id: delay_minutes}

                # Get flights that have already been penalized for being cancelled
                num_penalized_cancelled_before_step = len(env.penalized_cancelled_flights)  # Returns a set of flight IDs

                model.exploration_rate = epsilon

                # Get the action mask from the environment
                action_mask = obs['action_mask']

                # Convert observation to float32
                obs = {key: np.array(value, dtype=np.float32) for key, value in obs.items()}

                # Preprocess observation and get Q-values
                obs_tensor = model.policy.obs_to_tensor(obs)[0]
                q_values = model.policy.q_net(obs_tensor).detach().cpu().numpy().squeeze()

                # Apply the action mask (set invalid actions to -np.inf)
                masked_q_values = q_values.copy()
                masked_q_values[action_mask == 0] = -np.inf

                current_seed = int(time.time() * 1e9) % (2**32 - 1)
                # print(current_seed)
                np.random.seed(current_seed)
                
                brute_force_flag = False
                # Select an action
                action_reason = "None"
                if np.random.rand() < 12 or brute_force_flag:
                    # Exploration: choose a random valid action
                    valid_actions = np.where(action_mask == 1)[0]
                    action = np.random.choice(valid_actions)
                    action_reason = "exploration"
                else:
                    # Exploitation: choose the action with the highest masked Q-value
                    action = np.argmax(masked_q_values)
                    action_reason = "exploitation"

                # Take the selected action in the environment
                result = env.step(action)

                # Unpack the result (5 values)
                obs_next, reward, terminated, truncated, info = result

                print(f"    Episode {episode}, Reward: {reward}")

                # Store the reward for the current timestep
                rewards[episode][scenario_folder][timesteps] = reward
                action_sequences[episode][scenario_folder].append(action)

                # Combine the terminated and truncated flags into a single done flag
                done_flag = terminated or truncated

                # Store the action
                action_sequence.append(action)

                # Add the transition to the replay buffer
                model.replay_buffer.add(
                    obs=obs,
                    next_obs=obs_next,
                    action=action,
                    reward=reward,
                    done=done_flag,
                    infos=[info]
                )

                # Update the current observation
                obs = obs_next

                if total_timesteps < EXPLORATION_PHASE:
                    # Hold epsilon at 1 during the exploration phase
                    epsilon = EPSILON_START
                else:
                    # Update epsilon after the exploration phase
                    epsilon = max(EPSILON_MIN, epsilon * (1 - EPSILON_DECAY_RATE))
                    
                epsilon_values.append((episode + 1, epsilon))

                timesteps += 1
                total_timesteps += 1  # Update total_timesteps

                # Training
                if total_timesteps > model.learning_starts and total_timesteps % TRAIN_FREQ == 0:
                    # Perform a training step
                    model.train(gradient_steps=1, batch_size=BATCH_SIZE)

                # Update target network
                if total_timesteps % model.target_update_interval == 0:
                    polyak_update(model.q_net.parameters(), model.q_net_target.parameters(), model.tau)
                    # Copy batch norm stats
                    polyak_update(model.batch_norm_stats, model.batch_norm_stats_target, 1.0)

                num_cancelled_flights_after_step = len(env.cancelled_flights)
                num_delayed_flights_after_step = len(env.environment_delayed_flights)
                num_penalized_delays_after_step = len(env.penalized_delays)
                num_penalized_cancelled_after_step = len(env.penalized_cancelled_flights)

                impact_of_action = {
                    "num_cancelled_flights": num_cancelled_flights_after_step - num_cancelled_flights_before_step,
                    "num_delayed_flights": num_delayed_flights_after_step - num_delayed_flights_before_step,
                    "num_penalized_delays": num_penalized_delays_after_step - num_penalized_delays_before_step,
                    "num_penalized_cancelled": num_penalized_cancelled_after_step - num_penalized_cancelled_before_step,
                }

                scenario_data["steps"].append({
                    "step_number": timesteps,
                    "action": action,
                    "flight_action": env.map_index_to_action(action)[0],
                    "aircraft_action": env.map_index_to_action(action)[1],
                    "reward": reward,
                    "total_timestep": total_timesteps,
                    "time_in_scenario": timesteps,
                    "epsilon": epsilon,
                    "action_reason": action_reason,
                    "impact_of_action": impact_of_action,
                    "done_flag": done_flag,
                    "action_mask_sum": np.sum(action_mask),
                    "len_action_mask": len(action_mask),
                    "info_after_step": env.info_after_step,
                    "masked_q_values": masked_q_values,
                    "q_values": q_values,
                    "action_mask": action_mask,
                })
                
                # Check if the episode is done
                if done_flag:
                    break
            
            total_reward = 0
            for _, reward in rewards[episode][scenario_folder].items():
                total_reward += reward
            # Store the total reward for the episode with the scenario specified
            rewards[episode][scenario_folder] = total_reward

            # save the action sequence
            action_sequences[episode][scenario_folder] = action_sequence

            # Summarize scenario
            scenario_data["total_reward"] = total_reward
            episode_data["scenarios"][scenario_folder] = scenario_data

        # Perform cross-validation at specified intervals
        if cross_val_flag:
            # Initialize best_test_reward and current_test_reward at first cross validation
            if (episode + 1) % CROSS_VAL_INTERVAL == 0:
                current_test_reward = cross_validate_on_test_data(model, episode + 1, log_data)
                if not hasattr(train_dqn_agent, 'best_test_reward'):
                    train_dqn_agent.best_test_reward = current_test_reward
                best_test_reward = train_dqn_agent.best_test_reward
            
                # Early stopping logic
                if current_test_reward < best_test_reward:
                    consecutive_drops += 1
                    print(f"Performance drop {consecutive_drops}/5 (current: {current_test_reward:.2f}, best: {best_test_reward:.2f})")
                    if consecutive_drops >= 500:
                        print(f"Early stopping triggered at episode {episode + 1} due to 5 consecutive drops in test performance")
                        break
                else:
                    consecutive_drops = 0
                    train_dqn_agent.best_test_reward = current_test_reward
                    best_test_reward = current_test_reward

        # Calculate the average reward for this batch of episodes
        avg_reward_for_this_batch = 0
        for i in range(len(scenario_folders)):
            avg_reward_for_this_batch += rewards[episode][scenario_folders[i]]
        avg_reward_for_this_batch /= len(scenario_folders)

        # Append the avg reward for this batch to rewards
        rewards[episode + 1] = avg_reward_for_this_batch

        good_rewards[episode + 1] = avg_reward_for_this_batch
        if avg_reward_for_this_batch > best_reward_avg:
            best_reward_avg = avg_reward_for_this_batch
        print(f"{env_type}: ({episode + 1}/{N_EPISODES}) {epsilon:.2f} best avg: {best_reward_avg:.2f} - rewards avg: {avg_reward_for_this_batch:.2f}")
        # print(f"Total avg rewards for this batch: {avg_reward_for_this_batch}")

        # Summarize episode
        episode_data["avg_reward"] = avg_reward_for_this_batch
        log_data['episodes'][episode + 1] = episode_data

    # Save the model after training
    if env_type == "myopic":
        model.save(f"../trained_models/dqn/myopic-{training_id}.zip")
    else:
        model.save(f"../trained_models/dqn/proactive-{training_id}.zip")

    runtime_end_in_seconds = time.time()
    runtime_in_seconds = runtime_end_in_seconds - runtime_start_in_seconds

    actual_total_timesteps = total_timesteps
    actual_exploration_timesteps = EXPLORATION_PHASE
    actual_exploration_percentage = actual_exploration_timesteps / total_timesteps
    actual_exploitation_timesteps = total_timesteps - EXPLORATION_PHASE

    training_summary = {
        "runtime_seconds": runtime_in_seconds,
        "total_timesteps": total_timesteps,
        "final_rewards": good_rewards,
        "episodes_trained": episode + 1,
        "actual_total_timesteps": actual_total_timesteps,
        "actual_exploration_timesteps": actual_exploration_timesteps,
        "actual_exploration_percentage": actual_exploration_percentage,
        "actual_exploitation_timesteps": actual_exploitation_timesteps,
    }
    log_data['training_summary'] = training_summary

    # Include all other relevant data
    log_data['average_batch_episode_rewards'] = good_rewards
    log_data['test_rewards'] = test_rewards
    log_data['epsilon_values'] = epsilon_values
    log_data['action_sequences'] = action_sequences
    log_data['rewards'] = rewards

    # Write all data to the log file at once
    log_file_path = os.path.join("../logs", "training", f"training_{training_id}.json")
    
    # make log_data serializable
    log_data = convert_to_serializable(log_data)
    with open(log_file_path, 'w') as log_file:
        json.dump(log_data, log_file, indent=4, cls=NumpyEncoder)


    finalize_training_log(training_id, training_summary, model_path)

    # Return collected data
    return rewards, test_rewards, total_timesteps, epsilon_values, good_rewards, action_sequences, model_path_and_name

# %%
# Main code to train both agents and plot results
start_time = datetime.now()

# Train the myopic DQN agents
results_myopic = train_dqn_agent('myopic')

# Unpack the results
rewards_myopic, test_rewards_myopic, total_timesteps_myopic, epsilon_values_myopic, good_rewards_myopic, action_sequences_myopic, model_path_and_name_myopic = results_myopic


# Save the myopic rewards and good rewards
myopic_rewards_file = os.path.join(results_dir, "rewards_myopic.pkl")
good_rewards_file = os.path.join(results_dir, "good_rewards_myopic.pkl")
with open(myopic_rewards_file, "wb") as file:
    pickle.dump(rewards_myopic, file)
with open(good_rewards_file, "wb") as file:
    pickle.dump(good_rewards_myopic, file)

print(f"Myopic rewards saved to {myopic_rewards_file}")
print(f"Good rewards saved to {good_rewards_file}")
print(f"Myopic model saved to \n{model_path_and_name_myopic}")
# Out:
# Models will be saved to: ../trained_models/dqn/myopic-0246.zip
# Device: mps
# Using MacBook M1
# Logging to /var/folders/m6/gwyqzldd12bg_s3mrl40tp6r0000gn/T/SB3-2024-12-03-19-29-03-199277
# Current scenario: ../data/Training/3ac-1000/Scenario_264
#     Episode 0, Reward: 9229.0
#     Episode 0, Reward: -1849.8
#     Episode 0, Reward: 8084.200000000001
# Current scenario: ../data/Training/3ac-1000/Scenario_50
#     Episode 0, Reward: -769.4
#     Episode 0, Reward: -1859.5
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -2917.1
#     Episode 0, Reward: 6955.1
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: -3168.0
#     Episode 0, Reward: -3214.0
#     Episode 0, Reward: -5281.5
#     Episode 0, Reward: 4661.3
# Current scenario: ../data/Training/3ac-1000/Scenario_432
#     Episode 0, Reward: -775.7
#     Episode 0, Reward: -867.0
#     Episode 0, Reward: -2855.2
#     Episode 0, Reward: -2954.3
#     Episode 0, Reward: 6960.3
#     Episode 0, Reward: -3084.5
#     Episode 0, Reward: -3170.0
#     Episode 0, Reward: -4185.2
#     Episode 0, Reward: 5710.0
# Current scenario: ../data/Training/3ac-1000/Scenario_600
#     Episode 0, Reward: -798.0
#     Episode 0, Reward: -839.0
#     Episode 0, Reward: -1838.1
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -3037.0
#     Episode 0, Reward: -4027.6
#     Episode 0, Reward: -5131.9
#     Episode 0, Reward: -6230.0
#     Episode 0, Reward: 3725.6000000000004
# Current scenario: ../data/Training/3ac-1000/Scenario_290
#     Episode 0, Reward: -733.1
#     Episode 0, Reward: -1864.0
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -3976.0
#     Episode 0, Reward: -4025.7
#     Episode 0, Reward: -4012.0
#     Episode 0, Reward: 5842.1
#     Episode 0, Reward: -4157.7
#     Episode 0, Reward: -5274.9
#     Episode 0, Reward: -5289.7
#     Episode 0, Reward: 4607.0
# Current scenario: ../data/Training/3ac-1000/Scenario_855
#     Episode 0, Reward: -763.4
#     Episode 0, Reward: -1792.1
#     Episode 0, Reward: -1876.0
#     Episode 0, Reward: -1907.7
#     Episode 0, Reward: -3008.0
#     Episode 0, Reward: -3093.4
#     Episode 0, Reward: -3127.3
#     Episode 0, Reward: -3187.4
#     Episode 0, Reward: -4272.0
#     Episode 0, Reward: -4325.3
#     Episode 0, Reward: -4369.7
#     Episode 0, Reward: -5457.3
# Current scenario: ../data/Training/3ac-1000/Scenario_899
#     Episode 0, Reward: -1012.9
#     Episode 0, Reward: -3117.0
#     Episode 0, Reward: -3907.1
#     Episode 0, Reward: -3990.0
#     Episode 0, Reward: -6039.1
# Current scenario: ../data/Training/3ac-1000/Scenario_297
#     Episode 0, Reward: 9203.5
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: -1919.5
#     Episode 0, Reward: -1964.8
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: -2069.0
#     Episode 0, Reward: -2170.0
#     Episode 0, Reward: -3230.0
# Current scenario: ../data/Training/3ac-1000/Scenario_607
#     Episode 0, Reward: -782.9
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: 9073.0
#     Episode 0, Reward: -935.3
#     Episode 0, Reward: 8950.0
# Current scenario: ../data/Training/3ac-1000/Scenario_435
#     Episode 0, Reward: -1003.8
#     Episode 0, Reward: -2845.2
#     Episode 0, Reward: 7095.1
# Current scenario: ../data/Training/3ac-1000/Scenario_57
#     Episode 0, Reward: -1757.6
#     Episode 0, Reward: -2843.2
#     Episode 0, Reward: -2895.0
#     Episode 0, Reward: -3963.2
#     Episode 0, Reward: -5027.0
# Current scenario: ../data/Training/3ac-1000/Scenario_263
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -818.7
#     Episode 0, Reward: -1928.5
#     Episode 0, Reward: 8010.0
#     Episode 0, Reward: -1986.7
#     Episode 0, Reward: -3080.6
# Current scenario: ../data/Training/3ac-1000/Scenario_852
#     Episode 0, Reward: -1005.5
#     Episode 0, Reward: -1825.5
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -2946.8
#     Episode 0, Reward: -3050.0
#     Episode 0, Reward: 6890.8
# Current scenario: ../data/Training/3ac-1000/Scenario_68
#     Episode 0, Reward: -1005.1
#     Episode 0, Reward: -2847.0
#     Episode 0, Reward: -3895.6
#     Episode 0, Reward: -3913.3
#     Episode 0, Reward: -3994.9
#     Episode 0, Reward: -5045.3
# Current scenario: ../data/Training/3ac-1000/Scenario_638
#     Episode 0, Reward: -978.8
#     Episode 0, Reward: -2102.7
#     Episode 0, Reward: -3130.4
#     Episode 0, Reward: 5024.8
#     Episode 0, Reward: -5050.0
#     Episode 0, Reward: -5110.0
#     Episode 0, Reward: -5170.0
#     Episode 0, Reward: -5230.0
#     Episode 0, Reward: -6286.6
# Current scenario: ../data/Training/3ac-1000/Scenario_95
#     Episode 0, Reward: 9240.2
#     Episode 0, Reward: -2825.2
#     Episode 0, Reward: 7070.0
# Current scenario: ../data/Training/3ac-1000/Scenario_61
#     Episode 0, Reward: -756.0
#     Episode 0, Reward: -1795.8
#     Episode 0, Reward: -2841.7
# Current scenario: ../data/Training/3ac-1000/Scenario_255
#     Episode 0, Reward: 9220.3
#     Episode 0, Reward: -867.0
#     Episode 0, Reward: -3836.2
#     Episode 0, Reward: 6047.1
#     Episode 0, Reward: -5033.5
#     Episode 0, Reward: 4901.5
#     Episode 0, Reward: -6094.1
#     Episode 0, Reward: 3803.2
# Current scenario: ../data/Training/3ac-1000/Scenario_631
#     Episode 0, Reward: -2018.4
#     Episode 0, Reward: -2827.6
#     Episode 0, Reward: -2885.1
#     Episode 0, Reward: -3978.8
# Current scenario: ../data/Training/3ac-1000/Scenario_403
#     Episode 0, Reward: -2007.6
#     Episode 0, Reward: -2120.0
#     Episode 0, Reward: -2180.0
#     Episode 0, Reward: -3947.1
# Current scenario: ../data/Training/3ac-1000/Scenario_890
#     Episode 0, Reward: -810.0
#     Episode 0, Reward: -867.0
#     Episode 0, Reward: -2904.0
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -3050.0
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: -4095.9
#     Episode 0, Reward: -4230.0
#     Episode 0, Reward: -4287.6
#     Episode 0, Reward: -4350.0
#     Episode 0, Reward: -6343.4
# Current scenario: ../data/Training/3ac-1000/Scenario_864
#     Episode 0, Reward: -1060.0
#     Episode 0, Reward: -1120.0
#     Episode 0, Reward: -1180.0
#     Episode 0, Reward: -1978.7
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: -3109.5
# Current scenario: ../data/Training/3ac-1000/Scenario_404
#     Episode 0, Reward: -1048.0
#     Episode 0, Reward: -1810.9
#     Episode 0, Reward: 8087.700000000001
# Current scenario: ../data/Training/3ac-1000/Scenario_636
#     Episode 0, Reward: -1012.0
#     Episode 0, Reward: -2051.4
#     Episode 0, Reward: -2180.0
#     Episode 0, Reward: 5037.4
# Current scenario: ../data/Training/3ac-1000/Scenario_252
#     Episode 0, Reward: 9734.5
#     Episode 0, Reward: -819.9
#     Episode 0, Reward: -930.0
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: 8003.9
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -2135.0
#     Episode 0, Reward: -4223.0
# Current scenario: ../data/Training/3ac-1000/Scenario_66
#     Episode 0, Reward: 9199.0
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: -1899.0
#     Episode 0, Reward: 8025.4
# Current scenario: ../data/Training/3ac-1000/Scenario_92
#     Episode 0, Reward: -780.6
#     Episode 0, Reward: -786.9
#     Episode 0, Reward: 7099.3
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -4003.2
#     Episode 0, Reward: -5084.7
#     Episode 0, Reward: -5170.0
#     Episode 0, Reward: -6182.4
#     Episode 0, Reward: -6277.3
#     Episode 0, Reward: -7330.4
#     Episode 0, Reward: -9409.3
# Current scenario: ../data/Training/3ac-1000/Scenario_863
#     Episode 0, Reward: 9199.0
#     Episode 0, Reward: -845.6
#     Episode 0, Reward: -847.2
#     Episode 0, Reward: -990.0
#     Episode 0, Reward: -1016.9
#     Episode 0, Reward: 8893.0
#     Episode 0, Reward: -1108.1
#     Episode 0, Reward: -1230.0
#     Episode 0, Reward: 7710.0
# Current scenario: ../data/Training/3ac-1000/Scenario_59
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1861.0
#     Episode 0, Reward: 8084.299999999999
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -2012.7
#     Episode 0, Reward: -3101.3
#     Episode 0, Reward: 6837.8
# Current scenario: ../data/Training/3ac-1000/Scenario_609
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: 9169.4
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -2953.4
#     Episode 0, Reward: -3009.8
#     Episode 0, Reward: 6897.8
# Current scenario: ../data/Training/3ac-1000/Scenario_897
#     Episode 0, Reward: -764.7
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -2863.1
#     Episode 0, Reward: -3927.2
# Current scenario: ../data/Training/3ac-1000/Scenario_299
#     Episode 0, Reward: -807.0
#     Episode 0, Reward: -1809.4
#     Episode 0, Reward: -1917.9
#     Episode 0, Reward: 8010.0
#     Episode 0, Reward: -2046.0
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: 7830.0
#     Episode 0, Reward: -3225.2
#     Episode 0, Reward: -3242.4
#     Episode 0, Reward: -4289.6
#     Episode 0, Reward: -5405.5
#     Episode 0, Reward: 4531.8
# Current scenario: ../data/Training/3ac-1000/Scenario_239
#     Episode 0, Reward: -1051.0
#     Episode 0, Reward: 7177.1
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -4004.0
# Current scenario: ../data/Training/3ac-1000/Scenario_837
#     Episode 0, Reward: -792.0
#     Episode 0, Reward: -1838.8
#     Episode 0, Reward: -2865.6
# Current scenario: ../data/Training/3ac-1000/Scenario_662
#     Episode 0, Reward: -808.5
#     Episode 0, Reward: 9134.5
#     Episode 0, Reward: -1898.9
#     Episode 0, Reward: -2935.7
#     Episode 0, Reward: 5970.4
#     Episode 0, Reward: -4079.9
#     Episode 0, Reward: -4145.9
#     Episode 0, Reward: -5211.9
#     Episode 0, Reward: -6272.9
# Current scenario: ../data/Training/3ac-1000/Scenario_450
#     Episode 0, Reward: -1005.4
#     Episode 0, Reward: -2099.9
#     Episode 0, Reward: -4906.4
#     Episode 0, Reward: 5057.9
#     Episode 0, Reward: -6050.0
# Current scenario: ../data/Training/3ac-1000/Scenario_32
#     Episode 0, Reward: -994.4
#     Episode 0, Reward: -1806.5
#     Episode 0, Reward: 7100.5
# Current scenario: ../data/Training/3ac-1000/Scenario_808
#     Episode 0, Reward: -1805.5
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -1985.9
#     Episode 0, Reward: -4051.9
# Current scenario: ../data/Training/3ac-1000/Scenario_206
#     Episode 0, Reward: -1802.5
#     Episode 0, Reward: -1808.4
#     Episode 0, Reward: -2906.1
#     Episode 0, Reward: -2984.1
#     Episode 0, Reward: -4022.7
# Current scenario: ../data/Training/3ac-1000/Scenario_696
#     Episode 0, Reward: -1998.1
#     Episode 0, Reward: 7155.3
#     Episode 0, Reward: -2884.7
# Current scenario: ../data/Training/3ac-1000/Scenario_468
#     Episode 0, Reward: -1020.9
#     Episode 0, Reward: -1861.0
#     Episode 0, Reward: -2897.5
#     Episode 0, Reward: 7051.9
# Current scenario: ../data/Training/3ac-1000/Scenario_830
#     Episode 0, Reward: -769.5
#     Episode 0, Reward: -2858.0
#     Episode 0, Reward: -4903.3
#     Episode 0, Reward: -4990.0
#     Episode 0, Reward: -6050.0
#     Episode 0, Reward: -6078.6
#     Episode 0, Reward: -6170.0
#     Episode 0, Reward: -7182.7
#     Episode 0, Reward: -8281.2
#     Episode 0, Reward: -8292.6
#     Episode 0, Reward: -8358.6
#     Episode 0, Reward: -9462.7
# Current scenario: ../data/Training/3ac-1000/Scenario_691
#     Episode 0, Reward: -1052.5
#     Episode 0, Reward: 7167.5
#     Episode 0, Reward: -2878.9
#     Episode 0, Reward: 6028.5
#     Episode 0, Reward: -4050.0
#     Episode 0, Reward: -5074.8
#     Episode 0, Reward: -5142.0
#     Episode 0, Reward: -5230.0
#     Episode 0, Reward: -6220.2
#     Episode 0, Reward: -7311.7
#     Episode 0, Reward: 2590.0
# Current scenario: ../data/Training/3ac-1000/Scenario_201
#     Episode 0, Reward: -568.9
#     Episode 0, Reward: -861.0
#     Episode 0, Reward: -1864.6
#     Episode 0, Reward: -2930.6
#     Episode 0, Reward: -4030.3
#     Episode 0, Reward: 5891.7
#     Episode 0, Reward: -4114.0
#     Episode 0, Reward: -4215.7
#     Episode 0, Reward: -5281.4
# Current scenario: ../data/Training/3ac-1000/Scenario_35
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -837.9
#     Episode 0, Reward: -2877.7
#     Episode 0, Reward: 7073.1
#     Episode 0, Reward: -3050.0
#     Episode 0, Reward: -4109.6
# Current scenario: ../data/Training/3ac-1000/Scenario_457
#     Episode 0, Reward: -1046.5
#     Episode 0, Reward: 7130.0
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -3945.8
#     Episode 0, Reward: -5021.3
#     Episode 0, Reward: -5110.0
#     Episode 0, Reward: -6170.0
# Current scenario: ../data/Training/3ac-1000/Scenario_665
#     Episode 0, Reward: -804.0
#     Episode 0, Reward: -1857.6
#     Episode 0, Reward: -1894.0
#     Episode 0, Reward: 8046.700000000001
#     Episode 0, Reward: -2973.4
# Current scenario: ../data/Training/3ac-1000/Scenario_698
#     Episode 0, Reward: -2007.9
#     Episode 0, Reward: -2120.0
#     Episode 0, Reward: -3180.0
#     Episode 0, Reward: -5193.5
#     Episode 0, Reward: -5712.9
#     Episode 0, Reward: -6775.0
# Current scenario: ../data/Training/3ac-1000/Scenario_806
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -120.0
#     Episode 0, Reward: 9079.0
# Current scenario: ../data/Training/3ac-1000/Scenario_208
#     Episode 0, Reward: -770.3
#     Episode 0, Reward: -789.8
#     Episode 0, Reward: -2928.5
#     Episode 0, Reward: 7025.3
#     Episode 0, Reward: -4004.9
#     Episode 0, Reward: -4102.9
#     Episode 0, Reward: -4170.0
#     Episode 0, Reward: -4165.1
#     Episode 0, Reward: -4290.0
#     Episode 0, Reward: 5652.9
# Current scenario: ../data/Training/3ac-1000/Scenario_495
#     Episode 0, Reward: -1767.7
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: 7019.2
#     Episode 0, Reward: -4014.0
# Current scenario: ../data/Training/3ac-1000/Scenario_461
#     Episode 0, Reward: -2049.5
#     Episode 0, Reward: -2827.1
#     Episode 0, Reward: 7114.4
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: 6959.0
# Current scenario: ../data/Training/3ac-1000/Scenario_653
#     Episode 0, Reward: 8190.0
#     Episode 0, Reward: -2844.4
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -2969.2
#     Episode 0, Reward: -4017.1
#     Episode 0, Reward: -4052.2
#     Episode 0, Reward: -5118.2
# Current scenario: ../data/Training/3ac-1000/Scenario_237
#     Episode 0, Reward: -750.0
#     Episode 0, Reward: 9133.0
#     Episode 0, Reward: -1912.2
#     Episode 0, Reward: -2952.1
#     Episode 0, Reward: 5950.0
# Current scenario: ../data/Training/3ac-1000/Scenario_03
#     Episode 0, Reward: -782.3
#     Episode 0, Reward: 9130.0
#     Episode 0, Reward: -2904.0
#     Episode 0, Reward: -2947.3
#     Episode 0, Reward: 5988.9
#     Episode 0, Reward: 5913.1
# Current scenario: ../data/Training/3ac-1000/Scenario_839
#     Episode 0, Reward: -805.5
#     Episode 0, Reward: -1800.5
#     Episode 0, Reward: -2882.3
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: 6955.3
# Current scenario: ../data/Training/3ac-1000/Scenario_459
#     Episode 0, Reward: -1045.0
#     Episode 0, Reward: -2044.3
#     Episode 0, Reward: -4180.0
#     Episode 0, Reward: -5169.2
#     Episode 0, Reward: -6272.2
#     Episode 0, Reward: -7107.6
#     Episode 0, Reward: 2830.6
# Current scenario: ../data/Training/3ac-1000/Scenario_801
#     Episode 0, Reward: 8241.9
#     Episode 0, Reward: -2846.7
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -3990.0
#     Episode 0, Reward: -3991.1
#     Episode 0, Reward: -4083.8
#     Episode 0, Reward: -4170.0
#     Episode 0, Reward: -4186.3
#     Episode 0, Reward: -5252.3
#     Episode 0, Reward: 4669.4
# Current scenario: ../data/Training/3ac-1000/Scenario_04
#     Episode 0, Reward: -1045.0
#     Episode 0, Reward: -1834.3
#     Episode 0, Reward: -2880.4
#     Episode 0, Reward: -3926.3
# Current scenario: ../data/Training/3ac-1000/Scenario_230
#     Episode 0, Reward: -1029.8
#     Episode 0, Reward: -2826.1
#     Episode 0, Reward: 7089.1
# Current scenario: ../data/Training/3ac-1000/Scenario_654
#     Episode 0, Reward: 8241.0
#     Episode 0, Reward: 8153.299999999999
#     Episode 0, Reward: -3857.0
#     Episode 0, Reward: 5038.7
# Current scenario: ../data/Training/3ac-1000/Scenario_466
#     Episode 0, Reward: -1766.5
#     Episode 0, Reward: -2861.0
#     Episode 0, Reward: -3868.4
#     Episode 0, Reward: -4982.1
#     Episode 0, Reward: -6030.8
#     Episode 0, Reward: -7056.0
#     Episode 0, Reward: -8170.0
# Current scenario: ../data/Training/3ac-1000/Scenario_492
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: 8151.6
#     Episode 0, Reward: -1880.3
#     Episode 0, Reward: -1973.5
#     Episode 0, Reward: -2022.9
#     Episode 0, Reward: -2074.1
#     Episode 0, Reward: -2127.9
#     Episode 0, Reward: 7788.1
# Current scenario: ../data/Training/3ac-1000/Scenario_93
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1832.8
#     Episode 0, Reward: -1885.2
#     Episode 0, Reward: -2957.9
#     Episode 0, Reward: 6950.7
# Current scenario: ../data/Training/3ac-1000/Scenario_637
#     Episode 0, Reward: -796.5
#     Episode 0, Reward: 9130.0
#     Episode 0, Reward: -2889.2
#     Episode 0, Reward: 7051.8
#     Episode 0, Reward: -3001.4
#     Episode 0, Reward: -4110.0
#     Episode 0, Reward: 5868.7
# Current scenario: ../data/Training/3ac-1000/Scenario_405
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1081.7
#     Episode 0, Reward: -3180.0
#     Episode 0, Reward: -4221.2
#     Episode 0, Reward: 4955.9
#     Episode 0, Reward: 4906.3
# Current scenario: ../data/Training/3ac-1000/Scenario_67
#     Episode 0, Reward: -1033.0
#     Episode 0, Reward: -2120.0
#     Episode 0, Reward: -4142.2
#     Episode 0, Reward: -4983.7
#     Episode 0, Reward: 4950.0
# Current scenario: ../data/Training/3ac-1000/Scenario_253
#     Episode 0, Reward: -744.1
#     Episode 0, Reward: -861.0
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -2905.7
#     Episode 0, Reward: -3989.9
#     Episode 0, Reward: -5098.7
#     Episode 0, Reward: -7115.8
#     Episode 0, Reward: -7230.0
#     Episode 0, Reward: -7290.0
#     Episode 0, Reward: 2656.4
# Current scenario: ../data/Training/3ac-1000/Scenario_298
#     Episode 0, Reward: -748.6
#     Episode 0, Reward: 9163.8
#     Episode 0, Reward: -1863.7
# Current scenario: ../data/Training/3ac-1000/Scenario_896
#     Episode 0, Reward: -1030.9
#     Episode 0, Reward: -1120.0
#     Episode 0, Reward: -2180.0
#     Episode 0, Reward: 7039.2
# Current scenario: ../data/Training/3ac-1000/Scenario_58
#     Episode 0, Reward: -790.1
#     Episode 0, Reward: -2850.3
#     Episode 0, Reward: 6080.8
#     Episode 0, Reward: 6064.0
#     Episode 0, Reward: 5950.0
#     Episode 0, Reward: -4086.3
#     Episode 0, Reward: -4123.9
#     Episode 0, Reward: -5230.0
# Current scenario: ../data/Training/3ac-1000/Scenario_862
#     Episode 0, Reward: -1020.3
#     Episode 0, Reward: -2861.0
#     Episode 0, Reward: 7091.4
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -4010.2
#     Episode 0, Reward: -5025.8
#     Episode 0, Reward: -5156.2
#     Episode 0, Reward: -5230.0
#     Episode 0, Reward: -5290.0
#     Episode 0, Reward: -6350.0
# Current scenario: ../data/Training/3ac-1000/Scenario_608
#     Episode 0, Reward: -1043.5
#     Episode 0, Reward: -2081.3
#     Episode 0, Reward: -2882.0
#     Episode 0, Reward: -2916.0
#     Episode 0, Reward: -3050.0
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: -4165.0
#     Episode 0, Reward: -5180.0
#     Episode 0, Reward: 4728.0
# Current scenario: ../data/Training/3ac-1000/Scenario_254
#     Episode 0, Reward: 8214.5
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -1872.9
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -2025.0
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -2170.0
#     Episode 0, Reward: -2221.1
#     Episode 0, Reward: -3264.6
# Current scenario: ../data/Training/3ac-1000/Scenario_60
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -2074.1
#     Episode 0, Reward: -2876.9
#     Episode 0, Reward: -3970.1
# Current scenario: ../data/Training/3ac-1000/Scenario_402
#     Episode 0, Reward: 8251.7
#     Episode 0, Reward: -1847.8
#     Episode 0, Reward: -2834.2
#     Episode 0, Reward: 6021.6
#     Episode 0, Reward: -4050.0
#     Episode 0, Reward: 5896.8
#     Episode 0, Reward: -5147.9
#     Episode 0, Reward: -6154.6
#     Episode 0, Reward: -7247.4
# Current scenario: ../data/Training/3ac-1000/Scenario_630
#     Episode 0, Reward: -780.9
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: -1883.7
#     Episode 0, Reward: -3967.9
#     Episode 0, Reward: -3998.2
#     Episode 0, Reward: -4110.0
#     Episode 0, Reward: -5128.8
#     Episode 0, Reward: -5169.6
#     Episode 0, Reward: 4720.4
# Current scenario: ../data/Training/3ac-1000/Scenario_94
#     Episode 0, Reward: 8214.4
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -1915.5
#     Episode 0, Reward: -2975.7
#     Episode 0, Reward: 6971.4
#     Episode 0, Reward: -4087.2
#     Episode 0, Reward: 5830.0
# Current scenario: ../data/Training/3ac-1000/Scenario_865
#     Episode 0, Reward: -2032.0
#     Episode 0, Reward: -2839.3
#     Episode 0, Reward: -3924.8
#     Episode 0, Reward: 6065.7
#     Episode 0, Reward: 5950.0
#     Episode 0, Reward: 5902.1
#     Episode 0, Reward: -5096.4
#     Episode 0, Reward: -5212.3
#     Episode 0, Reward: -6214.3
#     Episode 0, Reward: -6272.8
#     Episode 0, Reward: 3605.5
# Current scenario: ../data/Training/3ac-1000/Scenario_891
#     Episode 0, Reward: -765.4
#     Episode 0, Reward: 9140.5
#     Episode 0, Reward: -1897.4
# Current scenario: ../data/Training/3ac-1000/Scenario_434
#     Episode 0, Reward: 9199.0
#     Episode 0, Reward: -1833.4
#     Episode 0, Reward: 8111.0
#     Episode 0, Reward: -2974.9
# Current scenario: ../data/Training/3ac-1000/Scenario_606
#     Episode 0, Reward: -1052.5
#     Episode 0, Reward: -1823.0
#     Episode 0, Reward: -1930.0
# Current scenario: ../data/Training/3ac-1000/Scenario_262
#     Episode 0, Reward: 9234.8
#     Episode 0, Reward: -829.5
#     Episode 0, Reward: -1867.7
#     Episode 0, Reward: -2899.1
# Current scenario: ../data/Training/3ac-1000/Scenario_56
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1839.7
#     Episode 0, Reward: -1879.9
#     Episode 0, Reward: -1920.4
#     Episode 0, Reward: -3050.0
# Current scenario: ../data/Training/3ac-1000/Scenario_296
#     Episode 0, Reward: -1003.5
#     Episode 0, Reward: 8181.200000000001
#     Episode 0, Reward: -3914.2
#     Episode 0, Reward: -3990.0
#     Episode 0, Reward: -4989.9
#     Episode 0, Reward: -5110.0
#     Episode 0, Reward: 4831.0
#     Episode 0, Reward: -6168.4
#     Episode 0, Reward: -7256.7
# Current scenario: ../data/Training/3ac-1000/Scenario_898
#     Episode 0, Reward: -799.5
#     Episode 0, Reward: -1823.6
#     Episode 0, Reward: -1846.0
#     Episode 0, Reward: 8020.299999999999
# Current scenario: ../data/Training/3ac-1000/Scenario_69
#     Episode 0, Reward: -1008.9
#     Episode 0, Reward: -2071.9
#     Episode 0, Reward: 5135.1
#     Episode 0, Reward: 5046.5
#     Episode 0, Reward: -5010.1
#     Episode 0, Reward: -5053.6
#     Episode 0, Reward: -7101.3
# Current scenario: ../data/Training/3ac-1000/Scenario_853
#     Episode 0, Reward: -798.0
#     Episode 0, Reward: -1837.4
#     Episode 0, Reward: -2892.4
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: 6993.0
# Current scenario: ../data/Training/3ac-1000/Scenario_639
#     Episode 0, Reward: -1799.5
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -1905.2
# Current scenario: ../data/Training/3ac-1000/Scenario_291
#     Episode 0, Reward: -757.7
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: -2910.9
# Current scenario: ../data/Training/3ac-1000/Scenario_51
#     Episode 0, Reward: 9229.6
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -1975.7
#     Episode 0, Reward: -3023.9
#     Episode 0, Reward: -3076.4
#     Episode 0, Reward: -3157.1
#     Episode 0, Reward: -4198.2
#     Episode 0, Reward: 5719.5
# Current scenario: ../data/Training/3ac-1000/Scenario_265
#     Episode 0, Reward: -762.7
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -2878.3
#     Episode 0, Reward: 7010.0
#     Episode 0, Reward: -3050.0
#     Episode 0, Reward: -3051.2
#     Episode 0, Reward: -4170.0
#     Episode 0, Reward: -4230.0
#     Episode 0, Reward: -4209.5
#     Episode 0, Reward: -5327.7
#     Episode 0, Reward: -6410.0
# Current scenario: ../data/Training/3ac-1000/Scenario_601
#     Episode 0, Reward: -1054.0
#     Episode 0, Reward: -2120.0
#     Episode 0, Reward: 17070.0
#     Episode 0, Reward: 7030.8
#     Episode 0, Reward: -4029.3
#     Episode 0, Reward: -4110.0
#     Episode 0, Reward: 5831.0
# Current scenario: ../data/Training/3ac-1000/Scenario_433
#     Episode 0, Reward: -804.0
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: 8127.4
#     Episode 0, Reward: -2933.8
#     Episode 0, Reward: -3050.0
#     Episode 0, Reward: -3032.9
#     Episode 0, Reward: -4170.0
# Current scenario: ../data/Training/3ac-1000/Scenario_854
#     Episode 0, Reward: -752.3
#     Episode 0, Reward: -1865.5
#     Episode 0, Reward: -1894.7
#     Episode 0, Reward: -1973.5
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: -3034.5
#     Episode 0, Reward: -4121.6
#     Episode 0, Reward: 5790.6
# Current scenario: ../data/Training/3ac-1000/Scenario_458
#     Episode 0, Reward: -1778.2
#     Episode 0, Reward: -2844.1
#     Episode 0, Reward: -3867.0
#     Episode 0, Reward: -3958.2
#     Episode 0, Reward: -5050.0
#     Episode 0, Reward: -5025.7
#     Episode 0, Reward: -5170.0
#     Episode 0, Reward: -7199.1
# Current scenario: ../data/Training/3ac-1000/Scenario_800
#     Episode 0, Reward: -775.1
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: 7088.3
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -4043.7
#     Episode 0, Reward: 5922.8
#     Episode 0, Reward: -5163.8
#     Episode 0, Reward: -6204.3
# Current scenario: ../data/Training/3ac-1000/Scenario_493
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1066.2
#     Episode 0, Reward: 8150.6
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -4003.7
#     Episode 0, Reward: -4109.0
#     Episode 0, Reward: -4163.5
#     Episode 0, Reward: 5781.1
# Current scenario: ../data/Training/3ac-1000/Scenario_231
#     Episode 0, Reward: -1757.1
#     Episode 0, Reward: 8164.4
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -2969.9
#     Episode 0, Reward: -3011.0
#     Episode 0, Reward: -4072.6
#     Episode 0, Reward: -5156.9
#     Episode 0, Reward: 4793.0
# Current scenario: ../data/Training/3ac-1000/Scenario_05
#     Episode 0, Reward: -1005.5
#     Episode 0, Reward: -2048.6
#     Episode 0, Reward: -4180.0
#     Episode 0, Reward: -4681.1
#     Episode 0, Reward: 4263.8
#     Episode 0, Reward: -7802.2
# Current scenario: ../data/Training/3ac-1000/Scenario_467
#     Episode 0, Reward: -1005.8
#     Episode 0, Reward: -2844.4
#     Episode 0, Reward: 7094.6
#     Episode 0, Reward: 7062.5
# Current scenario: ../data/Training/3ac-1000/Scenario_655
#     Episode 0, Reward: 9200.5
#     Episode 0, Reward: 9184.2
#     Episode 0, Reward: -1915.4
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -2999.6
# Current scenario: ../data/Training/3ac-1000/Scenario_209
#     Episode 0, Reward: -1005.8
#     Episode 0, Reward: -2055.8
#     Episode 0, Reward: -2925.5
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: 6950.0
#     Episode 0, Reward: -3105.1
#     Episode 0, Reward: -4170.0
# Current scenario: ../data/Training/3ac-1000/Scenario_807
#     Episode 0, Reward: -781.4
#     Episode 0, Reward: -1827.3
#     Episode 0, Reward: -2870.5
#     Episode 0, Reward: 7010.0
#     Episode 0, Reward: -3016.6
#     Episode 0, Reward: -3068.5
#     Episode 0, Reward: 6830.0
# Current scenario: ../data/Training/3ac-1000/Scenario_699
#     Episode 0, Reward: -1750.3
#     Episode 0, Reward: -2821.0
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: 7020.8
# Current scenario: ../data/Training/3ac-1000/Scenario_652
#     Episode 0, Reward: 8212.2
#     Episode 0, Reward: -1833.6
#     Episode 0, Reward: -1930.0
# Current scenario: ../data/Training/3ac-1000/Scenario_460
#     Episode 0, Reward: -1020.8
#     Episode 0, Reward: 8136.0
#     Episode 0, Reward: -1872.1
#     Episode 0, Reward: -1947.3
#     Episode 0, Reward: 7958.200000000001
#     Episode 0, Reward: -2040.5
#     Episode 0, Reward: -2137.9
#     Episode 0, Reward: -2194.4
#     Episode 0, Reward: -3285.6
# Current scenario: ../data/Training/3ac-1000/Scenario_838
#     Episode 0, Reward: 9190.0
#     Episode 0, Reward: 9149.9
#     Episode 0, Reward: 8070.0
# Current scenario: ../data/Training/3ac-1000/Scenario_02
#     Episode 0, Reward: 9199.0
#     Episode 0, Reward: -827.4
#     Episode 0, Reward: -2865.4
#     Episode 0, Reward: -4943.2
#     Episode 0, Reward: -5013.6
#     Episode 0, Reward: 4890.0
# Current scenario: ../data/Training/3ac-1000/Scenario_236
#     Episode 0, Reward: -756.0
#     Episode 0, Reward: 8179.700000000001
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -2974.6
#     Episode 0, Reward: -4050.0
# Current scenario: ../data/Training/3ac-1000/Scenario_494
#     Episode 0, Reward: -1060.0
#     Episode 0, Reward: 8373.8
#     Episode 0, Reward: -2733.4
#     Episode 0, Reward: -3760.8
#     Episode 0, Reward: -5033.7
#     Episode 0, Reward: -6079.9
#     Episode 0, Reward: 3836.3999999999996
# Current scenario: ../data/Training/3ac-1000/Scenario_469
#     Episode 0, Reward: -793.3
#     Episode 0, Reward: -2809.8
#     Episode 0, Reward: -2899.6
# Current scenario: ../data/Training/3ac-1000/Scenario_831
#     Episode 0, Reward: -768.7
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -1910.3
#     Episode 0, Reward: -2990.0
# Current scenario: ../data/Training/3ac-1000/Scenario_34
#     Episode 0, Reward: -1024.2
#     Episode 0, Reward: -2108.0
#     Episode 0, Reward: -2876.8
#     Episode 0, Reward: 7054.6
# Current scenario: ../data/Training/3ac-1000/Scenario_200
#     Episode 0, Reward: -998.6
#     Episode 0, Reward: -2055.3
#     Episode 0, Reward: -2924.0
#     Episode 0, Reward: -3990.0
#     Episode 0, Reward: -4006.1
#     Episode 0, Reward: -4110.0
#     Episode 0, Reward: -5169.3
# Current scenario: ../data/Training/3ac-1000/Scenario_664
#     Episode 0, Reward: 9217.4
#     Episode 0, Reward: -802.5
#     Episode 0, Reward: -1888.9
# Current scenario: ../data/Training/3ac-1000/Scenario_456
#     Episode 0, Reward: -1799.5
#     Episode 0, Reward: -1762.9
#     Episode 0, Reward: -1875.9
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: 7960.799999999999
# Current scenario: ../data/Training/3ac-1000/Scenario_690
#     Episode 0, Reward: 9199.0
#     Episode 0, Reward: -789.9
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: 8014.299999999999
#     Episode 0, Reward: -2004.2
#     Episode 0, Reward: 7901.0
# Current scenario: ../data/Training/3ac-1000/Scenario_836
#     Episode 0, Reward: -738.4
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: -930.0
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -2038.9
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -3170.0
#     Episode 0, Reward: -3230.0
#     Episode 0, Reward: -3286.2
#     Episode 0, Reward: -3309.8
#     Episode 0, Reward: -4398.4
#     Episode 0, Reward: -5428.0
#     Episode 0, Reward: 4472.1
# Current scenario: ../data/Training/3ac-1000/Scenario_238
#     Episode 0, Reward: 9203.5
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: 9098.0
#     Episode 0, Reward: -922.6
#     Episode 0, Reward: -2045.7
#     Episode 0, Reward: -3096.0
#     Episode 0, Reward: -4144.4
#     Episode 0, Reward: -4230.0
#     Episode 0, Reward: -4230.3
#     Episode 0, Reward: -5347.7
#     Episode 0, Reward: 4597.6
# Current scenario: ../data/Training/3ac-1000/Scenario_697
#     Episode 0, Reward: -1060.0
#     Episode 0, Reward: 8130.0
#     Episode 0, Reward: -2856.2
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -3045.2
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: -4142.5
# Current scenario: ../data/Training/3ac-1000/Scenario_451
#     Episode 0, Reward: 9237.2
#     Episode 0, Reward: -816.6
#     Episode 0, Reward: -1901.1
# Current scenario: ../data/Training/3ac-1000/Scenario_663
#     Episode 0, Reward: 9217.4
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: -1902.3
#     Episode 0, Reward: -1905.0
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: 7920.1
# Current scenario: ../data/Training/3ac-1000/Scenario_207
#     Episode 0, Reward: -2055.5
#     Episode 0, Reward: -3097.5
#     Episode 0, Reward: -4918.0
#     Episode 0, Reward: -5975.1
# Current scenario: ../data/Training/3ac-1000/Scenario_809
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: 8130.0
#     Episode 0, Reward: -2884.2
# Current scenario: ../data/Training/3ac-1000/Scenario_33
#     Episode 0, Reward: -776.6
#     Episode 0, Reward: -856.5
#     Episode 0, Reward: -1930.0
# Current scenario: ../data/Training/3ac-1000/Scenario_375
#     Episode 0, Reward: -1049.5
#     Episode 0, Reward: -2085.5
#     Episode 0, Reward: 7082.7
#     Episode 0, Reward: -3930.7
#     Episode 0, Reward: -5033.9
#     Episode 0, Reward: -5110.0
#     Episode 0, Reward: -6159.2
# Current scenario: ../data/Training/3ac-1000/Scenario_147
#     Episode 0, Reward: 8263.9
#     Episode 0, Reward: -1833.8
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -2974.7
#     Episode 0, Reward: 6969.8
# Current scenario: ../data/Training/3ac-1000/Scenario_523
#     Episode 0, Reward: 8211.4
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -2888.4
# Current scenario: ../data/Training/3ac-1000/Scenario_711
#     Episode 0, Reward: -1784.5
#     Episode 0, Reward: 7179.3
#     Episode 0, Reward: -3867.1
#     Episode 0, Reward: 6019.1
#     Episode 0, Reward: 5950.0
#     Episode 0, Reward: -4110.0
#     Episode 0, Reward: -4170.0
#     Episode 0, Reward: -4230.0
#     Episode 0, Reward: -4290.0
#     Episode 0, Reward: -5349.6
# Current scenario: ../data/Training/3ac-1000/Scenario_381
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1840.5
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -2976.2
#     Episode 0, Reward: 6963.5
#     Episode 0, Reward: -4085.7
#     Episode 0, Reward: -4170.0
#     Episode 0, Reward: -4189.0
#     Episode 0, Reward: 5725.8
# Current scenario: ../data/Training/3ac-1000/Scenario_178
#     Episode 0, Reward: -733.7
#     Episode 0, Reward: -829.7
#     Episode 0, Reward: -885.8
#     Episode 0, Reward: -1905.9
# Current scenario: ../data/Training/3ac-1000/Scenario_944
#     Episode 0, Reward: -32.099999999999994
#     Episode 0, Reward: -1124.5
#     Episode 0, Reward: -1905.2
#     Episode 0, Reward: -3933.7
# Current scenario: ../data/Training/3ac-1000/Scenario_988
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: 9130.0
#     Episode 0, Reward: -891.4
#     Episode 0, Reward: -1948.0
# Current scenario: ../data/Training/3ac-1000/Scenario_386
#     Episode 0, Reward: -986.7
#     Episode 0, Reward: 8136.0
#     Episode 0, Reward: -1901.7
#     Episode 0, Reward: 7036.4
#     Episode 0, Reward: 6950.0
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: -3144.3
#     Episode 0, Reward: 5788.6
# Current scenario: ../data/Training/3ac-1000/Scenario_716
#     Episode 0, Reward: 8219.6
#     Episode 0, Reward: -1839.3
#     Episode 0, Reward: -2905.3
# Current scenario: ../data/Training/3ac-1000/Scenario_524
#     Episode 0, Reward: -773.6
#     Episode 0, Reward: -859.5
#     Episode 0, Reward: -1878.7
#     Episode 0, Reward: -1925.4
#     Episode 0, Reward: 7955.9
#     Episode 0, Reward: -3081.4
# Current scenario: ../data/Training/3ac-1000/Scenario_140
#     Episode 0, Reward: -1802.5
#     Episode 0, Reward: 8174.799999999999
#     Episode 0, Reward: -1889.0
#     Episode 0, Reward: -1983.1
#     Episode 0, Reward: -4027.9
# Current scenario: ../data/Training/3ac-1000/Scenario_372
#     Episode 0, Reward: -776.2
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -1988.6
#     Episode 0, Reward: -2027.7
#     Episode 0, Reward: -3110.0
# Current scenario: ../data/Training/3ac-1000/Scenario_943
#     Episode 0, Reward: -768.3
#     Episode 0, Reward: 9131.5
#     Episode 0, Reward: -930.0
#     Episode 0, Reward: -2932.6
# Current scenario: ../data/Training/3ac-1000/Scenario_729
#     Episode 0, Reward: -787.5
#     Episode 0, Reward: -761.1
#     Episode 0, Reward: -930.0
#     Episode 0, Reward: -2893.1
# Current scenario: ../data/Training/3ac-1000/Scenario_182
#     Episode 0, Reward: -742.9
#     Episode 0, Reward: 8167.700000000001
#     Episode 0, Reward: -2875.2
#     Episode 0, Reward: -3928.7
#     Episode 0, Reward: -5050.0
#     Episode 0, Reward: -6082.1
# Current scenario: ../data/Training/3ac-1000/Scenario_176
#     Episode 0, Reward: -1060.0
#     Episode 0, Reward: -1829.0
#     Episode 0, Reward: -1913.0
#     Episode 0, Reward: -3949.0
#     Episode 0, Reward: -4007.6
#     Episode 0, Reward: 5899.0
#     Episode 0, Reward: -4170.0
#     Episode 0, Reward: -5158.5
#     Episode 0, Reward: 4724.1
# Current scenario: ../data/Training/3ac-1000/Scenario_344
#     Episode 0, Reward: -759.7
#     Episode 0, Reward: -1814.5
#     Episode 0, Reward: -2920.0
#     Episode 0, Reward: -2946.5
#     Episode 0, Reward: 6964.4
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: 6857.7
# Current scenario: ../data/Training/3ac-1000/Scenario_720
#     Episode 0, Reward: -2003.6
#     Episode 0, Reward: -2120.0
#     Episode 0, Reward: 7135.1
#     Episode 0, Reward: -2986.1
#     Episode 0, Reward: -3025.9
#     Episode 0, Reward: -4106.2
#     Episode 0, Reward: -4170.0
#     Episode 0, Reward: -4172.8
#     Episode 0, Reward: -5282.7
# Current scenario: ../data/Training/3ac-1000/Scenario_512
#     Episode 0, Reward: -1983.8
#     Episode 0, Reward: 7172.7
#     Episode 0, Reward: -3913.4
# Current scenario: ../data/Training/3ac-1000/Scenario_981
#     Episode 0, Reward: -208.8
#     Episode 0, Reward: 8195.6
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -1899.6
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: -3077.7
#     Episode 0, Reward: -4097.6
#     Episode 0, Reward: -5213.9
# Current scenario: ../data/Training/3ac-1000/Scenario_149
#     Episode 0, Reward: 9193.0
#     Episode 0, Reward: 9130.0
#     Episode 0, Reward: -910.5
# Current scenario: ../data/Training/3ac-1000/Scenario_975
#     Episode 0, Reward: 8245.3
#     Episode 0, Reward: -1801.5
#     Episode 0, Reward: -1907.7
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -2998.8
# Current scenario: ../data/Training/3ac-1000/Scenario_515
#     Episode 0, Reward: -772.2
#     Episode 0, Reward: -815.2
#     Episode 0, Reward: -1895.9
#     Episode 0, Reward: -2955.4
#     Episode 0, Reward: -3050.0
#     Episode 0, Reward: -4099.5
# Current scenario: ../data/Training/3ac-1000/Scenario_727
#     Episode 0, Reward: -737.1
#     Episode 0, Reward: -845.4
#     Episode 0, Reward: -1911.7
# Current scenario: ../data/Training/3ac-1000/Scenario_343
#     Episode 0, Reward: -1032.7
#     Episode 0, Reward: 8172.700000000001
#     Episode 0, Reward: -2894.8
#     Episode 0, Reward: -2960.7
#     Episode 0, Reward: 6956.9
#     Episode 0, Reward: -3075.8
#     Episode 0, Reward: -3125.4
#     Episode 0, Reward: -3230.0
#     Episode 0, Reward: -4224.4
#     Episode 0, Reward: -4350.0
#     Episode 0, Reward: -6405.8
# Current scenario: ../data/Training/3ac-1000/Scenario_171
#     Episode 0, Reward: 9190.0
#     Episode 0, Reward: -1835.2
#     Episode 0, Reward: 7084.2
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -3050.0
#     Episode 0, Reward: -3102.3
#     Episode 0, Reward: -3130.8
#     Episode 0, Reward: -4221.1
#     Episode 0, Reward: 5724.9
# Current scenario: ../data/Training/3ac-1000/Scenario_185
#     Episode 0, Reward: -1009.2
#     Episode 0, Reward: -3071.9
#     Episode 0, Reward: -3539.4
#     Episode 0, Reward: -4649.8
#     Episode 0, Reward: -4667.7
#     Episode 0, Reward: -5785.5
# Current scenario: ../data/Training/3ac-1000/Scenario_972
#     Episode 0, Reward: -740.3
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: -1895.9
#     Episode 0, Reward: -1933.6
#     Episode 0, Reward: -2044.1
#     Episode 0, Reward: -3061.8
#     Episode 0, Reward: -3150.1
#     Episode 0, Reward: -4226.7
# Current scenario: ../data/Training/3ac-1000/Scenario_718
#     Episode 0, Reward: -735.3
#     Episode 0, Reward: -1814.9
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -3975.9
# Current scenario: ../data/Training/3ac-1000/Scenario_986
#     Episode 0, Reward: -775.8
#     Episode 0, Reward: -823.1
#     Episode 0, Reward: -1863.4
#     Episode 0, Reward: 7073.5
#     Episode 0, Reward: -2959.0
#     Episode 0, Reward: -4025.0
#     Episode 0, Reward: -4170.0
#     Episode 0, Reward: -5230.0
#     Episode 0, Reward: -5290.0
#     Episode 0, Reward: -5272.2
#     Episode 0, Reward: -7388.5
# Current scenario: ../data/Training/3ac-1000/Scenario_388
#     Episode 0, Reward: -2048.0
#     Episode 0, Reward: -2115.5
#     Episode 0, Reward: -3157.0
#     Episode 0, Reward: -4236.7
#     Episode 0, Reward: -4300.0
#     Episode 0, Reward: -4360.0
#     Episode 0, Reward: -5415.5
# Current scenario: ../data/Training/3ac-1000/Scenario_328
#     Episode 0, Reward: -1000.6
#     Episode 0, Reward: -2118.5
#     Episode 0, Reward: -3111.0
#     Episode 0, Reward: -5223.7
#     Episode 0, Reward: -5300.0
#     Episode 0, Reward: -5360.0
#     Episode 0, Reward: -5420.0
#     Episode 0, Reward: -7471.2
# Current scenario: ../data/Training/3ac-1000/Scenario_926
#     Episode 0, Reward: -1795.0
#     Episode 0, Reward: -1804.4
#     Episode 0, Reward: -2901.8
#     Episode 0, Reward: -2955.7
#     Episode 0, Reward: -4039.3
# Current scenario: ../data/Training/3ac-1000/Scenario_773
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: 9134.5
#     Episode 0, Reward: 9086.3
#     Episode 0, Reward: -990.0
#     Episode 0, Reward: -1050.0
#     Episode 0, Reward: -1088.9
#     Episode 0, Reward: -1115.5
#     Episode 0, Reward: -1205.1
#     Episode 0, Reward: -3286.3
# Current scenario: ../data/Training/3ac-1000/Scenario_541
#     Episode 0, Reward: 9233.4
#     Episode 0, Reward: -801.0
#     Episode 0, Reward: -894.1
#     Episode 0, Reward: -1985.5
#     Episode 0, Reward: 8000.799999999999
#     Episode 0, Reward: 7917.700000000001
# Current scenario: ../data/Training/3ac-1000/Scenario_919
#     Episode 0, Reward: -777.7
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -2889.8
# Current scenario: ../data/Training/3ac-1000/Scenario_125
#     Episode 0, Reward: -807.0
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: -1925.5
#     Episode 0, Reward: 8047.299999999999
#     Episode 0, Reward: -2026.9
#     Episode 0, Reward: -2104.4
#     Episode 0, Reward: -4062.7
# Current scenario: ../data/Training/3ac-1000/Scenario_317
#     Episode 0, Reward: -761.9
#     Episode 0, Reward: -822.9
#     Episode 0, Reward: -1859.6
#     Episode 0, Reward: 8010.0
#     Episode 0, Reward: 7969.9
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -2152.9
#     Episode 0, Reward: -2189.4
#     Episode 0, Reward: -2290.0
#     Episode 0, Reward: 7662.4
# Current scenario: ../data/Training/3ac-1000/Scenario_787
#     Episode 0, Reward: 9218.7
#     Episode 0, Reward: -1845.6
#     Episode 0, Reward: -2885.8
#     Episode 0, Reward: -3958.3
#     Episode 0, Reward: -3994.6
#     Episode 0, Reward: -4110.0
#     Episode 0, Reward: -4126.3
#     Episode 0, Reward: -4173.0
#     Episode 0, Reward: 5710.5
# Current scenario: ../data/Training/3ac-1000/Scenario_579
#     Episode 0, Reward: -736.6
#     Episode 0, Reward: -803.4
#     Episode 0, Reward: 9080.5
#     Episode 0, Reward: -1987.0
#     Episode 0, Reward: -2999.5
#     Episode 0, Reward: -4087.0
# Current scenario: ../data/Training/3ac-1000/Scenario_921
#     Episode 0, Reward: -784.1
#     Episode 0, Reward: 8146.299999999999
#     Episode 0, Reward: -1853.5
# Current scenario: ../data/Training/3ac-1000/Scenario_780
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1067.9
#     Episode 0, Reward: -2180.0
#     Episode 0, Reward: -2978.3
#     Episode 0, Reward: -3995.7
#     Episode 0, Reward: 5898.0
#     Episode 0, Reward: -4170.0
#     Episode 0, Reward: -4230.0
#     Episode 0, Reward: 5721.7
# Current scenario: ../data/Training/3ac-1000/Scenario_310
#     Episode 0, Reward: 9202.0
#     Episode 0, Reward: -1858.0
#     Episode 0, Reward: -2870.4
#     Episode 0, Reward: -3983.8
#     Episode 0, Reward: -4028.3
#     Episode 0, Reward: -6055.9
#     Episode 0, Reward: -7157.3
#     Episode 0, Reward: -8214.7
# Current scenario: ../data/Training/3ac-1000/Scenario_122
#     Episode 0, Reward: -1001.0
#     Episode 0, Reward: 7154.0
#     Episode 0, Reward: -3875.1
#     Episode 0, Reward: -3919.8
#     Episode 0, Reward: -6003.9
# Current scenario: ../data/Training/3ac-1000/Scenario_546
#     Episode 0, Reward: 8236.9
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -2930.0
# Current scenario: ../data/Training/3ac-1000/Scenario_774
#     Episode 0, Reward: -1035.7
#     Episode 0, Reward: -2062.6
#     Episode 0, Reward: -3660.0
# Current scenario: ../data/Training/3ac-1000/Scenario_789
#     Episode 0, Reward: -1060.0
#     Episode 0, Reward: -1846.7
#     Episode 0, Reward: -3888.2
# Current scenario: ../data/Training/3ac-1000/Scenario_917
#     Episode 0, Reward: 9232.2
#     Episode 0, Reward: -837.4
#     Episode 0, Reward: 9076.0
#     Episode 0, Reward: -1961.8
#     Episode 0, Reward: -2989.8
#     Episode 0, Reward: -3107.3
#     Episode 0, Reward: -4159.8
#     Episode 0, Reward: -4205.6
#     Episode 0, Reward: 5726.1
# Current scenario: ../data/Training/3ac-1000/Scenario_319
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: 8957.8
#     Episode 0, Reward: -1883.2
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: 7961.4
#     Episode 0, Reward: -2099.5
#     Episode 0, Reward: -2170.0
#     Episode 0, Reward: -3188.2
#     Episode 0, Reward: -3290.0
#     Episode 0, Reward: -5338.1
# Current scenario: ../data/Training/3ac-1000/Scenario_584
#     Episode 0, Reward: 8244.8
#     Episode 0, Reward: -2799.0
#     Episode 0, Reward: -2895.1
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -3983.7
# Current scenario: ../data/Training/3ac-1000/Scenario_570
#     Episode 0, Reward: -740.5
#     Episode 0, Reward: 9192.9
#     Episode 0, Reward: -3898.2
#     Episode 0, Reward: 6078.2
#     Episode 0, Reward: 5965.6
# Current scenario: ../data/Training/3ac-1000/Scenario_742
#     Episode 0, Reward: -1058.5
#     Episode 0, Reward: -2068.1
#     Episode 0, Reward: -4894.6
#     Episode 0, Reward: -5976.8
# Current scenario: ../data/Training/3ac-1000/Scenario_326
#     Episode 0, Reward: -759.7
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: -1894.8
#     Episode 0, Reward: -1985.5
#     Episode 0, Reward: -1965.9
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -3097.9
#     Episode 0, Reward: -4186.2
# Current scenario: ../data/Training/3ac-1000/Scenario_928
#     Episode 0, Reward: -1025.0
#     Episode 0, Reward: 8131.5
# Current scenario: ../data/Training/3ac-1000/Scenario_114
#     Episode 0, Reward: -796.5
#     Episode 0, Reward: -830.2
#     Episode 0, Reward: -1899.1
# Current scenario: ../data/Training/3ac-1000/Scenario_548
#     Episode 0, Reward: 9217.5
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -1883.8
#     Episode 0, Reward: -1960.6
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: -2026.3
#     Episode 0, Reward: 7830.0
# Current scenario: ../data/Training/3ac-1000/Scenario_910
#     Episode 0, Reward: -1773.1
#     Episode 0, Reward: -1839.1
#     Episode 0, Reward: -2875.9
#     Episode 0, Reward: 7010.7
#     Episode 0, Reward: 6964.4
# Current scenario: ../data/Training/3ac-1000/Scenario_113
#     Episode 0, Reward: -1060.0
#     Episode 0, Reward: -1845.2
#     Episode 0, Reward: 8070.0
#     Episode 0, Reward: 8014.799999999999
#     Episode 0, Reward: -2961.2
#     Episode 0, Reward: -4012.5
#     Episode 0, Reward: 5845.7
# Current scenario: ../data/Training/3ac-1000/Scenario_321
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1112.5
#     Episode 0, Reward: 6096.5
#     Episode 0, Reward: 5034.6
#     Episode 0, Reward: 4993.1
# Current scenario: ../data/Training/3ac-1000/Scenario_745
#     Episode 0, Reward: -1799.5
#     Episode 0, Reward: -2794.0
#     Episode 0, Reward: -3918.0
#     Episode 0, Reward: 6067.6
#     Episode 0, Reward: -4994.4
#     Episode 0, Reward: -6038.3
#     Episode 0, Reward: -7170.0
#     Episode 0, Reward: -9179.0
#     Episode 0, Reward: -10284.3
#     Episode 0, Reward: -339.6
# Current scenario: ../data/Training/3ac-1000/Scenario_577
#     Episode 0, Reward: -1768.7
#     Episode 0, Reward: -2870.0
#     Episode 0, Reward: -2868.1
#     Episode 0, Reward: -2947.3
#     Episode 0, Reward: -3993.7
#     Episode 0, Reward: -6038.8
# Current scenario: ../data/Training/3ac-1000/Scenario_583
#     Episode 0, Reward: -737.2
#     Episode 0, Reward: -1851.9
#     Episode 0, Reward: 8073.0
# Current scenario: ../data/Training/3ac-1000/Scenario_184
#     Episode 0, Reward: -1031.2
#     Episode 0, Reward: -2817.2
#     Episode 0, Reward: -3914.2
#     Episode 0, Reward: 6045.0
# Current scenario: ../data/Training/3ac-1000/Scenario_726
#     Episode 0, Reward: 9209.5
#     Episode 0, Reward: 9175.5
#     Episode 0, Reward: -841.2
#     Episode 0, Reward: 8041.0
#     Episode 0, Reward: -1973.2
#     Episode 0, Reward: -3061.6
#     Episode 0, Reward: -4170.0
# Current scenario: ../data/Training/3ac-1000/Scenario_514
#     Episode 0, Reward: 8354.9
#     Episode 0, Reward: -1775.5
#     Episode 0, Reward: 8084.299999999999
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -2017.8
#     Episode 0, Reward: -2109.6
#     Episode 0, Reward: -4159.8
# Current scenario: ../data/Training/3ac-1000/Scenario_170
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: 9172.4
# ...
#     Episode 0, Reward: -1954.6
#     Episode 0, Reward: -2040.4
#     Episode 0, Reward: -3075.0
#     Episode 0, Reward: 6864.4
#     Episode 0, Reward: 6780.8
# Current scenario: ../data/Training/3ac-1000/Scenario_422
#     Episode 0, Reward: -1020.2
#     Episode 0, Reward: -3086.3
#     Episode 0, Reward: -3928.5
#     Episode 0, Reward: -4943.7
#     Episode 0, Reward: -5050.0
#     Episode 0, Reward: -5110.0
#     Episode 0, Reward: -5170.0
#     Episode 0, Reward: 4808.1
#     Episode 0, Reward: -6271.6
#     Episode 0, Reward: -7301.2
# Current scenario: ../data/Training/3ac-1000/Scenario_40
#     Episode 0, Reward: 9200.5
#     Episode 0, Reward: -1848.7
#     Episode 0, Reward: -1894.2
#     Episode 0, Reward: -2935.7
#     Episode 0, Reward: -4037.1
# Current scenario: ../data/Training/3ac-1000/Scenario_274
#     Episode 0, Reward: -1052.5
#     Episode 0, Reward: -2066.7
#     Episode 0, Reward: -3147.1
#     Episode 0, Reward: -4240.0
# Current scenario: ../data/Training/3ac-1000/Scenario_628
#     Episode 0, Reward: -1003.3
#     Episode 0, Reward: -2063.0
#     Episode 0, Reward: -3153.0
#     Episode 0, Reward: -5174.5
#     Episode 0, Reward: 4325.9
#     Episode 0, Reward: -6079.1
#     Episode 0, Reward: -8116.1
# Current scenario: ../data/Training/3ac-1000/Scenario_842
#     Episode 0, Reward: -1052.5
#     Episode 0, Reward: -2115.5
#     Episode 0, Reward: -2877.2
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -5033.1
# Current scenario: ../data/Training/3ac-1000/Scenario_78
#     Episode 0, Reward: -1810.0
#     Episode 0, Reward: -2838.3
#     Episode 0, Reward: 6078.6
#     Episode 0, Reward: -3990.0
#     Episode 0, Reward: -5009.6
#     Episode 0, Reward: -5102.3
#     Episode 0, Reward: -5158.2
#     Episode 0, Reward: -6201.5
# Current scenario: ../data/Training/3ac-1000/Scenario_273
#     Episode 0, Reward: -760.3
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -2892.4
#     Episode 0, Reward: -2912.8
#     Episode 0, Reward: -5048.1
#     Episode 0, Reward: -5066.8
#     Episode 0, Reward: -5110.8
#     Episode 0, Reward: -6176.8
# Current scenario: ../data/Training/3ac-1000/Scenario_47
#     Episode 0, Reward: 9261.4
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: 8106.299999999999
#     Episode 0, Reward: -1922.9
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: -3098.1
# Current scenario: ../data/Training/3ac-1000/Scenario_425
#     Episode 0, Reward: 9255.0
#     Episode 0, Reward: -2796.2
#     Episode 0, Reward: -2890.3
#     Episode 0, Reward: -2953.9
#     Episode 0, Reward: -4019.9
#     Episode 0, Reward: -6106.5
# Current scenario: ../data/Training/3ac-1000/Scenario_617
#     Episode 0, Reward: -1011.9
#     Episode 0, Reward: 7186.8
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -2978.1
#     Episode 0, Reward: -4036.9
#     Episode 0, Reward: -5054.0
#     Episode 0, Reward: -6169.5
# Current scenario: ../data/Training/3ac-1000/Scenario_287
#     Episode 0, Reward: -1808.5
#     Episode 0, Reward: -2830.1
#     Episode 0, Reward: -2910.0
#     Episode 0, Reward: 7012.7
#     Episode 0, Reward: -4043.9
#     Episode 0, Reward: -4073.1
#     Episode 0, Reward: -4126.9
#     Episode 0, Reward: -6205.1
# Current scenario: ../data/Training/3ac-1000/Scenario_889
#     Episode 0, Reward: -1042.0
#     Episode 0, Reward: -1820.9
#     Episode 0, Reward: -2859.6
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -3050.0
#     Episode 0, Reward: -4110.0
# Current scenario: ../data/Training/3ac-1000/Scenario_874
#     Episode 0, Reward: -783.7
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: 8070.0
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -2978.6
# Current scenario: ../data/Training/3ac-1000/Scenario_880
#     Episode 0, Reward: -756.3
#     Episode 0, Reward: -2836.3
#     Episode 0, Reward: 6112.3
#     Episode 0, Reward: -4953.7
#     Episode 0, Reward: -7048.2
#     Episode 0, Reward: -7070.2
#     Episode 0, Reward: -8136.4
# Current scenario: ../data/Training/3ac-1000/Scenario_413
#     Episode 0, Reward: 9190.0
#     Episode 0, Reward: -840.4
#     Episode 0, Reward: 9110.2
#     Episode 0, Reward: -1955.8
#     Episode 0, Reward: -3050.0
#     Episode 0, Reward: -3017.3
#     Episode 0, Reward: -3170.0
#     Episode 0, Reward: -4162.8
#     Episode 0, Reward: -4218.8
#     Episode 0, Reward: -4338.8
#     Episode 0, Reward: -4410.0
#     Episode 0, Reward: -4407.8
#     Episode 0, Reward: -5492.8
# Current scenario: ../data/Training/3ac-1000/Scenario_621
#     Episode 0, Reward: -1049.5
#     Episode 0, Reward: -1805.8
#     Episode 0, Reward: -1907.8
#     Episode 0, Reward: -2990.0
# Current scenario: ../data/Training/3ac-1000/Scenario_245
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -837.8
#     Episode 0, Reward: -1924.0
#     Episode 0, Reward: 8052.299999999999
#     Episode 0, Reward: -1996.4
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -3113.3
#     Episode 0, Reward: 6770.8
# Current scenario: ../data/Training/3ac-1000/Scenario_71
#     Episode 0, Reward: 8207.9
#     Episode 0, Reward: -2813.5
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -2996.2
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: -3160.9
#     Episode 0, Reward: -4190.9
# Current scenario: ../data/Training/3ac-1000/Scenario_85
#     Episode 0, Reward: -767.5
#     Episode 0, Reward: 9173.7
#     Episode 0, Reward: -3918.0
#     Episode 0, Reward: 6069.8
#     Episode 0, Reward: -4050.0
#     Episode 0, Reward: -5061.1
#     Episode 0, Reward: -5170.0
#     Episode 0, Reward: -6201.1
#     Episode 0, Reward: -7290.0
# Current scenario: ../data/Training/3ac-1000/Scenario_289
#     Episode 0, Reward: -772.9
#     Episode 0, Reward: -2822.3
#     Episode 0, Reward: 7111.2
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -4050.0
# Current scenario: ../data/Training/3ac-1000/Scenario_887
#     Episode 0, Reward: -1031.1
#     Episode 0, Reward: -2835.2
#     Episode 0, Reward: -2930.0
# Current scenario: ../data/Training/3ac-1000/Scenario_619
#     Episode 0, Reward: -1799.5
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -2913.3
#     Episode 0, Reward: -3984.0
#     Episode 0, Reward: -3991.7
#     Episode 0, Reward: -5083.3
#     Episode 0, Reward: -6144.8
#     Episode 0, Reward: -6189.7
#     Episode 0, Reward: 3713.7
# Current scenario: ../data/Training/3ac-1000/Scenario_873
#     Episode 0, Reward: -756.7
#     Episode 0, Reward: -1787.3
#     Episode 0, Reward: -1930.0
# Current scenario: ../data/Training/3ac-1000/Scenario_49
#     Episode 0, Reward: 9217.2
#     Episode 0, Reward: -1862.5
#     Episode 0, Reward: -1900.3
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -3011.6
#     Episode 0, Reward: -3063.3
#     Episode 0, Reward: 6840.3
#     Episode 0, Reward: -4156.5
#     Episode 0, Reward: -5281.7
# Current scenario: ../data/Training/3ac-1000/Scenario_82
#     Episode 0, Reward: -804.0
#     Episode 0, Reward: -1814.3
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -2973.2
#     Episode 0, Reward: -2965.3
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: -4145.9
#     Episode 0, Reward: -4230.0
#     Episode 0, Reward: 5711.1
#     Episode 0, Reward: -4350.0
#     Episode 0, Reward: -4410.0
#     Episode 0, Reward: -5396.2
#     Episode 0, Reward: -5493.3
#     Episode 0, Reward: -6546.5
# Current scenario: ../data/Training/3ac-1000/Scenario_76
#     Episode 0, Reward: -742.1
#     Episode 0, Reward: -1832.8
#     Episode 0, Reward: -2903.3
# Current scenario: ../data/Training/3ac-1000/Scenario_242
#     Episode 0, Reward: -1025.1
#     Episode 0, Reward: -1120.0
#     Episode 0, Reward: -2125.7
#     Episode 0, Reward: 7013.0
#     Episode 0, Reward: -3006.7
#     Episode 0, Reward: -5080.3
#     Episode 0, Reward: -6130.3
#     Episode 0, Reward: -7226.9
#     Episode 0, Reward: -8290.0
# Current scenario: ../data/Training/3ac-1000/Scenario_626
#     Episode 0, Reward: -792.0
#     Episode 0, Reward: -841.7
#     Episode 0, Reward: 9134.8
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -3011.5
#     Episode 0, Reward: -3050.8
#     Episode 0, Reward: -4115.4
#     Episode 0, Reward: -5194.5
#     Episode 0, Reward: -6277.2
# Current scenario: ../data/Training/3ac-1000/Scenario_414
#     Episode 0, Reward: 9197.5
#     Episode 0, Reward: -855.3
#     Episode 0, Reward: -876.6
#     Episode 0, Reward: 9044.0
#     Episode 0, Reward: -2022.8
# Current scenario: ../data/Training/3ac-1000/Scenario_686
#     Episode 0, Reward: 9197.5
#     Episode 0, Reward: -855.5
#     Episode 0, Reward: -894.9
#     Episode 0, Reward: -1944.9
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: 7909.0
# Current scenario: ../data/Training/3ac-1000/Scenario_216
#     Episode 0, Reward: -1012.5
#     Episode 0, Reward: 8146.5
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -2947.1
#     Episode 0, Reward: -4026.0
#     Episode 0, Reward: 5932.5
# Current scenario: ../data/Training/3ac-1000/Scenario_22
#     Episode 0, Reward: -801.0
#     Episode 0, Reward: 9131.5
#     Episode 0, Reward: -917.0
#     Episode 0, Reward: 8028.5
#     Episode 0, Reward: -2031.6
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -2170.0
#     Episode 0, Reward: -2221.4
#     Episode 0, Reward: -2278.8
#     Episode 0, Reward: 7653.9
# Current scenario: ../data/Training/3ac-1000/Scenario_818
#     Episode 0, Reward: 9196.0
#     Episode 0, Reward: -846.4
#     Episode 0, Reward: -905.2
#     Episode 0, Reward: 9024.8
# Current scenario: ../data/Training/3ac-1000/Scenario_440
#     Episode 0, Reward: -810.0
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -2917.2
#     Episode 0, Reward: -2950.5
#     Episode 0, Reward: -3050.0
#     Episode 0, Reward: 6916.2
# Current scenario: ../data/Training/3ac-1000/Scenario_672
#     Episode 0, Reward: -1009.8
#     Episode 0, Reward: -2056.0
#     Episode 0, Reward: 6107.9
#     Episode 0, Reward: -4990.0
#     Episode 0, Reward: -4993.9
#     Episode 0, Reward: -5110.0
#     Episode 0, Reward: 4830.1
#     Episode 0, Reward: 4770.0
#     Episode 0, Reward: -6225.5
# Current scenario: ../data/Training/3ac-1000/Scenario_827
#     Episode 0, Reward: -739.8
#     Episode 0, Reward: 9146.5
#     Episode 0, Reward: -930.0
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -1974.6
#     Episode 0, Reward: -2062.0
#     Episode 0, Reward: -4125.9
# Current scenario: ../data/Training/3ac-1000/Scenario_229
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: 8153.700000000001
#     Episode 0, Reward: 8139.6
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -2994.9
#     Episode 0, Reward: -3074.7
#     Episode 0, Reward: -5080.4
#     Episode 0, Reward: -5165.5
#     Episode 0, Reward: -5233.9
#     Episode 0, Reward: -5299.9
#     Episode 0, Reward: -7345.8
# Current scenario: ../data/Training/3ac-1000/Scenario_675
#     Episode 0, Reward: 9200.5
#     Episode 0, Reward: -837.1
#     Episode 0, Reward: -844.1
#     Episode 0, Reward: 9069.5
#     Episode 0, Reward: -992.6
#     Episode 0, Reward: -1110.0
#     Episode 0, Reward: 8837.7
# Current scenario: ../data/Training/3ac-1000/Scenario_447
#     Episode 0, Reward: -692.4
#     Episode 0, Reward: -2764.6
#     Episode 0, Reward: -3907.8
# Current scenario: ../data/Training/3ac-1000/Scenario_25
#     Episode 0, Reward: 9190.0
#     Episode 0, Reward: -1833.7
#     Episode 0, Reward: -2872.4
# Current scenario: ../data/Training/3ac-1000/Scenario_211
#     Episode 0, Reward: -1773.4
#     Episode 0, Reward: -1837.9
#     Episode 0, Reward: 8092.299999999999
# Current scenario: ../data/Training/3ac-1000/Scenario_681
#     Episode 0, Reward: -991.4
#     Episode 0, Reward: -1120.0
#     Episode 0, Reward: -3137.4
#     Episode 0, Reward: 6026.9
# Current scenario: ../data/Training/3ac-1000/Scenario_820
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1120.0
#     Episode 0, Reward: -3132.2
#     Episode 0, Reward: -4221.4
#     Episode 0, Reward: 5046.3
#     Episode 0, Reward: -5101.8
#     Episode 0, Reward: -6139.7
# Current scenario: ../data/Training/3ac-1000/Scenario_478
#     Episode 0, Reward: -1040.5
#     Episode 0, Reward: 7197.1
#     Episode 0, Reward: 7110.3
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -2963.4
#     Episode 0, Reward: -4110.0
# Current scenario: ../data/Training/3ac-1000/Scenario_13
#     Episode 0, Reward: -769.8
#     Episode 0, Reward: -1821.9
#     Episode 0, Reward: -1871.9
#     Episode 0, Reward: -1948.6
#     Episode 0, Reward: -3998.6
# Current scenario: ../data/Training/3ac-1000/Scenario_829
#     Episode 0, Reward: -1058.5
#     Episode 0, Reward: -1120.0
#     Episode 0, Reward: -1912.1
#     Episode 0, Reward: -1932.9
#     Episode 0, Reward: -3050.0
#     Episode 0, Reward: -3031.6
#     Episode 0, Reward: -4158.7
#     Episode 0, Reward: -5215.0
# Current scenario: ../data/Training/3ac-1000/Scenario_227
#     Episode 0, Reward: -1804.0
#     Episode 0, Reward: -2826.3
#     Episode 0, Reward: -3887.7
#     Episode 0, Reward: -3990.0
#     Episode 0, Reward: -4024.7
#     Episode 0, Reward: -6109.5
# Current scenario: ../data/Training/3ac-1000/Scenario_643
#     Episode 0, Reward: -1028.2
#     Episode 0, Reward: 8167.200000000001
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -2937.0
#     Episode 0, Reward: -4000.2
# Current scenario: ../data/Training/3ac-1000/Scenario_471
#     Episode 0, Reward: -787.6
#     Episode 0, Reward: 9131.5
#     Episode 0, Reward: -930.0
#     Episode 0, Reward: -1987.6
#     Episode 0, Reward: -2996.0
#     Episode 0, Reward: -3090.4
#     Episode 0, Reward: -4135.7
# Current scenario: ../data/Training/3ac-1000/Scenario_485
#     Episode 0, Reward: -776.2
#     Episode 0, Reward: -855.0
#     Episode 0, Reward: -2856.8
#     Episode 0, Reward: 7010.0
#     Episode 0, Reward: -4028.8
#     Episode 0, Reward: -5059.9
#     Episode 0, Reward: -6138.7
# Current scenario: ../data/Training/3ac-1000/Scenario_218
#     Episode 0, Reward: 9194.5
#     Episode 0, Reward: -1802.5
#     Episode 0, Reward: 8112.4
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -3050.0
# Current scenario: ../data/Training/3ac-1000/Scenario_816
#     Episode 0, Reward: -774.4
#     Episode 0, Reward: -2821.7
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: 6991.5
#     Episode 0, Reward: -4068.2
#     Episode 0, Reward: -5138.2
# Current scenario: ../data/Training/3ac-1000/Scenario_688
#     Episode 0, Reward: 8190.0
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -2877.7
# Current scenario: ../data/Training/3ac-1000/Scenario_482
#     Episode 0, Reward: 9245.1
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -3975.0
#     Episode 0, Reward: 5954.0
# Current scenario: ../data/Training/3ac-1000/Scenario_476
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -832.2
#     Episode 0, Reward: -1914.9
#     Episode 0, Reward: -1946.2
#     Episode 0, Reward: -2974.0
#     Episode 0, Reward: -4110.0
#     Episode 0, Reward: -4104.9
#     Episode 0, Reward: -4170.9
#     Episode 0, Reward: -4290.0
#     Episode 0, Reward: -4302.9
#     Episode 0, Reward: -6394.0
# Current scenario: ../data/Training/3ac-1000/Scenario_644
#     Episode 0, Reward: -1060.0
#     Episode 0, Reward: -2066.3
#     Episode 0, Reward: -3172.9
# Current scenario: ../data/Training/3ac-1000/Scenario_220
#     Episode 0, Reward: -2025.2
#     Episode 0, Reward: -3112.5
#     Episode 0, Reward: -4180.0
#     Episode 0, Reward: -5187.2
#     Episode 0, Reward: 3957.8999999999996
#     Episode 0, Reward: 3926.6000000000004
# Current scenario: ../data/Training/3ac-1000/Scenario_14
#     Episode 0, Reward: -1021.1
#     Episode 0, Reward: -2852.7
#     Episode 0, Reward: -2891.8
# Current scenario: ../data/Training/3ac-1000/Scenario_811
#     Episode 0, Reward: -805.5
#     Episode 0, Reward: -1826.6
#     Episode 0, Reward: -2880.0
#     Episode 0, Reward: -3978.3
#     Episode 0, Reward: -4960.9
#     Episode 0, Reward: -5110.0
#     Episode 0, Reward: -6168.4
# Current scenario: ../data/Training/3ac-1000/Scenario_449
#     Episode 0, Reward: -1810.0
#     Episode 0, Reward: -1818.2
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -1967.9
#     Episode 0, Reward: 7955.799999999999
# myopic: (1/1) 0.03 best avg: -5448.76 - rewards avg: -5448.76
# Marked logs_id 0246 as finished in ../logs/ids.json
# Training log finalized and summary added to ../logs/training/training_0246.json
# Myopic rewards saved to ../results/dqn/20241203-19-29/rewards_myopic.pkl
# Good rewards saved to ../results/dqn/20241203-19-29/good_rewards_myopic.pkl
# Myopic model saved to
# ../trained_models/dqn/myopic-0246.zip

# %%
results_proactive = train_dqn_agent('proactive')

# Unpack the results
rewards_proactive, test_rewards_proactive, total_timesteps_proactive, epsilon_values_proactive, good_rewards_proactive, action_sequences_proactive, model_path_and_name_proactive = results_proactive

# Save the proactive rewards and good rewards
proactive_rewards_file = os.path.join(results_dir, "rewards_proactive.pkl")
good_rewards_file = os.path.join(results_dir, "good_rewards_proactive.pkl")
with open(proactive_rewards_file, "wb") as file:
    pickle.dump(rewards_proactive, file)
with open(good_rewards_file, "wb") as file:
    pickle.dump(good_rewards_proactive, file)
print(f"Proactive rewards saved to {proactive_rewards_file}")




end_time = datetime.now()
runtime = end_time - start_time
runtime_in_seconds = runtime.total_seconds()

print(good_rewards_myopic)
print(good_rewards_proactive)
# Out:
# Models will be saved to: ../trained_models/dqn/proactive-0247.zip
# Device: mps
# Using MacBook M1
# Logging to /var/folders/m6/gwyqzldd12bg_s3mrl40tp6r0000gn/T/SB3-2024-12-03-19-29-25-412949
# Current scenario: ../data/Training/3ac-1000/Scenario_264
#     Episode 0, Reward: -755.1
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -2915.8
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -3050.0
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: -4152.0
# Current scenario: ../data/Training/3ac-1000/Scenario_50
#     Episode 0, Reward: -1048.0
#     Episode 0, Reward: -2859.5
#     Episode 0, Reward: 7123.3
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: 6955.1
#     Episode 0, Reward: 6909.0
# Current scenario: ../data/Training/3ac-1000/Scenario_432
#     Episode 0, Reward: 9224.3
#     Episode 0, Reward: -820.5
#     Episode 0, Reward: 9074.5
#     Episode 0, Reward: -990.0
#     Episode 0, Reward: -996.0
#     Episode 0, Reward: -2090.2
# Current scenario: ../data/Training/3ac-1000/Scenario_600
#     Episode 0, Reward: -798.0
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: -1905.1
#     Episode 0, Reward: -1935.5
#     Episode 0, Reward: -1989.2
#     Episode 0, Reward: 7923.6
#     Episode 0, Reward: -2138.4
#     Episode 0, Reward: -3216.6
# Current scenario: ../data/Training/3ac-1000/Scenario_290
#     Episode 0, Reward: -1054.0
#     Episode 0, Reward: -2099.9
#     Episode 0, Reward: -2180.0
#     Episode 0, Reward: -3976.0
#     Episode 0, Reward: -5025.9
#     Episode 0, Reward: -5076.9
#     Episode 0, Reward: 4830.0
# Current scenario: ../data/Training/3ac-1000/Scenario_855
#     Episode 0, Reward: -762.2
#     Episode 0, Reward: -2808.4
#     Episode 0, Reward: -3930.0
#     Episode 0, Reward: 6063.0
#     Episode 0, Reward: -5050.0
#     Episode 0, Reward: -6109.2
#     Episode 0, Reward: -6170.0
#     Episode 0, Reward: -7222.6
# Current scenario: ../data/Training/3ac-1000/Scenario_899
#     Episode 0, Reward: -755.8
#     Episode 0, Reward: 9133.0
#     Episode 0, Reward: -1913.9
#     Episode 0, Reward: -2957.8
#     Episode 0, Reward: -4026.9
# Current scenario: ../data/Training/3ac-1000/Scenario_297
#     Episode 0, Reward: -989.0
#     Episode 0, Reward: 8166.4
#     Episode 0, Reward: -2927.0
# Current scenario: ../data/Training/3ac-1000/Scenario_607
#     Episode 0, Reward: 9229.4
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: -2871.0
# Current scenario: ../data/Training/3ac-1000/Scenario_435
#     Episode 0, Reward: -749.6
#     Episode 0, Reward: -2868.5
#     Episode 0, Reward: 7114.2
#     Episode 0, Reward: -2924.1
#     Episode 0, Reward: -3008.4
#     Episode 0, Reward: -4103.9
#     Episode 0, Reward: -6140.4
# Current scenario: ../data/Training/3ac-1000/Scenario_57
#     Episode 0, Reward: -1776.1
#     Episode 0, Reward: -2823.6
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -4027.0
#     Episode 0, Reward: -5107.2
#     Episode 0, Reward: -5170.0
#     Episode 0, Reward: -6167.6
# Current scenario: ../data/Training/3ac-1000/Scenario_263
#     Episode 0, Reward: -733.6
#     Episode 0, Reward: -839.2
#     Episode 0, Reward: 9071.5
#     Episode 0, Reward: 9051.4
#     Episode 0, Reward: -1050.0
#     Episode 0, Reward: -2105.5
#     Episode 0, Reward: -4158.8
# Current scenario: ../data/Training/3ac-1000/Scenario_852
#     Episode 0, Reward: 9220.8
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: 7112.5
#     Episode 0, Reward: -4961.2
# Current scenario: ../data/Training/3ac-1000/Scenario_68
#     Episode 0, Reward: 9222.6
#     Episode 0, Reward: -1796.9
#     Episode 0, Reward: -2913.0
# Current scenario: ../data/Training/3ac-1000/Scenario_638
#     Episode 0, Reward: -790.5
#     Episode 0, Reward: -832.9
#     Episode 0, Reward: -930.0
#     Episode 0, Reward: -1964.9
#     Episode 0, Reward: 7958.799999999999
#     Episode 0, Reward: -3100.2
#     Episode 0, Reward: -4124.8
#     Episode 0, Reward: -4140.1
#     Episode 0, Reward: -5206.1
# Current scenario: ../data/Training/3ac-1000/Scenario_95
#     Episode 0, Reward: -1054.0
#     Episode 0, Reward: -2090.7
#     Episode 0, Reward: -2180.0
#     Episode 0, Reward: -3207.2
#     Episode 0, Reward: -3300.0
#     Episode 0, Reward: -4339.8
# Current scenario: ../data/Training/3ac-1000/Scenario_61
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1120.0
#     Episode 0, Reward: -1930.0
# Current scenario: ../data/Training/3ac-1000/Scenario_255
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -835.5
#     Episode 0, Reward: -2852.6
#     Episode 0, Reward: -3961.7
#     Episode 0, Reward: -4050.0
#     Episode 0, Reward: 4922.9
#     Episode 0, Reward: -7149.4
#     Episode 0, Reward: -7230.0
#     Episode 0, Reward: -8239.5
#     Episode 0, Reward: 1676.6
#     Episode 0, Reward: -9369.0
# Current scenario: ../data/Training/3ac-1000/Scenario_631
#     Episode 0, Reward: -1761.6
#     Episode 0, Reward: -1838.7
#     Episode 0, Reward: -1885.1
#     Episode 0, Reward: -2923.7
#     Episode 0, Reward: -3989.7
#     Episode 0, Reward: -4052.6
#     Episode 0, Reward: -5118.6
# Current scenario: ../data/Training/3ac-1000/Scenario_403
#     Episode 0, Reward: -1741.9
#     Episode 0, Reward: -1802.1
#     Episode 0, Reward: -3920.0
#     Episode 0, Reward: -3963.5
#     Episode 0, Reward: -4976.5
#     Episode 0, Reward: 3940.1000000000004
#     Episode 0, Reward: -6170.0
#     Episode 0, Reward: 3780.3999999999996
#     Episode 0, Reward: -6285.6
#     Episode 0, Reward: -6350.0
#     Episode 0, Reward: -7372.6
# Current scenario: ../data/Training/3ac-1000/Scenario_890
#     Episode 0, Reward: -759.6
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -2974.6
#     Episode 0, Reward: 6990.1
#     Episode 0, Reward: 6898.0
# Current scenario: ../data/Training/3ac-1000/Scenario_864
#     Episode 0, Reward: -1769.6
#     Episode 0, Reward: -1826.9
#     Episode 0, Reward: -2898.4
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -5048.2
#     Episode 0, Reward: -7063.7
# Current scenario: ../data/Training/3ac-1000/Scenario_404
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -861.0
#     Episode 0, Reward: -1877.2
#     Episode 0, Reward: -1903.6
#     Episode 0, Reward: -4026.7
# Current scenario: ../data/Training/3ac-1000/Scenario_636
#     Episode 0, Reward: -735.4
#     Episode 0, Reward: 9169.4
#     Episode 0, Reward: -930.0
#     Episode 0, Reward: -1990.0
# Current scenario: ../data/Training/3ac-1000/Scenario_252
#     Episode 0, Reward: -1793.5
#     Episode 0, Reward: -1772.6
#     Episode 0, Reward: -2905.2
#     Episode 0, Reward: -3929.8
#     Episode 0, Reward: -4970.6
#     Episode 0, Reward: 4904.2
#     Episode 0, Reward: -5133.2
#     Episode 0, Reward: -5171.4
#     Episode 0, Reward: -6290.0
#     Episode 0, Reward: -6283.7
#     Episode 0, Reward: -6349.7
#     Episode 0, Reward: -6470.0
#     Episode 0, Reward: -7530.0
# Current scenario: ../data/Training/3ac-1000/Scenario_66
#     Episode 0, Reward: -799.5
#     Episode 0, Reward: -1847.1
#     Episode 0, Reward: -1883.4
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -1980.2
#     Episode 0, Reward: -4097.0
# Current scenario: ../data/Training/3ac-1000/Scenario_92
#     Episode 0, Reward: -989.2
#     Episode 0, Reward: 8136.0
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -1952.7
#     Episode 0, Reward: -2044.6
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: 6854.3
# Current scenario: ../data/Training/3ac-1000/Scenario_863
#     Episode 0, Reward: -740.8
#     Episode 0, Reward: -1832.0
#     Episode 0, Reward: -1927.0
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -3039.3
#     Episode 0, Reward: -4072.5
#     Episode 0, Reward: -4100.0
#     Episode 0, Reward: -4166.0
#     Episode 0, Reward: -5239.7
#     Episode 0, Reward: -5350.0
#     Episode 0, Reward: -6402.5
#     Episode 0, Reward: 3539.2
# Current scenario: ../data/Training/3ac-1000/Scenario_59
#     Episode 0, Reward: -753.6
#     Episode 0, Reward: -2861.0
#     Episode 0, Reward: -3843.5
#     Episode 0, Reward: -4981.4
#     Episode 0, Reward: -7035.5
#     Episode 0, Reward: -8078.7
#     Episode 0, Reward: -9139.3
#     Episode 0, Reward: 771.8
# Current scenario: ../data/Training/3ac-1000/Scenario_609
#     Episode 0, Reward: -745.8
#     Episode 0, Reward: -853.5
#     Episode 0, Reward: -2896.6
# Current scenario: ../data/Training/3ac-1000/Scenario_897
#     Episode 0, Reward: -1030.4
#     Episode 0, Reward: 8130.0
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: 8010.0
# Current scenario: ../data/Training/3ac-1000/Scenario_299
#     Episode 0, Reward: -1042.0
#     Episode 0, Reward: -2082.5
#     Episode 0, Reward: 7875.8
#     Episode 0, Reward: 7041.3
# Current scenario: ../data/Training/3ac-1000/Scenario_239
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: 9133.0
#     Episode 0, Reward: -918.1
#     Episode 0, Reward: -1948.0
#     Episode 0, Reward: 6979.1
# Current scenario: ../data/Training/3ac-1000/Scenario_837
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -120.0
#     Episode 0, Reward: -1905.4
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -1977.9
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -3170.0
# Current scenario: ../data/Training/3ac-1000/Scenario_662
#     Episode 0, Reward: -1016.8
#     Episode 0, Reward: -2831.6
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: 7035.1
# Current scenario: ../data/Training/3ac-1000/Scenario_450
#     Episode 0, Reward: -1021.2
#     Episode 0, Reward: 8178.6
#     Episode 0, Reward: -2876.1
#     Episode 0, Reward: 7019.4
# Current scenario: ../data/Training/3ac-1000/Scenario_32
#     Episode 0, Reward: 9232.5
#     Episode 0, Reward: 9189.6
#     Episode 0, Reward: -1888.1
# Current scenario: ../data/Training/3ac-1000/Scenario_808
#     Episode 0, Reward: -1984.6
#     Episode 0, Reward: -2817.6
#     Episode 0, Reward: -2907.5
#     Episode 0, Reward: -2957.0
#     Episode 0, Reward: -2981.8
#     Episode 0, Reward: -5063.4
# Current scenario: ../data/Training/3ac-1000/Scenario_206
#     Episode 0, Reward: -1756.4
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: 8082.200000000001
# Current scenario: ../data/Training/3ac-1000/Scenario_696
#     Episode 0, Reward: -1758.7
#     Episode 0, Reward: 8185.9
#     Episode 0, Reward: -1872.5
#     Episode 0, Reward: -1953.8
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: -3054.6
# Current scenario: ../data/Training/3ac-1000/Scenario_468
#     Episode 0, Reward: -770.9
#     Episode 0, Reward: 9140.5
#     Episode 0, Reward: 9117.9
#     Episode 0, Reward: -919.2
#     Episode 0, Reward: -981.1
#     Episode 0, Reward: -2035.9
#     Episode 0, Reward: -3146.1
# Current scenario: ../data/Training/3ac-1000/Scenario_830
#     Episode 0, Reward: -1032.6
#     Episode 0, Reward: 8131.5
#     Episode 0, Reward: -1890.5
#     Episode 0, Reward: 8065.299999999999
#     Episode 0, Reward: -1984.2
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -2170.0
#     Episode 0, Reward: -2230.0
#     Episode 0, Reward: -3290.0
# Current scenario: ../data/Training/3ac-1000/Scenario_691
#     Episode 0, Reward: -996.9
#     Episode 0, Reward: -3089.5
#     Episode 0, Reward: -4180.0
#     Episode 0, Reward: 4810.2
#     Episode 0, Reward: 3969.5
# Current scenario: ../data/Training/3ac-1000/Scenario_201
#     Episode 0, Reward: -766.9
#     Episode 0, Reward: -832.3
#     Episode 0, Reward: 8089.700000000001
#     Episode 0, Reward: -1916.0
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: -2048.0
#     Episode 0, Reward: 7850.6
# Current scenario: ../data/Training/3ac-1000/Scenario_35
#     Episode 0, Reward: 9223.6
#     Episode 0, Reward: -845.6
#     Episode 0, Reward: -1877.8
#     Episode 0, Reward: -2943.7
#     Episode 0, Reward: 7007.1
# Current scenario: ../data/Training/3ac-1000/Scenario_457
#     Episode 0, Reward: -796.5
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: 8091.0
# Current scenario: ../data/Training/3ac-1000/Scenario_665
#     Episode 0, Reward: -804.0
#     Episode 0, Reward: -2857.9
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: 7046.7
#     Episode 0, Reward: -4015.6
# Current scenario: ../data/Training/3ac-1000/Scenario_698
#     Episode 0, Reward: 9191.5
#     Episode 0, Reward: -1841.2
#     Episode 0, Reward: -2889.9
#     Episode 0, Reward: -3957.1
# Current scenario: ../data/Training/3ac-1000/Scenario_806
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -853.5
#     Episode 0, Reward: -904.6
#     Episode 0, Reward: -1941.9
# Current scenario: ../data/Training/3ac-1000/Scenario_208
#     Episode 0, Reward: -1038.1
#     Episode 0, Reward: -2111.0
#     Episode 0, Reward: 7091.3
#     Episode 0, Reward: 7048.9
# Current scenario: ../data/Training/3ac-1000/Scenario_495
#     Episode 0, Reward: -1784.7
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -2914.8
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -4050.0
# Current scenario: ../data/Training/3ac-1000/Scenario_461
#     Episode 0, Reward: -1799.5
#     Episode 0, Reward: -2843.0
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -2976.0
#     Episode 0, Reward: -4033.1
#     Episode 0, Reward: -5083.6
# Current scenario: ../data/Training/3ac-1000/Scenario_653
#     Episode 0, Reward: -1995.9
#     Episode 0, Reward: 7152.2
#     Episode 0, Reward: -3903.2
#     Episode 0, Reward: -3990.0
#     Episode 0, Reward: -4050.0
#     Episode 0, Reward: -4110.0
#     Episode 0, Reward: -5165.7
# Current scenario: ../data/Training/3ac-1000/Scenario_237
#     Episode 0, Reward: -1030.2
#     Episode 0, Reward: -2830.9
#     Episode 0, Reward: -2925.5
#     Episode 0, Reward: 7010.0
#     Episode 0, Reward: -3014.0
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: -3118.2
#     Episode 0, Reward: -3230.0
#     Episode 0, Reward: -3290.0
#     Episode 0, Reward: -4350.0
# Current scenario: ../data/Training/3ac-1000/Scenario_03
#     Episode 0, Reward: -799.5
#     Episode 0, Reward: -1826.1
#     Episode 0, Reward: -1914.3
#     Episode 0, Reward: -2924.2
#     Episode 0, Reward: -2999.9
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: -4168.9
#     Episode 0, Reward: -4163.6
#     Episode 0, Reward: -4229.6
#     Episode 0, Reward: 5658.9
# Current scenario: ../data/Training/3ac-1000/Scenario_839
#     Episode 0, Reward: -805.5
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -1862.5
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -3050.0
# Current scenario: ../data/Training/3ac-1000/Scenario_459
#     Episode 0, Reward: 9190.0
#     Episode 0, Reward: 9130.0
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -3950.3
#     Episode 0, Reward: 5950.0
# Current scenario: ../data/Training/3ac-1000/Scenario_801
#     Episode 0, Reward: 9193.0
#     Episode 0, Reward: -859.7
#     Episode 0, Reward: 9109.9
#     Episode 0, Reward: 8065.4
# Current scenario: ../data/Training/3ac-1000/Scenario_04
#     Episode 0, Reward: -744.9
#     Episode 0, Reward: -1861.0
#     Episode 0, Reward: 8076.0
# Current scenario: ../data/Training/3ac-1000/Scenario_230
#     Episode 0, Reward: -1054.0
#     Episode 0, Reward: 7155.1
#     Episode 0, Reward: -2898.7
# Current scenario: ../data/Training/3ac-1000/Scenario_654
#     Episode 0, Reward: -1760.6
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -3895.3
#     Episode 0, Reward: 5056.4
#     Episode 0, Reward: 4955.3
#     Episode 0, Reward: -6095.5
#     Episode 0, Reward: -7140.0
#     Episode 0, Reward: 2779.0
# Current scenario: ../data/Training/3ac-1000/Scenario_466
#     Episode 0, Reward: -1747.2
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -2901.8
#     Episode 0, Reward: -2964.8
#     Episode 0, Reward: -5030.5
# Current scenario: ../data/Training/3ac-1000/Scenario_492
#     Episode 0, Reward: 9217.6
#     Episode 0, Reward: -1867.0
#     Episode 0, Reward: -1876.1
#     Episode 0, Reward: -1967.6
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -3135.8
#     Episode 0, Reward: -3230.0
#     Episode 0, Reward: 6722.1
# Current scenario: ../data/Training/3ac-1000/Scenario_93
#     Episode 0, Reward: 9199.0
#     Episode 0, Reward: -1849.8
#     Episode 0, Reward: -2917.3
# Current scenario: ../data/Training/3ac-1000/Scenario_637
#     Episode 0, Reward: -623.5
#     Episode 0, Reward: -683.5
#     Episode 0, Reward: 7132.7
#     Episode 0, Reward: -3915.8
#     Episode 0, Reward: -3993.8
#     Episode 0, Reward: 5906.4
#     Episode 0, Reward: -4170.0
#     Episode 0, Reward: -4230.0
#     Episode 0, Reward: -4253.7
#     Episode 0, Reward: -6288.4
# Current scenario: ../data/Training/3ac-1000/Scenario_405
#     Episode 0, Reward: -780.6
#     Episode 0, Reward: -1833.8
#     Episode 0, Reward: -4897.7
#     Episode 0, Reward: 5021.4
#     Episode 0, Reward: 4984.5
#     Episode 0, Reward: -5110.0
#     Episode 0, Reward: -6108.7
# Current scenario: ../data/Training/3ac-1000/Scenario_67
#     Episode 0, Reward: -92.8
#     Episode 0, Reward: -2199.0
#     Episode 0, Reward: -2917.7
#     Episode 0, Reward: -3958.2
#     Episode 0, Reward: 5950.0
# Current scenario: ../data/Training/3ac-1000/Scenario_253
#     Episode 0, Reward: -768.7
#     Episode 0, Reward: -1813.5
#     Episode 0, Reward: 8074.5
#     Episode 0, Reward: -2937.7
#     Episode 0, Reward: -2971.7
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: -4170.0
#     Episode 0, Reward: -4193.0
#     Episode 0, Reward: -4218.2
#     Episode 0, Reward: -5301.7
#     Episode 0, Reward: -6350.2
# Current scenario: ../data/Training/3ac-1000/Scenario_298
#     Episode 0, Reward: -743.2
#     Episode 0, Reward: -1795.0
#     Episode 0, Reward: -2880.6
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -4031.5
#     Episode 0, Reward: -4078.6
#     Episode 0, Reward: -5127.7
# Current scenario: ../data/Training/3ac-1000/Scenario_896
#     Episode 0, Reward: -776.5
#     Episode 0, Reward: 9171.2
#     Episode 0, Reward: -1930.0
# Current scenario: ../data/Training/3ac-1000/Scenario_58
#     Episode 0, Reward: 9197.5
#     Episode 0, Reward: -853.5
#     Episode 0, Reward: -930.0
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -3020.3
#     Episode 0, Reward: 6913.1
# Current scenario: ../data/Training/3ac-1000/Scenario_862
#     Episode 0, Reward: -795.0
#     Episode 0, Reward: -1828.5
#     Episode 0, Reward: -2882.1
#     Episode 0, Reward: -3974.6
# Current scenario: ../data/Training/3ac-1000/Scenario_608
#     Episode 0, Reward: 9206.5
#     Episode 0, Reward: 9168.7
#     Episode 0, Reward: 9124.0
# Current scenario: ../data/Training/3ac-1000/Scenario_254
#     Episode 0, Reward: -1775.6
#     Episode 0, Reward: -1862.5
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -3944.9
#     Episode 0, Reward: -6017.3
#     Episode 0, Reward: -7110.0
#     Episode 0, Reward: -7170.0
#     Episode 0, Reward: -7185.3
#     Episode 0, Reward: -9230.2
# Current scenario: ../data/Training/3ac-1000/Scenario_60
#     Episode 0, Reward: 9227.9
#     Episode 0, Reward: -1824.1
#     Episode 0, Reward: -1930.0
# Current scenario: ../data/Training/3ac-1000/Scenario_402
#     Episode 0, Reward: 8219.6
#     Episode 0, Reward: -2855.2
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -2956.2
#     Episode 0, Reward: -3050.0
#     Episode 0, Reward: -4103.2
#     Episode 0, Reward: 5855.7
# Current scenario: ../data/Training/3ac-1000/Scenario_630
#     Episode 0, Reward: -1030.9
#     Episode 0, Reward: 8201.2
#     Episode 0, Reward: -3928.5
#     Episode 0, Reward: -4905.6
#     Episode 0, Reward: 4984.4
#     Episode 0, Reward: -5037.6
#     Episode 0, Reward: -6167.8
# Current scenario: ../data/Training/3ac-1000/Scenario_94
#     Episode 0, Reward: -2025.1
#     Episode 0, Reward: 7169.4
#     Episode 0, Reward: 7082.4
# Current scenario: ../data/Training/3ac-1000/Scenario_865
#     Episode 0, Reward: -2017.9
#     Episode 0, Reward: -3098.0
#     Episode 0, Reward: -4132.3
#     Episode 0, Reward: -4240.0
#     Episode 0, Reward: -5250.3
# Current scenario: ../data/Training/3ac-1000/Scenario_891
#     Episode 0, Reward: -1015.4
#     Episode 0, Reward: -1859.5
#     Episode 0, Reward: -2860.8
#     Episode 0, Reward: -4969.1
# Current scenario: ../data/Training/3ac-1000/Scenario_434
#     Episode 0, Reward: -799.5
#     Episode 0, Reward: -1867.0
#     Episode 0, Reward: -1825.9
#     Episode 0, Reward: -1977.5
#     Episode 0, Reward: 7979.0
#     Episode 0, Reward: -3110.0
# Current scenario: ../data/Training/3ac-1000/Scenario_606
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1050.5
#     Episode 0, Reward: -1930.0
# Current scenario: ../data/Training/3ac-1000/Scenario_262
#     Episode 0, Reward: -85.3
#     Episode 0, Reward: 9198.3
#     Episode 0, Reward: -2895.5
#     Episode 0, Reward: 7013.0
#     Episode 0, Reward: 6963.1
#     Episode 0, Reward: -3037.0
#     Episode 0, Reward: -4144.7
#     Episode 0, Reward: 5772.8
# Current scenario: ../data/Training/3ac-1000/Scenario_56
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1118.5
#     Episode 0, Reward: -1573.0
#     Episode 0, Reward: -2681.7
# Current scenario: ../data/Training/3ac-1000/Scenario_296
#     Episode 0, Reward: 9271.3
#     Episode 0, Reward: -791.9
#     Episode 0, Reward: -2885.5
#     Episode 0, Reward: -3950.8
#     Episode 0, Reward: -5046.2
#     Episode 0, Reward: -5110.0
#     Episode 0, Reward: -7148.5
# Current scenario: ../data/Training/3ac-1000/Scenario_898
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1839.9
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -2979.7
# Current scenario: ../data/Training/3ac-1000/Scenario_69
#     Episode 0, Reward: -755.9
#     Episode 0, Reward: -868.5
#     Episode 0, Reward: -2878.1
#     Episode 0, Reward: -2901.8
#     Episode 0, Reward: -3022.9
#     Episode 0, Reward: -4062.9
#     Episode 0, Reward: -5170.0
#     Episode 0, Reward: 4782.5
# Current scenario: ../data/Training/3ac-1000/Scenario_853
#     Episode 0, Reward: -760.4
#     Episode 0, Reward: -1862.5
#     Episode 0, Reward: -3908.2
#     Episode 0, Reward: -3952.4
#     Episode 0, Reward: 5950.0
#     Episode 0, Reward: -5012.1
#     Episode 0, Reward: 4832.6
#     Episode 0, Reward: -5143.2
#     Episode 0, Reward: -5210.1
#     Episode 0, Reward: 4650.0
# Current scenario: ../data/Training/3ac-1000/Scenario_639
#     Episode 0, Reward: -1060.0
#     Episode 0, Reward: -1849.3
#     Episode 0, Reward: -2888.0
# Current scenario: ../data/Training/3ac-1000/Scenario_291
#     Episode 0, Reward: 9202.0
#     Episode 0, Reward: -1823.7
#     Episode 0, Reward: -1890.7
# Current scenario: ../data/Training/3ac-1000/Scenario_51
#     Episode 0, Reward: 9229.6
#     Episode 0, Reward: -1822.6
#     Episode 0, Reward: -2909.7
#     Episode 0, Reward: 7010.0
# Current scenario: ../data/Training/3ac-1000/Scenario_265
#     Episode 0, Reward: -1018.8
#     Episode 0, Reward: -2115.5
#     Episode 0, Reward: -2894.7
# Current scenario: ../data/Training/3ac-1000/Scenario_601
#     Episode 0, Reward: -756.6
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -1862.1
#     Episode 0, Reward: -3963.3
#     Episode 0, Reward: 5998.9
# Current scenario: ../data/Training/3ac-1000/Scenario_433
#     Episode 0, Reward: -735.8
#     Episode 0, Reward: -2819.8
#     Episode 0, Reward: -2844.0
#     Episode 0, Reward: -2924.6
#     Episode 0, Reward: 6965.5
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: -4143.7
# Current scenario: ../data/Training/3ac-1000/Scenario_854
#     Episode 0, Reward: -801.0
#     Episode 0, Reward: 9130.0
#     Episode 0, Reward: -1913.5
#     Episode 0, Reward: -2960.7
#     Episode 0, Reward: -4040.0
#     Episode 0, Reward: -5077.4
# Current scenario: ../data/Training/3ac-1000/Scenario_458
#     Episode 0, Reward: -1798.0
#     Episode 0, Reward: 8170.9
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -1977.1
#     Episode 0, Reward: 6950.0
#     Episode 0, Reward: -4110.0
# Current scenario: ../data/Training/3ac-1000/Scenario_800
#     Episode 0, Reward: 9199.0
#     Episode 0, Reward: -829.3
#     Episode 0, Reward: -1912.7
#     Episode 0, Reward: -2961.3
#     Episode 0, Reward: -4014.5
#     Episode 0, Reward: 5890.3
#     Episode 0, Reward: -4170.0
#     Episode 0, Reward: 5774.8
#     Episode 0, Reward: -4249.7
#     Episode 0, Reward: -4350.0
#     Episode 0, Reward: 5592.8
# Current scenario: ../data/Training/3ac-1000/Scenario_493
#     Episode 0, Reward: -795.0
#     Episode 0, Reward: 9216.6
#     Episode 0, Reward: -930.0
#     Episode 0, Reward: -2937.7
#     Episode 0, Reward: -4043.0
#     Episode 0, Reward: -4033.8
#     Episode 0, Reward: -4142.6
#     Episode 0, Reward: -4151.6
#     Episode 0, Reward: -5278.2
# Current scenario: ../data/Training/3ac-1000/Scenario_231
#     Episode 0, Reward: 8206.6
#     Episode 0, Reward: -2835.6
#     Episode 0, Reward: 7123.0
# Current scenario: ../data/Training/3ac-1000/Scenario_05
#     Episode 0, Reward: -732.6
#     Episode 0, Reward: -1847.4
#     Episode 0, Reward: 8073.0
#     Episode 0, Reward: -2904.1
#     Episode 0, Reward: -3025.6
#     Episode 0, Reward: -5080.7
# Current scenario: ../data/Training/3ac-1000/Scenario_467
#     Episode 0, Reward: -755.8
#     Episode 0, Reward: 8194.5
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -2924.2
#     Episode 0, Reward: 6962.6
#     Episode 0, Reward: -4069.5
# Current scenario: ../data/Training/3ac-1000/Scenario_655
#     Episode 0, Reward: 9219.5
#     Episode 0, Reward: -2790.8
#     Episode 0, Reward: -3897.7
#     Episode 0, Reward: -3958.8
#     Episode 0, Reward: -5013.8
# Current scenario: ../data/Training/3ac-1000/Scenario_209
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: 9131.5
#     Episode 0, Reward: -2884.3
#     Episode 0, Reward: -2973.1
#     Episode 0, Reward: -2994.9
#     Episode 0, Reward: 5896.7
# Current scenario: ../data/Training/3ac-1000/Scenario_807
#     Episode 0, Reward: -802.5
#     Episode 0, Reward: -1838.0
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -1894.8
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: -2096.1
#     Episode 0, Reward: -3170.0
# Current scenario: ../data/Training/3ac-1000/Scenario_699
#     Episode 0, Reward: -1750.8
#     Episode 0, Reward: -1798.8
#     Episode 0, Reward: 8113.0
#     Episode 0, Reward: -2923.3
#     Episode 0, Reward: -4017.7
# Current scenario: ../data/Training/3ac-1000/Scenario_652
#     Episode 0, Reward: 9191.5
#     Episode 0, Reward: 9146.2
#     Episode 0, Reward: -1892.9
# Current scenario: ../data/Training/3ac-1000/Scenario_460
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1086.8
#     Episode 0, Reward: 8070.0
#     Episode 0, Reward: -2974.6
#     Episode 0, Reward: -3998.5
#     Episode 0, Reward: -5110.0
#     Episode 0, Reward: -5170.0
#     Episode 0, Reward: -5221.7
#     Episode 0, Reward: -7251.3
# Current scenario: ../data/Training/3ac-1000/Scenario_838
#     Episode 0, Reward: -977.4
#     Episode 0, Reward: 7172.8
#     Episode 0, Reward: -4916.1
# Current scenario: ../data/Training/3ac-1000/Scenario_02
#     Episode 0, Reward: 19190.0
#     Episode 0, Reward: -842.4
#     Episode 0, Reward: -1854.3
#     Episode 0, Reward: -2990.0
# Current scenario: ../data/Training/3ac-1000/Scenario_236
#     Episode 0, Reward: -792.0
#     Episode 0, Reward: -1827.6
#     Episode 0, Reward: -1908.3
#     Episode 0, Reward: -1939.1
#     Episode 0, Reward: -2991.5
#     Episode 0, Reward: -3027.5
#     Episode 0, Reward: -3170.0
#     Episode 0, Reward: -4188.9
#     Episode 0, Reward: -5209.1
#     Episode 0, Reward: -6350.0
# Current scenario: ../data/Training/3ac-1000/Scenario_494
#     Episode 0, Reward: 8214.6
#     Episode 0, Reward: 8187.299999999999
#     Episode 0, Reward: -1867.1
#     Episode 0, Reward: -1967.7
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -2145.3
#     Episode 0, Reward: -3230.0
# Current scenario: ../data/Training/3ac-1000/Scenario_469
#     Episode 0, Reward: -771.0
#     Episode 0, Reward: -1840.4
#     Episode 0, Reward: -4884.5
#     Episode 0, Reward: -4979.3
#     Episode 0, Reward: -5017.4
#     Episode 0, Reward: -6071.5
#     Episode 0, Reward: -7170.0
# Current scenario: ../data/Training/3ac-1000/Scenario_831
#     Episode 0, Reward: 9213.3
#     Episode 0, Reward: -1796.2
#     Episode 0, Reward: -1930.0
# Current scenario: ../data/Training/3ac-1000/Scenario_34
#     Episode 0, Reward: -1018.1
#     Episode 0, Reward: -2106.5
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: 6027.8
#     Episode 0, Reward: -4997.6
#     Episode 0, Reward: -5053.9
#     Episode 0, Reward: -5170.0
#     Episode 0, Reward: -5185.9
#     Episode 0, Reward: -5287.1
#     Episode 0, Reward: -5350.0
#     Episode 0, Reward: -6410.0
# Current scenario: ../data/Training/3ac-1000/Scenario_200
#     Episode 0, Reward: -1042.0
#     Episode 0, Reward: -1808.1
#     Episode 0, Reward: -3872.3
#     Episode 0, Reward: -5970.0
# Current scenario: ../data/Training/3ac-1000/Scenario_664
#     Episode 0, Reward: -973.8
#     Episode 0, Reward: -1822.9
#     Episode 0, Reward: -3885.4
#     Episode 0, Reward: -3930.5
#     Episode 0, Reward: -5046.6
# Current scenario: ../data/Training/3ac-1000/Scenario_456
#     Episode 0, Reward: -2025.2
#     Episode 0, Reward: -3099.4
#     Episode 0, Reward: -5125.9
#     Episode 0, Reward: -5968.7
#     Episode 0, Reward: -6960.9
#     Episode 0, Reward: -8082.0
#     Episode 0, Reward: 1843.0
# Current scenario: ../data/Training/3ac-1000/Scenario_690
#     Episode 0, Reward: 9491.5
#     Episode 0, Reward: -1803.0
#     Episode 0, Reward: -1893.1
# Current scenario: ../data/Training/3ac-1000/Scenario_836
#     Episode 0, Reward: -804.0
#     Episode 0, Reward: -840.9
#     Episode 0, Reward: -870.4
#     Episode 0, Reward: -2905.8
#     Episode 0, Reward: 7000.1
#     Episode 0, Reward: 6901.7
# Current scenario: ../data/Training/3ac-1000/Scenario_238
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -832.0
#     Episode 0, Reward: 8098.0
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: 7927.6
# Current scenario: ../data/Training/3ac-1000/Scenario_697
#     Episode 0, Reward: -1802.5
#     Episode 0, Reward: -2805.4
#     Episode 0, Reward: -3863.6
#     Episode 0, Reward: -4971.5
#     Episode 0, Reward: -6005.4
#     Episode 0, Reward: 3901.0
# Current scenario: ../data/Training/3ac-1000/Scenario_451
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -835.1
#     Episode 0, Reward: -1902.7
#     Episode 0, Reward: -1989.7
#     Episode 0, Reward: -3015.3
#     Episode 0, Reward: -3103.9
#     Episode 0, Reward: -4138.0
#     Episode 0, Reward: 5775.2
# Current scenario: ../data/Training/3ac-1000/Scenario_663
#     Episode 0, Reward: 9250.1
#     Episode 0, Reward: -835.8
#     Episode 0, Reward: -2866.2
#     Episode 0, Reward: -2947.9
#     Episode 0, Reward: -3989.1
# Current scenario: ../data/Training/3ac-1000/Scenario_207
#     Episode 0, Reward: -1060.0
#     Episode 0, Reward: -2080.0
#     Episode 0, Reward: -2180.0
#     Episode 0, Reward: -2240.0
#     Episode 0, Reward: -3045.5
#     Episode 0, Reward: -4041.5
# Current scenario: ../data/Training/3ac-1000/Scenario_809
#     Episode 0, Reward: -987.4
#     Episode 0, Reward: -2848.7
#     Episode 0, Reward: -3901.6
# Current scenario: ../data/Training/3ac-1000/Scenario_33
#     Episode 0, Reward: -771.0
#     Episode 0, Reward: -1839.3
#     Episode 0, Reward: 8073.0
#     Episode 0, Reward: -2942.8
#     Episode 0, Reward: -3040.6
#     Episode 0, Reward: -4074.9
# Current scenario: ../data/Training/3ac-1000/Scenario_375
#     Episode 0, Reward: -417.9
#     Episode 0, Reward: -2480.2
#     Episode 0, Reward: 7104.8
#     Episode 0, Reward: -2967.5
#     Episode 0, Reward: -3984.7
#     Episode 0, Reward: -4099.5
#     Episode 0, Reward: -4098.8
#     Episode 0, Reward: -4164.8
#     Episode 0, Reward: -4290.0
#     Episode 0, Reward: -5339.9
#     Episode 0, Reward: 4607.3
# Current scenario: ../data/Training/3ac-1000/Scenario_147
#     Episode 0, Reward: -1058.5
#     Episode 0, Reward: -1842.7
#     Episode 0, Reward: 7074.7
#     Episode 0, Reward: -2944.2
#     Episode 0, Reward: -4044.6
#     Episode 0, Reward: -4110.0
#     Episode 0, Reward: 5836.2
#     Episode 0, Reward: -6176.9
#     Episode 0, Reward: -7249.9
#     Episode 0, Reward: -7350.0
#     Episode 0, Reward: 2603.9
# Current scenario: ../data/Training/3ac-1000/Scenario_523
#     Episode 0, Reward: 9190.0
#     Episode 0, Reward: 9177.6
#     Episode 0, Reward: -882.2
#     Episode 0, Reward: -2943.9
# Current scenario: ../data/Training/3ac-1000/Scenario_711
#     Episode 0, Reward: -2034.5
#     Episode 0, Reward: -4070.7
#     Episode 0, Reward: -5164.9
#     Episode 0, Reward: 4818.5
#     Episode 0, Reward: -6040.5
#     Episode 0, Reward: -6044.4
#     Episode 0, Reward: -6170.0
#     Episode 0, Reward: -7176.4
#     Episode 0, Reward: -7261.5
#     Episode 0, Reward: -8298.0
# Current scenario: ../data/Training/3ac-1000/Scenario_381
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -2090.5
#     Episode 0, Reward: -2180.0
#     Episode 0, Reward: -3220.5
#     Episode 0, Reward: -4269.7
#     Episode 0, Reward: -5073.1
#     Episode 0, Reward: -5170.0
#     Episode 0, Reward: -6208.2
# Current scenario: ../data/Training/3ac-1000/Scenario_178
#     Episode 0, Reward: -989.1
#     Episode 0, Reward: -1800.2
#     Episode 0, Reward: -1885.8
#     Episode 0, Reward: -2990.0
# Current scenario: ../data/Training/3ac-1000/Scenario_944
#     Episode 0, Reward: -792.0
#     Episode 0, Reward: -1839.2
#     Episode 0, Reward: -2867.7
#     Episode 0, Reward: -4960.5
# Current scenario: ../data/Training/3ac-1000/Scenario_988
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1825.6
#     Episode 0, Reward: -2916.2
#     Episode 0, Reward: -3990.0
# Current scenario: ../data/Training/3ac-1000/Scenario_386
#     Episode 0, Reward: -766.3
#     Episode 0, Reward: -1802.7
#     Episode 0, Reward: -3894.5
#     Episode 0, Reward: 6036.4
#     Episode 0, Reward: -5029.6
#     Episode 0, Reward: -5065.2
#     Episode 0, Reward: -5170.0
#     Episode 0, Reward: -5162.8
#     Episode 0, Reward: -5290.0
#     Episode 0, Reward: 4656.6
# Current scenario: ../data/Training/3ac-1000/Scenario_716
#     Episode 0, Reward: -2023.3
#     Episode 0, Reward: 7153.6
#     Episode 0, Reward: -2880.0
# Current scenario: ../data/Training/3ac-1000/Scenario_524
#     Episode 0, Reward: -761.7
#     Episode 0, Reward: -1804.5
#     Episode 0, Reward: -3883.4
#     Episode 0, Reward: 6021.9
# Current scenario: ../data/Training/3ac-1000/Scenario_140
#     Episode 0, Reward: -1787.9
#     Episode 0, Reward: -2868.5
#     Episode 0, Reward: -3827.6
#     Episode 0, Reward: -3958.0
#     Episode 0, Reward: 4976.8
# Current scenario: ../data/Training/3ac-1000/Scenario_372
#     Episode 0, Reward: -805.5
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -2923.7
#     Episode 0, Reward: 7056.0
#     Episode 0, Reward: 6950.0
#     Episode 0, Reward: -4110.0
# Current scenario: ../data/Training/3ac-1000/Scenario_943
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1798.3
#     Episode 0, Reward: -1906.3
#     Episode 0, Reward: 6032.8
#     Episode 0, Reward: -4050.0
#     Episode 0, Reward: -4063.7
#     Episode 0, Reward: -5165.2
#     Episode 0, Reward: -5163.0
#     Episode 0, Reward: -5290.0
#     Episode 0, Reward: -6328.6
# Current scenario: ../data/Training/3ac-1000/Scenario_729
#     Episode 0, Reward: -742.4
#     Episode 0, Reward: -790.8
#     Episode 0, Reward: -903.2
#     Episode 0, Reward: -1990.0
# Current scenario: ../data/Training/3ac-1000/Scenario_182
#     Episode 0, Reward: -786.3
#     Episode 0, Reward: 7181.9
#     Episode 0, Reward: -3874.9
#     Episode 0, Reward: 6016.7
#     Episode 0, Reward: 4969.7
#     Episode 0, Reward: -6096.3
#     Episode 0, Reward: -6092.2
#     Episode 0, Reward: 3778.1000000000004
#     Episode 0, Reward: 3736.5
#     Episode 0, Reward: 3675.3
# Current scenario: ../data/Training/3ac-1000/Scenario_176
#     Episode 0, Reward: -1060.0
#     Episode 0, Reward: -1120.0
#     Episode 0, Reward: -2129.9
#     Episode 0, Reward: -3941.6
#     Episode 0, Reward: -4015.0
#     Episode 0, Reward: -4110.0
#     Episode 0, Reward: -5159.0
# Current scenario: ../data/Training/3ac-1000/Scenario_344
#     Episode 0, Reward: -805.5
#     Episode 0, Reward: -1825.7
#     Episode 0, Reward: 8121.700000000001
#     Episode 0, Reward: 8030.4
# Current scenario: ../data/Training/3ac-1000/Scenario_720
#     Episode 0, Reward: -2038.1
#     Episode 0, Reward: -3048.9
#     Episode 0, Reward: -5122.9
#     Episode 0, Reward: -5240.0
#     Episode 0, Reward: 3982.3999999999996
#     Episode 0, Reward: -8110.0
#     Episode 0, Reward: -8170.0
#     Episode 0, Reward: 1783.3000000000002
# Current scenario: ../data/Training/3ac-1000/Scenario_512
#     Episode 0, Reward: -1756.5
#     Episode 0, Reward: -1848.2
#     Episode 0, Reward: -3897.3
#     Episode 0, Reward: -3990.0
#     Episode 0, Reward: 4953.1
#     Episode 0, Reward: -5068.3
#     Episode 0, Reward: -6128.2
#     Episode 0, Reward: 3776.7
# Current scenario: ../data/Training/3ac-1000/Scenario_981
#     Episode 0, Reward: 9223.6
#     Episode 0, Reward: -1856.5
#     Episode 0, Reward: -3843.0
#     Episode 0, Reward: 6063.6
#     Episode 0, Reward: -4050.0
#     Episode 0, Reward: 5906.7
#     Episode 0, Reward: 5852.1
# Current scenario: ../data/Training/3ac-1000/Scenario_149
#     Episode 0, Reward: -2029.0
#     Episode 0, Reward: -2120.0
#     Episode 0, Reward: -3915.2
#     Episode 0, Reward: -4981.9
# Current scenario: ../data/Training/3ac-1000/Scenario_975
#     Episode 0, Reward: -1810.0
#     Episode 0, Reward: -1856.1
#     Episode 0, Reward: -2897.4
#     Episode 0, Reward: -2933.5
#     Episode 0, Reward: -4989.9
#     Episode 0, Reward: -5027.0
#     Episode 0, Reward: 4839.4
#     Episode 0, Reward: -5230.0
#     Episode 0, Reward: 4730.5
#     Episode 0, Reward: -6350.0
# Current scenario: ../data/Training/3ac-1000/Scenario_515
#     Episode 0, Reward: -1037.5
#     Episode 0, Reward: -2088.2
#     Episode 0, Reward: -2889.4
#     Episode 0, Reward: -3960.0
#     Episode 0, Reward: 5966.5
# Current scenario: ../data/Training/3ac-1000/Scenario_727
#     Episode 0, Reward: 9190.0
#     Episode 0, Reward: -870.0
# Current scenario: ../data/Training/3ac-1000/Scenario_343
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: 9187.2
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -2988.3
#     Episode 0, Reward: -3004.9
#     Episode 0, Reward: -4110.0
#     Episode 0, Reward: -4158.7
#     Episode 0, Reward: -4224.8
#     Episode 0, Reward: -5290.0
# Current scenario: ../data/Training/3ac-1000/Scenario_171
#     Episode 0, Reward: 8252.9
#     Episode 0, Reward: 8150.200000000001
#     Episode 0, Reward: -2901.6
#     Episode 0, Reward: -2948.1
#     Episode 0, Reward: -3002.4
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: -3170.0
#     Episode 0, Reward: -4193.6
# Current scenario: ../data/Training/3ac-1000/Scenario_185
#     Episode 0, Reward: -1009.2
#     Episode 0, Reward: -2071.9
#     Episode 0, Reward: -3930.0
#     Episode 0, Reward: 6024.5
#     Episode 0, Reward: -4010.0
#     Episode 0, Reward: -5061.3
# Current scenario: ../data/Training/3ac-1000/Scenario_972
#     Episode 0, Reward: -754.1
#     Episode 0, Reward: -806.3
#     Episode 0, Reward: 7103.3
#     Episode 0, Reward: -2962.7
#     Episode 0, Reward: -3986.3
# Current scenario: ../data/Training/3ac-1000/Scenario_718
#     Episode 0, Reward: -777.9
#     Episode 0, Reward: -1822.3
#     Episode 0, Reward: -1867.3
#     Episode 0, Reward: 8010.0
# Current scenario: ../data/Training/3ac-1000/Scenario_986
#     Episode 0, Reward: -1025.8
#     Episode 0, Reward: -1823.1
#     Episode 0, Reward: 8077.5
#     Episode 0, Reward: -1979.3
#     Episode 0, Reward: -2992.5
#     Episode 0, Reward: -3002.6
#     Episode 0, Reward: -4091.0
#     Episode 0, Reward: 4790.5
# Current scenario: ../data/Training/3ac-1000/Scenario_388
#     Episode 0, Reward: -1676.8
#     Episode 0, Reward: -1836.9
#     Episode 0, Reward: 7098.5
#     Episode 0, Reward: 7013.3
# Current scenario: ../data/Training/3ac-1000/Scenario_328
#     Episode 0, Reward: 9209.5
#     Episode 0, Reward: -816.6
#     Episode 0, Reward: -873.6
#     Episode 0, Reward: -917.2
#     Episode 0, Reward: -1025.5
#     Episode 0, Reward: -1110.0
#     Episode 0, Reward: -1151.7
#     Episode 0, Reward: -2141.6
# Current scenario: ../data/Training/3ac-1000/Scenario_926
#     Episode 0, Reward: -2033.0
#     Episode 0, Reward: -3091.3
#     Episode 0, Reward: -3885.1
# Current scenario: ../data/Training/3ac-1000/Scenario_773
#     Episode 0, Reward: -755.6
#     Episode 0, Reward: -2824.2
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -2956.9
#     Episode 0, Reward: -4050.0
# Current scenario: ../data/Training/3ac-1000/Scenario_541
#     Episode 0, Reward: -787.5
#     Episode 0, Reward: 9143.5
#     Episode 0, Reward: -922.5
#     Episode 0, Reward: -1950.3
#     Episode 0, Reward: -3026.1
#     Episode 0, Reward: -3089.4
#     Episode 0, Reward: -4155.4
#     Episode 0, Reward: -5150.5
#     Episode 0, Reward: -5239.2
#     Episode 0, Reward: -5282.5
#     Episode 0, Reward: -5370.9
#     Episode 0, Reward: -5461.0
#     Episode 0, Reward: -6502.9
# Current scenario: ../data/Training/3ac-1000/Scenario_919
#     Episode 0, Reward: -757.8
#     Episode 0, Reward: -1843.7
#     Episode 0, Reward: -2859.0
# Current scenario: ../data/Training/3ac-1000/Scenario_125
#     Episode 0, Reward: 9206.5
#     Episode 0, Reward: -802.5
#     Episode 0, Reward: -894.9
#     Episode 0, Reward: 9047.3
#     Episode 0, Reward: -1042.6
#     Episode 0, Reward: -1071.9
#     Episode 0, Reward: -2116.7
# Current scenario: ../data/Training/3ac-1000/Scenario_317
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1082.1
#     Episode 0, Reward: -2164.5
#     Episode 0, Reward: -3240.0
#     Episode 0, Reward: -3300.0
#     Episode 0, Reward: -4336.9
#     Episode 0, Reward: -5139.7
#     Episode 0, Reward: 4794.4
# Current scenario: ../data/Training/3ac-1000/Scenario_787
#     Episode 0, Reward: -994.6
#     Episode 0, Reward: 7152.7
#     Episode 0, Reward: -2924.2
#     Episode 0, Reward: 7040.5
# Current scenario: ../data/Training/3ac-1000/Scenario_579
#     Episode 0, Reward: -789.0
#     Episode 0, Reward: -835.0
#     Episode 0, Reward: -921.0
#     Episode 0, Reward: -2935.4
#     Episode 0, Reward: -3032.6
#     Episode 0, Reward: 6913.0
# Current scenario: ../data/Training/3ac-1000/Scenario_921
#     Episode 0, Reward: -759.4
#     Episode 0, Reward: -1830.7
#     Episode 0, Reward: -1921.5
#     Episode 0, Reward: -2936.2
# Current scenario: ../data/Training/3ac-1000/Scenario_780
#     Episode 0, Reward: -1001.9
#     Episode 0, Reward: 8139.0
#     Episode 0, Reward: -2925.5
#     Episode 0, Reward: 7030.0
#     Episode 0, Reward: -2985.3
#     Episode 0, Reward: -3082.1
#     Episode 0, Reward: 6853.7
# Current scenario: ../data/Training/3ac-1000/Scenario_310
#     Episode 0, Reward: -792.0
#     Episode 0, Reward: 9136.0
#     Episode 0, Reward: -863.2
#     Episode 0, Reward: 19010.0
# Current scenario: ../data/Training/3ac-1000/Scenario_122
#     Episode 0, Reward: -808.5
#     Episode 0, Reward: -2797.8
#     Episode 0, Reward: -4875.1
#     Episode 0, Reward: -5949.0
#     Episode 0, Reward: 3950.0
#     Episode 0, Reward: -7110.0
# Current scenario: ../data/Training/3ac-1000/Scenario_546
#     Episode 0, Reward: -2044.8
#     Episode 0, Reward: -2120.0
#     Episode 0, Reward: -5145.1
# Current scenario: ../data/Training/3ac-1000/Scenario_774
#     Episode 0, Reward: -796.5
#     Episode 0, Reward: -851.7
#     Episode 0, Reward: -1904.0
# Current scenario: ../data/Training/3ac-1000/Scenario_789
#     Episode 0, Reward: -2000.7
#     Episode 0, Reward: -2120.0
#     Episode 0, Reward: -2381.8
# Current scenario: ../data/Training/3ac-1000/Scenario_917
#     Episode 0, Reward: -735.0
#     Episode 0, Reward: -1837.4
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -2961.1
#     Episode 0, Reward: 6902.2
#     Episode 0, Reward: -4155.5
#     Episode 0, Reward: -5207.9
# Current scenario: ../data/Training/3ac-1000/Scenario_319
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: 8183.799999999999
#     Episode 0, Reward: -2896.4
#     Episode 0, Reward: -2949.2
#     Episode 0, Reward: -3998.0
#     Episode 0, Reward: 5895.4
#     Episode 0, Reward: -4092.5
#     Episode 0, Reward: -4158.5
#     Episode 0, Reward: -5204.6
#     Episode 0, Reward: 4650.0
# Current scenario: ../data/Training/3ac-1000/Scenario_584
#     Episode 0, Reward: 9191.5
#     Episode 0, Reward: -812.1
#     Episode 0, Reward: -922.5
#     Episode 0, Reward: -990.0
#     Episode 0, Reward: -3019.2
# Current scenario: ../data/Training/3ac-1000/Scenario_570
#     Episode 0, Reward: 9229.6
#     Episode 0, Reward: 9210.2
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -2964.2
#     Episode 0, Reward: -3045.2
#     Episode 0, Reward: 6928.9
# Current scenario: ../data/Training/3ac-1000/Scenario_742
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: 9276.4
#     Episode 0, Reward: -1878.4
#     Episode 0, Reward: -1960.6
#     Episode 0, Reward: -3010.4
#     Episode 0, Reward: -4110.0
# Current scenario: ../data/Training/3ac-1000/Scenario_326
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: 9167.8
#     Episode 0, Reward: -1921.0
# Current scenario: ../data/Training/3ac-1000/Scenario_928
#     Episode 0, Reward: 9225.0
#     Episode 0, Reward: -1797.7
# Current scenario: ../data/Training/3ac-1000/Scenario_114
#     Episode 0, Reward: -764.2
#     Episode 0, Reward: -833.1
#     Episode 0, Reward: -1888.2
# Current scenario: ../data/Training/3ac-1000/Scenario_548
#     Episode 0, Reward: -1028.9
#     Episode 0, Reward: -3068.4
#     Episode 0, Reward: -4164.5
#     Episode 0, Reward: 5793.1
# Current scenario: ../data/Training/3ac-1000/Scenario_910
#     Episode 0, Reward: -1060.0
#     Episode 0, Reward: 8162.4
#     Episode 0, Reward: -1854.8
#     Episode 0, Reward: -3969.6
# Current scenario: ../data/Training/3ac-1000/Scenario_113
#     Episode 0, Reward: -2029.2
#     Episode 0, Reward: 7146.8
#     Episode 0, Reward: 7070.0
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -3037.1
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: 6845.7
# Current scenario: ../data/Training/3ac-1000/Scenario_321
#     Episode 0, Reward: -810.0
#     Episode 0, Reward: -799.9
#     Episode 0, Reward: -1928.5
#     Episode 0, Reward: -1963.9
#     Episode 0, Reward: -2031.4
#     Episode 0, Reward: -3072.9
#     Episode 0, Reward: -4120.5
# Current scenario: ../data/Training/3ac-1000/Scenario_745
#     Episode 0, Reward: -2033.7
#     Episode 0, Reward: -3101.2
#     Episode 0, Reward: -4884.6
#     Episode 0, Reward: -4990.0
#     Episode 0, Reward: -5995.5
#     Episode 0, Reward: -6110.0
#     Episode 0, Reward: -6126.4
#     Episode 0, Reward: 3774.8
#     Episode 0, Reward: -6290.0
#     Episode 0, Reward: -7310.6
#     Episode 0, Reward: -7359.0
#     Episode 0, Reward: 2530.0
# Current scenario: ../data/Training/3ac-1000/Scenario_577
#     Episode 0, Reward: 9191.5
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: -930.0
#     Episode 0, Reward: -921.9
#     Episode 0, Reward: -2024.6
# Current scenario: ../data/Training/3ac-1000/Scenario_583
#     Episode 0, Reward: -1052.5
#     Episode 0, Reward: -1803.2
#     Episode 0, Reward: -2840.9
# Current scenario: ../data/Training/3ac-1000/Scenario_184
#     Episode 0, Reward: 9218.8
#     Episode 0, Reward: 9134.5
#     Episode 0, Reward: -849.5
#     Episode 0, Reward: -982.7
#     Episode 0, Reward: -1010.9
#     Episode 0, Reward: -1074.9
#     Episode 0, Reward: 8847.0
# Current scenario: ../data/Training/3ac-1000/Scenario_726
#     Episode 0, Reward: -1021.9
#     Episode 0, Reward: -1120.0
#     Episode 0, Reward: 8077.5
#     Episode 0, Reward: -2926.8
#     Episode 0, Reward: 6950.0
#     Episode 0, Reward: 6909.0
#     Episode 0, Reward: 6830.0
# Current scenario: ../data/Training/3ac-1000/Scenario_514
#     Episode 0, Reward: -1753.8
#     Episode 0, Reward: 18130.0
#     Episode 0, Reward: -3863.0
#     Episode 0, Reward: -4974.1
#     Episode 0, Reward: -5050.0
#     Episode 0, Reward: -6110.0
#     Episode 0, Reward: -8143.0
# Current scenario: ../data/Training/3ac-1000/Scenario_170
#     Episode 0, Reward: 9223.6
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: -2928.5
#     Episode 0, Reward: 7042.4
#     Episode 0, Reward: 6974.4
#     Episode 0, Reward: 6897.3
#     Episode 0, Reward: -3170.0
#     Episode 0, Reward: -3230.0
#     Episode 0, Reward: -4275.0
# Current scenario: ../data/Training/3ac-1000/Scenario_342
#     Episode 0, Reward: -1043.5
#     Episode 0, Reward: -1815.9
#     Episode 0, Reward: -2925.5
#     Episode 0, Reward: -2941.4
#     Episode 0, Reward: -3038.9
#     Episode 0, Reward: -4110.0
#     Episode 0, Reward: -4151.6
#     Episode 0, Reward: -4180.7
#     Episode 0, Reward: -5290.0
# Current scenario: ../data/Training/3ac-1000/Scenario_389
#     Episode 0, Reward: -735.1
#     Episode 0, Reward: -1851.9
#     Episode 0, Reward: -1930.0
# Current scenario: ../data/Training/3ac-1000/Scenario_987
#     Episode 0, Reward: -992.7
#     Episode 0, Reward: 8254.9
#     Episode 0, Reward: -1889.4
#     Episode 0, Reward: -3972.5
# Current scenario: ../data/Training/3ac-1000/Scenario_973
#     Episode 0, Reward: -741.7
#     Episode 0, Reward: -865.5
#     Episode 0, Reward: -851.1
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -2004.3
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -2158.9
#     Episode 0, Reward: -3230.0
# Current scenario: ../data/Training/3ac-1000/Scenario_719
#     Episode 0, Reward: -789.0
#     Episode 0, Reward: -1844.2
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -3032.8
#     Episode 0, Reward: -4046.5
#     Episode 0, Reward: -5155.7
#     Episode 0, Reward: -6196.2
#     Episode 0, Reward: -7270.3
#     Episode 0, Reward: 2658.6
# Current scenario: ../data/Training/3ac-1000/Scenario_345
# ...
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -2170.0
#     Episode 0, Reward: -3166.8
# Current scenario: ../data/Training/3ac-1000/Scenario_628
#     Episode 0, Reward: 9209.5
#     Episode 0, Reward: 9210.9
#     Episode 0, Reward: -1873.6
#     Episode 0, Reward: -1918.1
#     Episode 0, Reward: -2022.7
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -3170.0
#     Episode 0, Reward: -4169.0
#     Episode 0, Reward: -4248.1
#     Episode 0, Reward: -5301.0
#     Episode 0, Reward: -6409.1
# Current scenario: ../data/Training/3ac-1000/Scenario_842
#     Episode 0, Reward: -769.1
#     Episode 0, Reward: -1835.1
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -1967.1
#     Episode 0, Reward: -3050.0
# Current scenario: ../data/Training/3ac-1000/Scenario_78
#     Episode 0, Reward: -2039.4
#     Episode 0, Reward: -2857.7
#     Episode 0, Reward: -2892.1
#     Episode 0, Reward: -2978.8
#     Episode 0, Reward: -3999.9
#     Episode 0, Reward: -4077.3
#     Episode 0, Reward: -5127.6
#     Episode 0, Reward: 4774.4
# Current scenario: ../data/Training/3ac-1000/Scenario_273
#     Episode 0, Reward: -1035.9
#     Episode 0, Reward: -2850.1
#     Episode 0, Reward: -3930.0
#     Episode 0, Reward: -3990.0
#     Episode 0, Reward: -4004.7
#     Episode 0, Reward: -4110.0
#     Episode 0, Reward: -4170.0
#     Episode 0, Reward: -5230.0
#     Episode 0, Reward: 4711.7
# Current scenario: ../data/Training/3ac-1000/Scenario_47
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -120.0
#     Episode 0, Reward: -2921.0
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: 5961.3
#     Episode 0, Reward: -5043.2
#     Episode 0, Reward: -5166.6
#     Episode 0, Reward: -5196.4
#     Episode 0, Reward: -7266.6
# Current scenario: ../data/Training/3ac-1000/Scenario_425
#     Episode 0, Reward: -755.9
#     Episode 0, Reward: -2809.2
#     Episode 0, Reward: 7123.0
#     Episode 0, Reward: -2943.0
#     Episode 0, Reward: -3046.3
#     Episode 0, Reward: -4106.5
# Current scenario: ../data/Training/3ac-1000/Scenario_617
#     Episode 0, Reward: -742.9
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -1880.0
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -2987.1
#     Episode 0, Reward: -3102.9
#     Episode 0, Reward: -4121.8
#     Episode 0, Reward: -4230.0
#     Episode 0, Reward: -4290.0
#     Episode 0, Reward: -5294.9
#     Episode 0, Reward: 4592.8
# Current scenario: ../data/Training/3ac-1000/Scenario_287
#     Episode 0, Reward: -1526.7
#     Episode 0, Reward: -1830.1
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -2987.3
#     Episode 0, Reward: -3042.0
#     Episode 0, Reward: -3109.9
#     Episode 0, Reward: -4100.7
#     Episode 0, Reward: -5230.0
# Current scenario: ../data/Training/3ac-1000/Scenario_889
#     Episode 0, Reward: -1042.0
#     Episode 0, Reward: -2093.0
#     Episode 0, Reward: -4109.6
# Current scenario: ../data/Training/3ac-1000/Scenario_874
#     Episode 0, Reward: -1003.2
#     Episode 0, Reward: -2870.0
#     Episode 0, Reward: 7082.5
#     Episode 0, Reward: -2983.5
#     Episode 0, Reward: 6980.4
# Current scenario: ../data/Training/3ac-1000/Scenario_880
#     Episode 0, Reward: 9196.0
#     Episode 0, Reward: -856.0
#     Episode 0, Reward: -2872.4
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -4015.7
#     Episode 0, Reward: 5924.7
#     Episode 0, Reward: -6079.8
#     Episode 0, Reward: 3782.3
# Current scenario: ../data/Training/3ac-1000/Scenario_413
#     Episode 0, Reward: -1808.5
#     Episode 0, Reward: -1810.8
#     Episode 0, Reward: -1892.3
#     Episode 0, Reward: -2879.8
#     Episode 0, Reward: -4023.3
#     Episode 0, Reward: 5912.2
#     Episode 0, Reward: -4170.0
#     Episode 0, Reward: -4230.0
#     Episode 0, Reward: -5257.2
#     Episode 0, Reward: -5275.8
#     Episode 0, Reward: -5410.0
#     Episode 0, Reward: 4539.5
# Current scenario: ../data/Training/3ac-1000/Scenario_621
#     Episode 0, Reward: -745.3
#     Episode 0, Reward: -797.3
#     Episode 0, Reward: -856.7
#     Episode 0, Reward: 9010.0
# Current scenario: ../data/Training/3ac-1000/Scenario_245
#     Episode 0, Reward: -728.6
#     Episode 0, Reward: 9166.8
#     Episode 0, Reward: 8118.299999999999
# Current scenario: ../data/Training/3ac-1000/Scenario_71
#     Episode 0, Reward: -1808.5
#     Episode 0, Reward: -1806.6
#     Episode 0, Reward: -2879.5
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -3044.3
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: -4132.0
#     Episode 0, Reward: -5230.0
# Current scenario: ../data/Training/3ac-1000/Scenario_85
#     Episode 0, Reward: -765.8
#     Episode 0, Reward: -805.1
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: 7016.0
#     Episode 0, Reward: 6975.7
#     Episode 0, Reward: -3090.3
#     Episode 0, Reward: -3170.0
#     Episode 0, Reward: -4155.4
#     Episode 0, Reward: 5728.0
#     Episode 0, Reward: -4350.0
#     Episode 0, Reward: -4375.9
#     Episode 0, Reward: -4419.4
#     Episode 0, Reward: -5489.6
#     Episode 0, Reward: -5551.4
#     Episode 0, Reward: -5617.4
#     Episode 0, Reward: -7683.4
# Current scenario: ../data/Training/3ac-1000/Scenario_289
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: 9130.0
#     Episode 0, Reward: -925.5
#     Episode 0, Reward: -953.2
#     Episode 0, Reward: -1976.8
#     Episode 0, Reward: -2053.6
#     Episode 0, Reward: -4152.8
# Current scenario: ../data/Training/3ac-1000/Scenario_887
#     Episode 0, Reward: -1006.2
#     Episode 0, Reward: -3115.5
#     Episode 0, Reward: -3180.0
#     Episode 0, Reward: -3967.2
#     Episode 0, Reward: 5954.9
# Current scenario: ../data/Training/3ac-1000/Scenario_619
#     Episode 0, Reward: -1748.8
#     Episode 0, Reward: -2824.3
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -4050.0
# Current scenario: ../data/Training/3ac-1000/Scenario_873
#     Episode 0, Reward: 9200.5
#     Episode 0, Reward: -1790.1
#     Episode 0, Reward: -2922.3
# Current scenario: ../data/Training/3ac-1000/Scenario_49
#     Episode 0, Reward: -1013.7
#     Episode 0, Reward: -2813.6
#     Episode 0, Reward: -2930.0
#     Episode 0, Reward: -3934.9
#     Episode 0, Reward: 4982.3
#     Episode 0, Reward: -5040.9
#     Episode 0, Reward: -5092.6
#     Episode 0, Reward: -6194.4
# Current scenario: ../data/Training/3ac-1000/Scenario_82
#     Episode 0, Reward: -810.0
#     Episode 0, Reward: 8144.799999999999
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -3012.3
#     Episode 0, Reward: -4105.2
#     Episode 0, Reward: -4170.0
#     Episode 0, Reward: -4215.5
#     Episode 0, Reward: 5711.1
#     Episode 0, Reward: -4350.0
#     Episode 0, Reward: -5390.1
# Current scenario: ../data/Training/3ac-1000/Scenario_76
#     Episode 0, Reward: -793.5
#     Episode 0, Reward: -811.8
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -1969.3
#     Episode 0, Reward: -2974.9
#     Episode 0, Reward: -3041.6
#     Episode 0, Reward: -3143.8
#     Episode 0, Reward: -4230.0
# Current scenario: ../data/Training/3ac-1000/Scenario_242
#     Episode 0, Reward: 9211.0
#     Episode 0, Reward: 9177.2
#     Episode 0, Reward: -930.0
#     Episode 0, Reward: -990.0
#     Episode 0, Reward: -2028.6
#     Episode 0, Reward: -3107.2
# Current scenario: ../data/Training/3ac-1000/Scenario_626
#     Episode 0, Reward: -810.0
#     Episode 0, Reward: -836.5
#     Episode 0, Reward: 9134.8
#     Episode 0, Reward: -1916.1
#     Episode 0, Reward: -2039.7
#     Episode 0, Reward: -2105.7
#     Episode 0, Reward: -2114.1
#     Episode 0, Reward: -2209.5
#     Episode 0, Reward: -4277.2
# Current scenario: ../data/Training/3ac-1000/Scenario_414
#     Episode 0, Reward: -1032.8
#     Episode 0, Reward: 8131.5
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -1987.3
#     Episode 0, Reward: -1960.2
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -2170.0
#     Episode 0, Reward: -3206.6
#     Episode 0, Reward: -4290.0
# Current scenario: ../data/Training/3ac-1000/Scenario_686
#     Episode 0, Reward: -810.0
#     Episode 0, Reward: 8145.0
#     Episode 0, Reward: -1866.1
#     Episode 0, Reward: -1990.0
#     Episode 0, Reward: -2022.6
#     Episode 0, Reward: -2087.1
#     Episode 0, Reward: -2106.8
#     Episode 0, Reward: -2230.0
#     Episode 0, Reward: -3251.1
# Current scenario: ../data/Training/3ac-1000/Scenario_216
#     Episode 0, Reward: 9212.5
#     Episode 0, Reward: 9196.5
#     Episode 0, Reward: -930.0
#     Episode 0, Reward: -1982.3
#     Episode 0, Reward: -1997.9
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -3129.6
#     Episode 0, Reward: -5221.3
# Current scenario: ../data/Training/3ac-1000/Scenario_22
#     Episode 0, Reward: -801.0
#     Episode 0, Reward: -1838.5
#     Episode 0, Reward: 8115.9
#     Episode 0, Reward: -3961.9
#     Episode 0, Reward: -4017.7
#     Episode 0, Reward: -5062.4
#     Episode 0, Reward: -6169.5
# Current scenario: ../data/Training/3ac-1000/Scenario_818
#     Episode 0, Reward: -780.4
#     Episode 0, Reward: 9130.0
#     Episode 0, Reward: 8090.799999999999
#     Episode 0, Reward: -2980.9
#     Episode 0, Reward: -4023.1
# Current scenario: ../data/Training/3ac-1000/Scenario_440
#     Episode 0, Reward: -750.4
#     Episode 0, Reward: 8180.200000000001
#     Episode 0, Reward: -1919.5
#     Episode 0, Reward: -2922.5
#     Episode 0, Reward: 6950.8
# Current scenario: ../data/Training/3ac-1000/Scenario_672
#     Episode 0, Reward: 9239.9
#     Episode 0, Reward: -1825.8
#     Episode 0, Reward: -3924.0
#     Episode 0, Reward: -4958.1
#     Episode 0, Reward: -5050.0
#     Episode 0, Reward: -5050.7
#     Episode 0, Reward: -5116.7
#     Episode 0, Reward: -5202.0
#     Episode 0, Reward: -5290.0
#     Episode 0, Reward: -6308.6
#     Episode 0, Reward: -7403.7
# Current scenario: ../data/Training/3ac-1000/Scenario_827
#     Episode 0, Reward: -787.5
#     Episode 0, Reward: -805.8
#     Episode 0, Reward: -841.0
#     Episode 0, Reward: -2916.4
#     Episode 0, Reward: -3030.8
#     Episode 0, Reward: -3110.0
#     Episode 0, Reward: 6832.4
# Current scenario: ../data/Training/3ac-1000/Scenario_229
#     Episode 0, Reward: -718.5
#     Episode 0, Reward: 9133.0
#     Episode 0, Reward: -921.0
#     Episode 0, Reward: -899.8
#     Episode 0, Reward: -2031.4
#     Episode 0, Reward: -2071.9
#     Episode 0, Reward: 6857.7
#     Episode 0, Reward: -3163.8
#     Episode 0, Reward: -3290.0
#     Episode 0, Reward: -4329.4
#     Episode 0, Reward: -5351.8
#     Episode 0, Reward: -5440.3
#     Episode 0, Reward: -6506.3
#     Episode 0, Reward: -7590.0
# Current scenario: ../data/Training/3ac-1000/Scenario_675
#     Episode 0, Reward: -746.2
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -1910.1
#     Episode 0, Reward: -1972.8
#     Episode 0, Reward: -1965.6
#     Episode 0, Reward: -2110.0
#     Episode 0, Reward: -2170.0
#     Episode 0, Reward: -3193.8
#     Episode 0, Reward: -3216.7
#     Episode 0, Reward: -3263.2
#     Episode 0, Reward: -4392.5
# Current scenario: ../data/Training/3ac-1000/Scenario_447
#     Episode 0, Reward: -1045.0
#     Episode 0, Reward: -2836.6
#     Episode 0, Reward: -2902.6
# Current scenario: ../data/Training/3ac-1000/Scenario_25
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1076.2
#     Episode 0, Reward: 8070.0
# Current scenario: ../data/Training/3ac-1000/Scenario_211
#     Episode 0, Reward: -1057.0
#     Episode 0, Reward: -2115.5
#     Episode 0, Reward: -2903.9
#     Episode 0, Reward: -2925.8
#     Episode 0, Reward: -4037.4
#     Episode 0, Reward: -5105.7
# Current scenario: ../data/Training/3ac-1000/Scenario_681
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -853.5
#     Episode 0, Reward: 9070.0
#     Episode 0, Reward: 9046.6
#     Episode 0, Reward: -1050.0
#     Episode 0, Reward: -2062.7
# Current scenario: ../data/Training/3ac-1000/Scenario_820
#     Episode 0, Reward: -799.5
#     Episode 0, Reward: 8130.0
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -2971.4
#     Episode 0, Reward: -3999.3
#     Episode 0, Reward: -4110.0
#     Episode 0, Reward: -5145.7
# Current scenario: ../data/Training/3ac-1000/Scenario_478
#     Episode 0, Reward: -810.0
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: -2909.6
#     Episode 0, Reward: 7022.0
#     Episode 0, Reward: 6978.3
#     Episode 0, Reward: -4086.7
#     Episode 0, Reward: -4139.2
#     Episode 0, Reward: -4210.4
#     Episode 0, Reward: -4251.5
#     Episode 0, Reward: -4294.8
#     Episode 0, Reward: -5375.7
#     Episode 0, Reward: -5470.0
#     Episode 0, Reward: 4471.1
# Current scenario: ../data/Training/3ac-1000/Scenario_13
#     Episode 0, Reward: 9218.3
#     Episode 0, Reward: -2832.7
#     Episode 0, Reward: -2930.0
# Current scenario: ../data/Training/3ac-1000/Scenario_829
#     Episode 0, Reward: 8916.5
#     Episode 0, Reward: -2176.6
#     Episode 0, Reward: 7757.1
# Current scenario: ../data/Training/3ac-1000/Scenario_227
#     Episode 0, Reward: -2024.3
#     Episode 0, Reward: -2120.0
# Current scenario: ../data/Training/3ac-1000/Scenario_643
#     Episode 0, Reward: -778.2
#     Episode 0, Reward: -870.0
#     Episode 0, Reward: 9077.5
#     Episode 0, Reward: -990.0
#     Episode 0, Reward: -1011.2
#     Episode 0, Reward: -2066.2
#     Episode 0, Reward: -2092.1
#     Episode 0, Reward: -3228.8
# Current scenario: ../data/Training/3ac-1000/Scenario_471
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -1120.0
#     Episode 0, Reward: -2130.6
#     Episode 0, Reward: 7028.4
# Current scenario: ../data/Training/3ac-1000/Scenario_485
#     Episode 0, Reward: -764.8
#     Episode 0, Reward: -1859.5
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -1934.6
#     Episode 0, Reward: -3036.2
#     Episode 0, Reward: -3106.2
#     Episode 0, Reward: -3170.0
#     Episode 0, Reward: 6790.1
# Current scenario: ../data/Training/3ac-1000/Scenario_218
#     Episode 0, Reward: -1739.6
#     Episode 0, Reward: -2862.5
#     Episode 0, Reward: -3903.2
#     Episode 0, Reward: -4982.7
#     Episode 0, Reward: 3980.3999999999996
# Current scenario: ../data/Training/3ac-1000/Scenario_816
#     Episode 0, Reward: -804.0
#     Episode 0, Reward: -1853.0
#     Episode 0, Reward: -1930.0
#     Episode 0, Reward: -1959.2
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: 7925.5
#     Episode 0, Reward: -3110.3
# Current scenario: ../data/Training/3ac-1000/Scenario_688
#     Episode 0, Reward: -2049.5
#     Episode 0, Reward: -2842.2
#     Episode 0, Reward: -2877.7
#     Episode 0, Reward: -2990.0
#     Episode 0, Reward: -3050.0
#     Episode 0, Reward: -4074.5
# Current scenario: ../data/Training/3ac-1000/Scenario_482
#     Episode 0, Reward: -779.9
#     Episode 0, Reward: 9130.0
#     Episode 0, Reward: 9113.1
#     Episode 0, Reward: -1980.0
# Current scenario: ../data/Training/3ac-1000/Scenario_476
#     Episode 0, Reward: -60.0
#     Episode 0, Reward: -120.0
#     Episode 0, Reward: -1180.0
#     Episode 0, Reward: -1961.6
#     Episode 0, Reward: -2050.0
#     Episode 0, Reward: 7893.1
#     Episode 0, Reward: -2163.3
#     Episode 0, Reward: -2230.0
#     Episode 0, Reward: 7722.6
# Current scenario: ../data/Training/3ac-1000/Scenario_644
#     Episode 0, Reward: -1772.9
#     Episode 0, Reward: -1815.3
#     Episode 0, Reward: -1901.1
#     Episode 0, Reward: -2990.0
# Current scenario: ../data/Training/3ac-1000/Scenario_220
#     Episode 0, Reward: -1810.0
#     Episode 0, Reward: -1870.0
#     Episode 0, Reward: 8089.9
#     Episode 0, Reward: 8058.6
# Current scenario: ../data/Training/3ac-1000/Scenario_14
#     Episode 0, Reward: -1009.8
#     Episode 0, Reward: -2835.1
#     Episode 0, Reward: -3881.0
#     Episode 0, Reward: -3990.0
#     Episode 0, Reward: -5002.6
#     Episode 0, Reward: -6101.1
# Current scenario: ../data/Training/3ac-1000/Scenario_811
#     Episode 0, Reward: -748.0
#     Episode 0, Reward: 9134.5
#     Episode 0, Reward: -930.0
#     Episode 0, Reward: 9029.6
# Current scenario: ../data/Training/3ac-1000/Scenario_449
#     Episode 0, Reward: 8219.8
#     Episode 0, Reward: -2824.7
#     Episode 0, Reward: -4922.2
#     Episode 0, Reward: -4940.5
#     Episode 0, Reward: -5006.5
#     Episode 0, Reward: -5091.0
#     Episode 0, Reward: -5170.0
#     Episode 0, Reward: -5230.0
#     Episode 0, Reward: -5290.0
#     Episode 0, Reward: -6336.5
# proactive: (1/1) 0.03 best avg: -5694.90 - rewards avg: -5694.90
# Marked logs_id 0247 as finished in ../logs/ids.json
# Training log finalized and summary added to ../logs/training/training_0247.json
# Proactive rewards saved to ../results/dqn/20241203-19-29/rewards_proactive.pkl
# {1: -5448.7631999999985}
# {1: -5694.897699999999}

# %%
import shutil

print(f"Myopic model saved to \n{model_path_and_name_myopic}")
print(f"Proactive model saved to \n{model_path_and_name_proactive}")
# Copy the src/environment.py to the results folder under the name used_env.py
shutil.copy('../src/environment.py', os.path.join(results_dir, 'used_e_file.py'))
shutil.copy('../src/config.py', os.path.join(results_dir, 'used_c_file.py'))
# Out:
# Myopic model saved to
# ../trained_models/dqn/myopic-0246.zip
# Proactive model saved to
# ../trained_models/dqn/proactive-0247.zip
# '../results/dqn/20241203-19-29/used_c_file.py'

# %%
# extract the good rewards from the good_rewards_myopic and good_rewards_proactive
good_rewards_myopic_values = good_rewards_myopic.values()   
good_rewards_proactive_values = good_rewards_proactive.values()

print(good_rewards_myopic_values)

epsilon_values_myopic_values = [epsilon for episode, epsilon in epsilon_values_myopic]
epsilon_values_proactive_values = [epsilon for episode, epsilon in epsilon_values_proactive]

episode_numbers_myopic = [episode for episode, epsilon in epsilon_values_myopic]
episode_numbers_proactive = [episode for episode, epsilon in epsilon_values_proactive]

# Plot the good rewards and epsilon values
plt.figure(figsize=(10, 6))
ax1 = plt.gca()
ax1.plot(good_rewards_myopic_values, label='Myopic Rewards', color='C0')
ax1.plot(good_rewards_proactive_values, label='Proactive Rewards', color='C1')
ax1.set_ylabel('Reward')
ax1.set_xlabel('Episode')
ax1.set_title('Rewards per Episode')

ax2 = ax1.twinx()
ax2.plot(episode_numbers_myopic, epsilon_values_myopic_values, label='Myopic Epsilon Values', color='C2')
ax2.plot(episode_numbers_proactive, epsilon_values_proactive_values, label='Proactive Epsilon Values', color='C3')
ax2.set_ylabel('Epsilon')

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2, loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=2)

plt.savefig(os.path.join(results_dir, 'plots', 'good_rewards_per_episode_batch.png'))
plt.show()
# Out:
# dict_values([-5448.7631999999985])

# %%
# extract the good rewards from the good_rewards_myopic and good_rewards_proactive
good_rewards_myopic_values = good_rewards_myopic.values()   
good_rewards_proactive_values = good_rewards_proactive.values()

window_size = 20

# # Smooth out the rewards with a window of 100
# window = np.ones(window_size) / window_size
# smoothed_good_rewards_myopic_values = np.convolve(np.array(list(good_rewards_myopic_values)), window, mode='same')
# smoothed_good_rewards_proactive_values = np.convolve(np.array(list(good_rewards_proactive_values)), window, mode='same')

# ==== Gaussian Filter ====
from scipy.ndimage import gaussian_filter1d

smoothed_good_rewards_myopic_values = gaussian_filter1d(np.array(list(good_rewards_myopic_values)), sigma=window_size / 2)
smoothed_good_rewards_proactive_values = gaussian_filter1d(np.array(list(good_rewards_proactive_values)), sigma=window_size / 2)



# Plot the smoothed good rewards and epsilon values
plt.figure(figsize=(10, 6))
ax1 = plt.gca()
ax1.plot(smoothed_good_rewards_myopic_values, label='Myopic Rewards', color='blue')
ax1.plot(smoothed_good_rewards_proactive_values, label='Proactive Rewards', color='orange')
ax1.set_ylabel('Reward')
ax1.set_xlabel('Episode')
ax1.set_title('Rewards per Episode')

ax2 = ax1.twinx()
ax2.plot(episode_numbers_myopic, epsilon_values_myopic_values, label='Myopic Epsilon Values', color='C2')
ax2.plot(episode_numbers_proactive, epsilon_values_proactive_values, label='Proactive Epsilon Values', color='C3')
ax2.set_ylabel('Epsilon')

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2, loc='center left', bbox_to_anchor=(1.1, 0.5))

plt.savefig(os.path.join(results_dir, 'plots', 'smoothed_good_rewards_per_episode_batch.png'))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Process training rewards per episode for myopic
avg_rewards_per_episode_myopic = []
episodes_myopic = []

for episode in sorted(rewards_myopic.keys()):
    # Calculate the total reward across all scenarios for this episode
    total_reward = sum(rewards_myopic[episode].values()) if isinstance(rewards_myopic[episode], dict) else rewards_myopic[episode]
    avg_rewards_per_episode_myopic.append(total_reward)
    episodes_myopic.append(episode + 1)  # Convert 0-based to 1-based indexing

# Process training rewards per episode for proactive
avg_rewards_per_episode_proactive = []
episodes_proactive = []

for episode in sorted(rewards_proactive.keys()):
    # Calculate the total reward across all scenarios for this episode
    total_reward = sum(rewards_proactive[episode].values()) if isinstance(rewards_proactive[episode], dict) else rewards_proactive[episode]
    avg_rewards_per_episode_proactive.append(total_reward)
    episodes_proactive.append(episode + 1)  # Convert 0-based to 1-based indexing

# Extract test rewards for myopic
test_episodes_myopic = [ep + 1 for ep, _ in test_rewards_myopic]  # Add 1 for 1-based indexing
test_avg_rewards_myopic = [reward for _, reward in test_rewards_myopic]

# Extract test rewards for proactive
test_episodes_proactive = [ep + 1 for ep, _ in test_rewards_proactive]
test_avg_rewards_proactive = [reward for _, reward in test_rewards_proactive]

# Plot 1: Myopic (Training and Testing)
plt.figure(figsize=(10, 5))
plt.plot(episodes_myopic, avg_rewards_per_episode_myopic, label='Myopic Training Reward', color='C0')
plt.plot(test_episodes_myopic, test_avg_rewards_myopic, label='Myopic Test Reward', color='C0', linestyle='--')
plt.legend()
plt.xlabel('Episode')
plt.ylabel('Average Reward')
plt.title('Myopic Rewards')
plt.tight_layout()
plt.savefig(os.path.join(results_dir, 'plots', 'myopic_only.png'))
plt.show()

# Plot 2: Proactive (Training and Testing)
plt.figure(figsize=(10, 5))
plt.plot(episodes_proactive, avg_rewards_per_episode_proactive, label='Proactive Training Reward', color='C1')
plt.plot(test_episodes_proactive, test_avg_rewards_proactive, label='Proactive Test Reward', color='C1', linestyle='--')
plt.legend()
plt.xlabel('Episode')
plt.ylabel('Average Reward')
plt.title('Proactive Rewards')
plt.tight_layout()
plt.savefig(os.path.join(results_dir, 'plots', 'proactive_only.png'))
plt.show()

# Plot 3: Training Rewards (Myopic and Proactive)
plt.figure(figsize=(10, 5))
plt.plot(episodes_myopic, avg_rewards_per_episode_myopic, label='Myopic Training Reward', color='C0')
plt.plot(episodes_proactive, avg_rewards_per_episode_proactive, label='Proactive Training Reward', color='C1')
plt.legend()
plt.xlabel('Episode')
plt.ylabel('Average Reward')
plt.title('Training Rewards (Myopic vs Proactive)')
plt.tight_layout()
plt.savefig(os.path.join(results_dir, 'plots', 'training_only.png'))
plt.show()

# Plot 4: Testing Rewards (Myopic and Proactive)
plt.figure(figsize=(10, 5))
plt.plot(test_episodes_myopic, test_avg_rewards_myopic, label='Myopic Test Reward', color='C0', linestyle='--')
plt.plot(test_episodes_proactive, test_avg_rewards_proactive, label='Proactive Test Reward', color='C1', linestyle='--')
plt.legend()
plt.xlabel('Episode')
plt.ylabel('Average Reward')
plt.title('Testing Rewards (Myopic vs Proactive)')
plt.tight_layout()
plt.savefig(os.path.join(results_dir, 'plots', 'testing_only.png'))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

# Initialize dictionaries to store rewards for each scenario
scenario_rewards_myopic = defaultdict(list)
scenario_rewards_proactive = defaultdict(list)

# Group rewards by scenario for the myopic model
for episode, scenarios in rewards_myopic.items():
    if isinstance(scenarios, dict):  # Check if rewards are stored per scenario
        for scenario, reward in scenarios.items():
            scenario_id = scenario[-2:]  # Extract the last two characters of the scenario
            scenario_rewards_myopic[scenario_id].append(reward)

# Group rewards by scenario for the proactive model
for episode, scenarios in rewards_proactive.items():
    if isinstance(scenarios, dict):  # Check if rewards are stored per scenario
        for scenario, reward in scenarios.items():
            scenario_id = scenario[-2:]  # Extract the last two characters of the scenario
            scenario_rewards_proactive[scenario_id].append(reward)

# Calculate the average reward for each scenario for both models
avg_rewards_per_scenario_myopic = {scenario: np.mean(rewards) for scenario, rewards in scenario_rewards_myopic.items()}
avg_rewards_per_scenario_proactive = {scenario: np.mean(rewards) for scenario, rewards in scenario_rewards_proactive.items()}


# Get all unique scenarios
all_scenarios = set(avg_rewards_per_scenario_myopic.keys()).union(avg_rewards_per_scenario_proactive.keys())
sorted_scenarios = sorted(all_scenarios)

# Extract the sorted average rewards for both models
sorted_avg_rewards_myopic = [avg_rewards_per_scenario_myopic.get(scenario, 0) for scenario in sorted_scenarios]
sorted_avg_rewards_proactive = [avg_rewards_per_scenario_proactive.get(scenario, 0) for scenario in sorted_scenarios]

# Plot a grouped bar chart with scenarios on the x-axis and average rewards on the y-axis
x = np.arange(len(sorted_scenarios))  # the label locations
width = 0.35  # the width of the bars

plt.figure(figsize=(12, 6))
plt.bar(x - width / 2, sorted_avg_rewards_myopic, width, label='Myopic', color='blue')
plt.bar(x + width / 2, sorted_avg_rewards_proactive, width, label='Proactive', color='orange')

plt.xlabel('Scenario')
plt.ylabel('Average Reward')
plt.title('Average Reward per Scenario')
plt.xticks(x, sorted_scenarios)
plt.legend()

plt.tight_layout()
plt.savefig(os.path.join(results_dir, 'plots', 'average_reward_per_scenario.png'))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# Create the new folder within results_dir
scenario_results_dir = os.path.join(results_dir, 'plots', 'reward-plots-per-scenario')
os.makedirs(scenario_results_dir, exist_ok=True)

# Get all unique scenario IDs from both models
all_scenario_ids = set(scenario_rewards_myopic.keys()).union(scenario_rewards_proactive.keys())

# Iterate over all scenarios
for scenario_id in all_scenario_ids:
    # Get rewards lists for both models
    rewards_list_myopic = scenario_rewards_myopic.get(scenario_id, [])
    rewards_list_proactive = scenario_rewards_proactive.get(scenario_id, [])
    
    # Initialize the plot
    plt.figure(figsize=(12, 6))
    
    # Plot for Myopic model
    if rewards_list_myopic:
        window_myopic = min(10, len(rewards_list_myopic))  # Adjust window size as needed
        smoothed_rewards_myopic = np.convolve(rewards_list_myopic, np.ones(window_myopic) / window_myopic, mode='valid')
        plt.plot(range(len(rewards_list_myopic)), rewards_list_myopic, label='Myopic Reward', color='blue', alpha=0.3)
        plt.plot(range(len(smoothed_rewards_myopic)), smoothed_rewards_myopic, label='Myopic Smoothed Reward', color='blue')
    
    # Plot for Proactive model
    if rewards_list_proactive:
        window_proactive = min(10, len(rewards_list_proactive))  # Adjust window size as needed
        smoothed_rewards_proactive = np.convolve(rewards_list_proactive, np.ones(window_proactive) / window_proactive, mode='valid')
        plt.plot(range(len(rewards_list_proactive)), rewards_list_proactive, label='Proactive Reward', color='orange', alpha=0.3)
        plt.plot(range(len(smoothed_rewards_proactive)), smoothed_rewards_proactive, label='Proactive Smoothed Reward', color='orange')
    
    # Set labels and title
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.title(f'Reward per Episode for Scenario {scenario_id}')
    plt.legend()
    
    # Save the plot
    plot_filename = f'average_reward_for_scenario_{scenario_id}.png'
    plt.savefig(os.path.join(scenario_results_dir, plot_filename))
    plt.close()

# %%
print("total_timesteps_proactive:", total_timesteps_proactive)
print("total_timesteps_myopic:", total_timesteps_myopic)

# Extract epsilon values and their corresponding timesteps
timesteps_myopic = [i for i, _ in enumerate(epsilon_values_myopic)]
epsilon_values_myopic_only = [epsilon for _, epsilon in epsilon_values_myopic]

timesteps_proactive = [i for i, _ in enumerate(epsilon_values_proactive)]
epsilon_values_proactive_only = [epsilon for _, epsilon in epsilon_values_proactive]

# Plot the epsilon values over the episodes for both models
plt.figure(figsize=(10, 6))

# Plot for Proactive model
plt.plot(timesteps_proactive, epsilon_values_proactive_only, label='Proactive Epsilon', color='C1', linestyle='--')
plt.plot(timesteps_myopic, epsilon_values_myopic_only, label='Myopic Epsilon', color='C0', linestyle=':')

plt.xlabel('Timesteps')
plt.ylabel('Epsilon Value')
plt.title('Epsilon Value over Timesteps for Both Models')
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(results_dir, 'plots', 'epsilon_value_over_timesteps_both_models.png'))
plt.show()
# Out:
# total_timesteps_proactive: 6161
# total_timesteps_myopic: 6142
