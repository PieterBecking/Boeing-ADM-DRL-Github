# %% [markdown]
# ### Import packages

# %%
import pandas as pd
import os
import torch as th
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.utils import set_random_seed
from scripts.utils import *
from scripts.visualizations import *
from config import *
from datetime import datetime, timedelta

# %% [markdown]
# ### Hyperparameters

# %%
LEARNING_RATE = 0.001
GAMMA = 0.99
BUFFER_SIZE = 50000
BATCH_SIZE = 32
TARGET_UPDATE_INTERVAL = 100
EPSILON_START = 1.0
EPSILON_MIN = 0.05
EPSILON_DECAY_RATE = 0.0005
N_EPISODES = 300            # number of episodes PER TRAINING SCENARIO
MAX_TIMESTEPS = 500         # maximum number of timesteps per episode (not relevant here)
TRAINING_FOLDERS_PATH = 'Data/Training'
MODEL_SAVE_PATH = 'Models/dqn_' + get_model_name()

# %% [markdown]
# # Reinforcement Learning

# %% [markdown]
# ## Environment

# %%
from environment import AircraftDisruptionEnv

# %% [markdown]
# ## Loading Scenario

# %%
def load_scenario_data(scenario_folder):
    file_keys = ['aircraft', 'airports', 'alt_aircraft', 'alt_airports', 'alt_flights', 'config', 'dist', 'flights', 'itineraries', 'position', 'rotations']
    file_paths = {key: os.path.join(scenario_folder, f"{key}.csv") for key in file_keys}

    data_dict = {}
    file_parsing_functions = {
        'config': FileParsers.parse_config,
        'airports': FileParsers.parse_airports,
        'dist': FileParsers.parse_dist,
        'flights': FileParsers.parse_flights,
        'aircraft': FileParsers.parse_aircraft,
        'rotations': FileParsers.parse_rotations,
        'itineraries': FileParsers.parse_itineraries,
        'position': FileParsers.parse_position,
        'alt_flights': FileParsers.parse_alt_flights,
        'alt_aircraft': FileParsers.parse_alt_aircraft,
        'alt_airports': FileParsers.parse_alt_airports
    }

    # Iterate over each file and process it using the correct parsing function
    for file_type, file_path in file_paths.items():
        file_lines = read_csv_with_comments(file_path)
        if file_lines:
            parse_function = file_parsing_functions.get(file_type)
            if parse_function:
                parsed_data = parse_function(file_lines)
                data_dict[file_type] = parsed_data
            else:
                print(f"No parser available for file type: {file_type}")
        else:
            data_dict[file_type] = None
            print(f"{file_type.capitalize()} file is empty")

    return data_dict

# %% [markdown]
# ## Training

# %%
# Storing the reward for each episode per scenario
rewards = []


def train_dqn_agent():
    # List all the scenario folders in Data/Training
    scenario_folders = [os.path.join(TRAINING_FOLDERS_PATH, folder) for folder in os.listdir(TRAINING_FOLDERS_PATH) if os.path.isdir(os.path.join(TRAINING_FOLDERS_PATH, folder))]
    
    total_timesteps = 0
    epsilon = EPSILON_START

    # Training loop over the number of episodes
    for episode in range(N_EPISODES):
        # Cycle through all the scenario folders
        for scenario_folder in scenario_folders:
            # Load the data for the current scenario
            data_dict = load_scenario_data(scenario_folder)

            # Extract necessary data for the environment
            aircraft_dict = data_dict['aircraft']
            flights_dict = data_dict['flights']
            rotations_dict = data_dict['rotations']
            alt_aircraft_dict = data_dict['alt_aircraft']
            config_dict = data_dict['config']

            # Initialize the environment with the current scenario
            env = AircraftDisruptionEnv(aircraft_dict, flights_dict, rotations_dict, alt_aircraft_dict, config_dict)
            env = DummyVecEnv([lambda: env])

            # Initialize the DQN model **after** setting the environment
            model = DQN(
                policy="MlpPolicy",
                env=env,  # Pass the environment here
                learning_rate=LEARNING_RATE,
                gamma=GAMMA,
                buffer_size=BUFFER_SIZE,
                batch_size=BATCH_SIZE,
                target_update_interval=TARGET_UPDATE_INTERVAL,
                verbose=1
            )

            # Reset the environment
            obs = env.reset()

            done = False
            total_reward = 0
            timesteps = 0

            while not done and timesteps < MAX_TIMESTEPS:
                # Perform an action using the current policy (or epsilon-greedy)
                action = model.predict(obs, deterministic=False)[0]

                # Step the environment
                obs, reward, done, info = env.step(action)

                # Accumulate the reward
                total_reward += reward

                # Update epsilon (exploration rate)
                epsilon = max(EPSILON_MIN, epsilon - EPSILON_DECAY_RATE)

                timesteps += 1
                total_timesteps += 1

            # Store the total reward for the episode with the scenario specified
            rewards.append((episode, scenario_folder, total_reward))
            
            print(f"Episode {episode}, Scenario {scenario_folder}, Total Reward: {total_reward}")

    # Save the model after training
    model.save(MODEL_SAVE_PATH)

# Run the training process
train_dqn_agent()
# Out:
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_03, Total Reward: [-1945.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_04, Total Reward: [2575.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_05, Total Reward: [9815.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_02, Total Reward: [16465.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_10, Total Reward: [3455.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_09, Total Reward: [-2935.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_07, Total Reward: [16640.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_06, Total Reward: [-200.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_04, Total Reward: [3705.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_05, Total Reward: [-47095.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# /Users/pieterbecking/.pyenv/versions/thesis_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:108: RuntimeWarning: invalid value encountered in cast
#   self.buf_obs[key][env_idx] = obs
# Episode 1, Scenario Data/Training/Scenario_02, Total Reward: [-66500.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_10, Total Reward: [3195.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_09, Total Reward: [-2935.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_07, Total Reward: [-90000.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_06, Total Reward: [-285.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_04, Total Reward: [4445.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_05, Total Reward: [8955.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_02, Total Reward: [16465.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_10, Total Reward: [5180.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_09, Total Reward: [-2935.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_07, Total Reward: [14810.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_06, Total Reward: [-1000.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 3, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 3, Scenario Data/Training/Scenario_04, Total Reward: [3925.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode
Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 295, Scenario Data/Training/Scenario_07, Total Reward: [5430.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 295, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 295, Scenario Data/Training/Scenario_06, Total Reward: [-2135.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 295, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_03, Total Reward: [-1945.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_04, Total Reward: [4085.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_05, Total Reward: [4100.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_02, Total Reward: [-96000.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_10, Total Reward: [5400.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_09, Total Reward: [-3840.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_07, Total Reward: [15235.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_06, Total Reward: [-1675.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_04, Total Reward: [2835.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_05, Total Reward: [5345.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_02, Total Reward: [9075.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_10, Total Reward: [3625.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_09, Total Reward: [-785.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_07, Total Reward: [15235.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_06, Total Reward: [-2135.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_03, Total Reward: [-395.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_04, Total Reward: [5385.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_05, Total Reward: [-47095.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_02, Total Reward: [17250.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_10, Total Reward: [4455.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_09, Total Reward: [-365.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_07, Total Reward: [15500.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_06, Total Reward: [-1000.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_03, Total Reward: [-1945.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_04, Total Reward: [3705.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_05, Total Reward: [9785.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_02, Total Reward: [-96000.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_10, Total Reward: [-51000.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_09, Total Reward: [-1460.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_07, Total Reward: [-62235.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_06, Total Reward: [-24000.]
# Alt_airports file is empty
# Alt_flights file is empty
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_08, Total Reward: [0.]

# %%
print(len(rewards))

avg_rewards = []

# avg_rewards contains N_EPISODES elements, each element is the average reward for a given iteration of the ten scenarios
for i in range(0, len(rewards), 10):
    avg_rewards.append(np.mean([reward for _, _, reward in rewards[i:i+10]]))
    
# Plot the average rewards over the episodes
plt.plot(range(N_EPISODES), avg_rewards)
plt.xlabel('Episode')
plt.ylabel('Average Reward')
plt.title('Average Reward per Episode')
plt.show()
# Out:
# 3000
