# %% [markdown]
# ### Import packages

# %%
import pandas as pd
import os
import torch as th
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.utils import set_random_seed
from scripts.utils import *
from scripts.visualizations import *
from config import *
from datetime import datetime, timedelta

# %% [markdown]
# ### Hyperparameters

# %%
LEARNING_RATE = 0.001
GAMMA = 0.99
BUFFER_SIZE = 50000
BATCH_SIZE = 32
TARGET_UPDATE_INTERVAL = 100
EPSILON_START = 1.0
EPSILON_MIN = 0.05
EPSILON_DECAY_RATE = 0.0005
N_EPISODES = 300            # number of episodes PER TRAINING SCENARIO
MAX_TIMESTEPS = 500         # maximum number of timesteps per episode (not relevant here)
TRAINING_FOLDERS_PATH = 'Data/Training'

#print all folders in the training folder
training_folders = []
for folder in os.listdir(TRAINING_FOLDERS_PATH):
    if os.path.isdir(os.path.join(TRAINING_FOLDERS_PATH, folder)):
        training_folders.append(folder)

num_days_trained_on = N_EPISODES * len(training_folders)
print(f'Training on {num_days_trained_on} days of data ({len(training_folders)} unique scenarios)')

model_name = 'dqn_' + str(num_days_trained_on) + "d_" + str(len(training_folders)) + "u"
print('Model name:', model_name)
model_version = get_model_version(model_name)
MODEL_SAVE_PATH = 'Models/' + model_name + '-' + model_version + '.zip'

print('Model will be saved to:', MODEL_SAVE_PATH)
# Out:
# Training on 3000 days of data (10 unique scenarios)
# Model name: dqn_3000d_10u
# checking file: dqn_3000d_20240914-1.zip
# Model will be saved to: Models/dqn_3000d_10u-1.zip

# %% [markdown]
# # Reinforcement Learning

# %% [markdown]
# ## Environment

# %%
from environment import AircraftDisruptionEnv

# %% [markdown]
# ## Loading Scenario

# %%
def load_scenario_data(scenario_folder):
    file_keys = ['aircraft', 'airports', 'alt_aircraft', 'alt_airports', 'alt_flights', 'config', 'dist', 'flights', 'itineraries', 'position', 'rotations']
    file_paths = {key: os.path.join(scenario_folder, f"{key}.csv") for key in file_keys}

    data_dict = {}
    file_parsing_functions = {
        'config': FileParsers.parse_config,
        'airports': FileParsers.parse_airports,
        'dist': FileParsers.parse_dist,
        'flights': FileParsers.parse_flights,
        'aircraft': FileParsers.parse_aircraft,
        'rotations': FileParsers.parse_rotations,
        'itineraries': FileParsers.parse_itineraries,
        'position': FileParsers.parse_position,
        'alt_flights': FileParsers.parse_alt_flights,
        'alt_aircraft': FileParsers.parse_alt_aircraft,
        'alt_airports': FileParsers.parse_alt_airports
    }

    # Iterate over each file and process it using the correct parsing function
    for file_type, file_path in file_paths.items():
        file_lines = read_csv_with_comments(file_path)
        if file_lines:
            parse_function = file_parsing_functions.get(file_type)
            if parse_function:
                parsed_data = parse_function(file_lines)
                data_dict[file_type] = parsed_data
            else:
                print(f"No parser available for file type: {file_type}")
        else:
            data_dict[file_type] = None

    return data_dict

# %% [markdown]
# ## Training

# %%
# Storing the reward for each episode per scenario
rewards = []


def train_dqn_agent():
    # List all the scenario folders in Data/Training
    scenario_folders = [os.path.join(TRAINING_FOLDERS_PATH, folder) for folder in os.listdir(TRAINING_FOLDERS_PATH) if os.path.isdir(os.path.join(TRAINING_FOLDERS_PATH, folder))]
    
    total_timesteps = 0
    epsilon = EPSILON_START

    # Training loop over the number of episodes
    for episode in range(N_EPISODES):
        # Cycle through all the scenario folders
        for scenario_folder in scenario_folders:
            # Load the data for the current scenario
            data_dict = load_scenario_data(scenario_folder)

            # Extract necessary data for the environment
            aircraft_dict = data_dict['aircraft']
            flights_dict = data_dict['flights']
            rotations_dict = data_dict['rotations']
            alt_aircraft_dict = data_dict['alt_aircraft']
            config_dict = data_dict['config']

            # Initialize the environment with the current scenario
            env = AircraftDisruptionEnv(aircraft_dict, flights_dict, rotations_dict, alt_aircraft_dict, config_dict)
            env = DummyVecEnv([lambda: env])

            # Initialize the DQN model **after** setting the environment
            model = DQN(
                policy="MlpPolicy",
                env=env,  # Pass the environment here
                learning_rate=LEARNING_RATE,
                gamma=GAMMA,
                buffer_size=BUFFER_SIZE,
                batch_size=BATCH_SIZE,
                target_update_interval=TARGET_UPDATE_INTERVAL,
                verbose=1
            )

            # Reset the environment
            obs = env.reset()

            done = False
            total_reward = 0
            timesteps = 0

            while not done and timesteps < MAX_TIMESTEPS:
                # Perform an action using the current policy (or epsilon-greedy)
                action = model.predict(obs, deterministic=False)[0]

                # Step the environment
                obs, reward, done, info = env.step(action)

                # Accumulate the reward
                total_reward += reward

                # Update epsilon (exploration rate)
                epsilon = max(EPSILON_MIN, epsilon - EPSILON_DECAY_RATE)

                timesteps += 1
                total_timesteps += 1

            # Store the total reward for the episode with the scenario specified
            rewards.append((episode, scenario_folder, total_reward))
            
            print(f"Episode {episode}, Scenario {scenario_folder}, Total Reward: {total_reward}")

    # Save the model after training
    model.save(MODEL_SAVE_PATH)

# Run the training process
train_dqn_agent()
# Out:
# Using cpu device
# /Users/pieterbecking/.pyenv/versions/thesis_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:108: RuntimeWarning: invalid value encountered in cast
#   self.buf_obs[key][env_idx] = obs
# Episode 0, Scenario Data/Training/Scenario_03, Total Reward: [-395.]
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_04, Total Reward: [-2605.]
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_05, Total Reward: [-72000.]
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_02, Total Reward: [8055.]
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_10, Total Reward: [4415.]
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_09, Total Reward: [-365.]
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_07, Total Reward: [-2440.]
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_06, Total Reward: [-1675.]
# Using cpu device
# Episode 0, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_03, Total Reward: [-395.]
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_04, Total Reward: [-2650.]
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_05, Total Reward: [9425.]
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_02, Total Reward: [16225.]
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_10, Total Reward: [4835.]
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_09, Total Reward: [-3475.]
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_07, Total Reward: [16405.]
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_06, Total Reward: [-820.]
# Using cpu device
# Episode 1, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_03, Total Reward: [-22500.]
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_04, Total Reward: [-12895.]
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_05, Total Reward: [10705.]
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_02, Total Reward: [-62000.]
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_10, Total Reward: [-48000.]
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_09, Total Reward: [0.]
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_07, Total Reward: [-37330.]
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_06, Total Reward: [-645.]
# Using cpu device
# Episode 2, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 3, Scenario Data/Training/Scenario_03, Total Reward: [-22500.]
# Using cpu device
# Episode 3, Scenario Data/Training/Scenario_04, Total Reward: [-2650.]
# Using cpu device
# Episode 3, Scenario Data/Training/Scenario_05, Total Reward: [9300.]
# Using cpu device
# Episode 3, Scenario Data/Training/Scenario_02, Total Reward: [-26370.]
# Using cpu device
# Episode 3, Scenario Data/Training/Scenario_10, Total Reward: [3775.]
# Using cpu device
# Episode 3, Scenario Data/Training/Scenario_09, Total Reward: [-375.]
# Using cpu device
# Episode 3, Scenario Data/Training/Scenario_07, Total Reward: [-24930.]
# Using cpu device
# Episode 3, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 3, Scenario Data/Training/Scenario_06, Total Reward: [-940.]
# Using cpu device
# Episode 3, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 4, Scenario Data/Training/Scenario_03, Total Reward: [-22500.]
# Using cpu device
# Episode 4, Scenario Data/Training/Scenario_04, Total Reward: [4970.]
# Using cpu device
# Episode 4, Scenario Data/Training/Scenario_05, Total Reward: [6830.]
# Using cpu device
# Episode 4, Scenario Data/Training/Scenario_02, Total Reward: [17745.]
# Using cpu device
# Episode 4, Scenario Data/Training/Scenario_10, Total Reward: [-11220.]
# Using cpu device
# Episode 4, Scenario Data/Training/Scenario_09, Total Reward: [-28500.]
# Using cpu device
# Episode 4, Scenario Data/Training/Scenario_07, Total Reward: [17205.]
# Using cpu device
# Episode 4, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 4, Scenario Data/Training/Scenario_06, Total Reward: [-645.]
# Using cpu device
# Episode 4, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 5, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 5, Scenario Data/Training/Scenario_04, Total Reward: [1115.]
# Using cpu device
# Episode 5, Scenario Data/Training/Scenario_05, Total Reward: [10705.]
# Using cpu device
# Episode 5, Scenario Data/Training/Scenario_02, Total Reward: [16225.]
# Using cpu device
# Episode 5, Scenario Data/Training/Scenario_10, Total Reward: [5135.]
# Using cpu device
# Episode 5, Scenario Data/Training/Scenario_09, Total Reward: [-785.]
# Using cpu device
# Episode 5, Scenario Data/Training/Scenario_07, Total Reward: [17325.]
# Using cpu device
# Episode 5, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 5, Scenario Data/Training/Scenario_06, Total Reward: [-285.]
# Using cpu device
# Episode 5, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 6, Scenario Data/Training/Scenario_03, Total Reward: [-1505.]
# Using cpu device
# Episode 6, Scenario Data/Training/Scenario_04, Total Reward: [-6365.]
# Using cpu device
# Episode 6, Scenario Data/Training/Scenario_05, Total Reward: [10705.]
# Using cpu device
# Episode 6, Scenario Data/Training/Scenario_02, Total Reward: [-90000.]
# Using cpu device
# Episode 6, Scenario Data/Training/Scenario_10, Total Reward: [3970.]
# Using cpu device
# Episode 6, Scenario Data/Training/Scenario_09, Total Reward: [-785.]
# Using cpu device
# Episode 6, Scenario Data/Training/Scenario_07, Total Reward: [16855.]
# Using cpu device
# Episode 6, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 6, Scenario Data/Training/Scenario_06, Total Reward: [-200.]
# Using cpu device
# Episode 6, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 7, Scenario Data/Training/Scenario_03, Total Reward: [-22500.]
# Using cpu device
# Episode 7, Scenario Data/Training/Scenario_04, Total Reward: [4875.]
# Using cpu device
# Episode 7, Scenario Data/Training/Scenario_05, Total Reward: [8535.]
# Using cpu device
# Episode 7, Scenario Data/Training/Scenario_02, Total Reward: [16825.]
# Using cpu device
# Episode 7, Scenario Data/Training/Scenario_10, Total Reward: [3970.]
# Using cpu device
# Episode 7, Scenario Data/Training/Scenario_09, Total Reward: [-785.]
# Using cpu device
# Episode 7, Scenario Data/Training/Scenario_07, Total Reward: [16575.]
# Using cpu device
# Episode 7, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 7, Scenario Data/Training/Scenario_06, Total Reward: [-285.]
# Using cpu device
# Episode 7, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 8, Scenario Data/Training/Scenario_03, Total Reward: [-1880.]
# Using cpu device
# Episode 8, Scenario Data/Training/Scenario_04, Total Reward: [-12895.]
# Using cpu device
# Episode 8, Scenario Data/Training/Scenario_05, Total Reward: [-72000.]
# Using cpu device
# Episode 8, Scenario Data/Training/Scenario_02, Total Reward: [16625.]
# Using cpu device
# Episode 8, Scenario Data/Training/Scenario_10, Total Reward: [5135.]
# Using cpu device
# Episode 8, Scenario Data/Training/Scenario_09, Total Reward: [-785.]
# Using cpu device
# Episode 8, Scenario Data/Training/Scenario_07, Total Reward: [17305.]
# Using cpu device
# Episode 8, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 8, Scenario Data/Training/Scenario_06, Total Reward: [-940.]
# Using cpu device
# Episode 8, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 9, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 9, Scenario Data/Training/Scenario_04, Total Reward: [-11915.]
# Using cpu device
# Episode 9, Scenario Data/Training/Scenario_05, Total Reward: [-3645.]
# Using cpu device
# Episode 9, Scenario Data/Training/Scenario_02, Total Reward: [16625.]
# Using cpu device
# Episode 9, Scenario Data/Training/Scenario_10, Total Reward: [4940.]
# Using cpu device
# Episode 9, Scenario Data/Training/Scenario_09, Total Reward: [-28500.]
# Using cpu device
# Episode 9, Scenario Data/Training/Scenario_07, Total Reward: [16785.]
# Using cpu device
# Episode 9, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 9, Scenario Data/Training/Scenario_06, Total Reward: [-22500.]
# Using cpu device
# Episode 9, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 10, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 10, Scenario Data/Training/Scenario_04, Total Reward: [-480.]
# Using cpu device
# Episode 10, Scenario Data/Training/Scenario_05, Total Reward: [9680.]
# Using cpu device
# Episode 10, Scenario Data/Training/Scenario_02, Total Reward: [16625.]
# Using cpu device
# Episode 10, Scenario Data/Training/Scenario_10, Total Reward: [4420.]
# Using cpu device
# Episode 10, Scenario Data/Training/Scenario_09, Total Reward: [0.]
# Using cpu device
# Episode 10, Scenario Data/Training/Scenario_07, Total Reward: [16590.]
# Using cpu device
# Episode 10, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 10, Scenario Data/Training/Scenario_06, Total Reward: [-1155.]
# Using cpu device
# Episode 10, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 11, Scenario Data/Training/Scenario_03, Total Reward: [-395.]
# Using cpu device
# Episode 11, Scenario Data/Training/Scenario_04, Total Reward: [-2650.]
# Using cpu device
# Episode 11, Scenario Data/Training/Scenario_05, Total Reward: [-18615.]
# Using cpu device
# Episode 11, Scenario Data/Training/Scenario_02, Total Reward: [11310.]
# Using cpu device
# Episode 11, Scenario Data/Training/Scenario_10, Total Reward: [4420.]
# Using cpu device
# Episode 11, Scenario Data/Training/Scenario_09, Total Reward: [-3475.]
# Using cpu device
# Episode 11, Scenario Data/Training/Scenario_07, Total Reward: [17000.]
# Using cpu device
# Episode 11, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 11, Scenario Data/Training/Scenario_06, Total Reward: [-645.]
# Using cpu device
# Episode 11, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 12, Scenario Data/Training/Scenario_03, Total Reward: [-2705.]
# Using cpu device
# Episode 12, Scenario Data/Training/Scenario_04, Total Reward: [-12895.]
# Using cpu device
# Episode 12, Scenario Data/Training/Scenario_05, Total Reward: [-18615.]
# Using cpu device
# Episode 12, Scenario Data/Training/Scenario_02, Total Reward: [-54775.]
# Using cpu device
# Episode 12, Scenario Data/Training/Scenario_10, Total Reward: [5260.]
# Using cpu device
# Episode 12, Scenario Data/Training/Scenario_09, Total Reward: [-365.]
# Using cpu device
# Episode 12, Scenario Data/Training/Scenario_07, Total Reward: [17720.]
# Using cpu device
# Episode 12, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 12, Scenario Data/Training/Scenario_06, Total Reward: [-1925.]
# Using cpu device
# Episode 12, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 13, Scenario Data/Training/Scenario_03, Total Reward: [-395.]
# Using cpu device
# Episode 13, Scenario Data/Training/Scenario_04, Total Reward: [4085.]
# Using cpu device
# Episode 13, Scenario Data/Training/Scenario_05, Total Reward: [9425.]
# Using cpu device
# Episode 13, Scenario Data/Training/Scenario_02, Total Reward: [17745.]
# Using cpu device
# Episode 13, Scenario Data/Training/Scenario_10, Total Reward: [5360.]
# Using cpu device
# Episode 13, Scenario Data/Training/Scenario_09, Total Reward: [-785.]
# Using cpu device
# Episode 13, Scenario Data/Training/Scenario_07, Total Reward: [-4415.]
# Using cpu device
# Episode 13, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 13, Scenario Data/Training/Scenario_06, Total Reward: [-940.]
# Using cpu device
# Episode 13, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 14, Scenario Data/Training/Scenario_03, Total Reward: [-22500.]
# Using cpu device
# Episode 14, Scenario Data/Training/Scenario_04, Total Reward: [3400.]
# Using cpu device
# Episode 14, Scenario Data/Training/Scenario_05, Total Reward: [-36235.]
# Using cpu device
# Episode 14, Scenario Data/Training/Scenario_02, Total Reward: [-75000.]
# Using cpu device
# Episode 14, Scenario Data/Training/Scenario_10, Total Reward: [4635.]
# Using cpu device
# Episode 14, Scenario Data/Training/Scenario_09, Total Reward: [-375.]
# Using cpu device
# Episode 14, Scenario Data/Training/Scenario_07, Total Reward: [17250.]
# Using cpu device
# Episode 14, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 14, Scenario Data/Training/Scenario_06, Total Reward: [-200.]
# Using cpu device
# Episode 14, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 15, Scenario Data/Training/Scenario_03, Total Reward: [-1505.]
# Using cpu device
# Episode 15, Scenario Data/Training/Scenario_04, Total Reward: [1115.]
# Using cpu device
# Episode 15, Scenario Data/Training/Scenario_05, Total Reward: [-72000.]
# Using cpu device
# Episode 15, Scenario Data/Training/Scenario_02, Total Reward: [16225.]
# Using cpu device
# Episode 15, Scenario Data/Training/Scenario_10, Total Reward: [3970.]
# Using cpu device
# Episode 15, Scenario Data/Training/Scenario_09, Total Reward: [-1460.]
# Using cpu device
# Episode 15, Scenario Data/Training/Scenario_07, Total Reward: [16575.]
# Using cpu device
# Episode 15, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 15, Scenario Data/Training/Scenario_06, Total Reward: [-1675.]
# Using cpu device
# Episode 15, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 16, Scenario Data/Training/Scenario_03, Total Reward: [-22500.]
# Using cpu device
# Episode 16, Scenario Data/Training/Scenario_04, Total Reward: [3050.]
# Using cpu device
# Episode 16, Scenario Data/Training/Scenario_05, Total Reward: [9830.]
# Using cpu device
# Episode 16, Scenario Data/Training/Scenario_02, Total Reward: [-47545.]
# Using cpu device
# Episode 16, Scenario Data/Training/Scenario_10, Total Reward: [3970.]
# Using cpu device
# Episode 16, Scenario Data/Training/Scenario_09, Total Reward: [0.]
# Using cpu device
# Episode 16, Scenario Data/Training/Scenario_07, Total Reward: [16785.]
# Using cpu device
# Episode 16, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 16, Scenario Data/Training/Scenario_06, Total Reward: [-200.]
# Using cpu device
# Episode 16, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 17, Scenario Data/Training/Scenario_03, Total Reward: [-1880.]
# Using cpu device
# Episode 17, Scenario Data/Training/Scenario_04, Total Reward: [3050.]
# Using cpu device
# Episode 17, Scenario Data/Training/Scenario_05, Total Reward: [10705.]
# Using cpu device
# Episode 17, Scenario Data/Training/Scenario_02, Total Reward: [-20265.]
# Using cpu device
# Episode 17, Scenario Data/Training/Scenario_10, Total Reward: [3970.]
# Using cpu device
# Episode 17, Scenario Data/Training/Scenario_09, Total Reward: [0.]
# Using cpu device
# Episode 17, Scenario Data/Training/Scenario_07, Total Reward: [-10720.]
# Using cpu device
# Episode 17, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 17, Scenario Data/Training/Scenario_06, Total Reward: [-200.]
# Using cpu device
# Episode 17, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 18, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 18, Scenario Data/Training/Scenario_04, Total Reward: [-45000.]
# Using cpu device
# Episode 18, Scenario Data/Training/Scenario_05, Total Reward: [10705.]
# Using cpu device
# Episode 18, Scenario Data/Training/Scenario_02, Total Reward: [-26370.]
# Using cpu device
# Episode 18, Scenario Data/Training/Scenario_10, Total Reward: [4635.]
# Using cpu device
# Episode 18, Scenario Data/Training/Scenario_09, Total Reward: [-2045.]
# Using cpu device
# Episode 18, Scenario Data/Training/Scenario_07, Total Reward: [16590.]
# Using cpu device
# Episode 18, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 18, Scenario Data/Training/Scenario_06, Total Reward: [-16940.]
# Using cpu device
# Episode 18, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 19, Scenario Data/Training/Scenario_03, Total Reward: [-395.]
# Using cpu device
# Episode 19, Scenario Data/Training/Scenario_04, Total Reward: [-450.]
# Using cpu device
# Episode 19, Scenario Data/Training/Scenario_05, Total Reward: [-72000.]
# Using cpu device
# Episode 19, Scenario Data/Training/Scenario_02, Total Reward: [16625.]
# Using cpu device
# Episode 19, Scenario Data/Training/Scenario_10, Total Reward: [-48000.]
# Using cpu device
# Episode 19, Scenario Data/Training/Scenario_09, Total Reward: [-2990.]
# Using cpu device
# Episode 19, Scenario Data/Training/Scenario_07, Total Reward: [16820.]
# Using cpu device
# Episode 19, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 19, Scenario Data/Training/Scenario_06, Total Reward: [-1155.]
# Using cpu device
# Episode 19, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 20, Scenario Data/Training/Scenario_03, Total Reward: [-22500.]
# Using cpu device
# Episode 20, Scenario Data/Training/Scenario_04, Total Reward: [-12895.]
# Using cpu device
# Episode 20, Scenario Data/Training/Scenario_05, Total Reward: [8990.]
# Using cpu device
# Episode 20, Scenario Data/Training/Scenario_02, Total Reward: [17390.]
# Using cpu device
# Episode 20, Scenario Data/Training/Scenario_10, Total Reward: [5260.]
# Using cpu device
# Episode 20, Scenario Data/Training/Scenario_09, Total Reward: [-2045.]
# Using cpu device
# Episode 20, Scenario Data/Training/Scenario_07, Total Reward: [16490.]
# Using cpu device
# Episode 20, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 20, Scenario Data/Training/Scenario_06, Total Reward: [-285.]
# Using cpu device
# Episode 20, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 21, Scenario Data/Training/Scenario_03, Total Reward: [-395.]
# Using cpu device
# Episode 21, Scenario Data/Training/Scenario_04, Total Reward: [-12895.]
# Using cpu device
# Episode 21, Scenario Data/Training/Scenario_05, Total Reward: [10270.]
# Using cpu device
# Episode 21, Scenario Data/Training/Scenario_02, Total Reward: [16225.]
# Using cpu device
# Episode 21, Scenario Data/Training/Scenario_10, Total Reward: [5260.]
# Using cpu device
# Episode 21, Scenario Data/Training/Scenario_09, Total Reward: [-2045.]
# Using cpu device
# Episode 21, Scenario Data/Training/Scenario_07, Total Reward: [17205.]
# Using cpu device
# Episode 21, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 21, Scenario Data/Training/Scenario_06, Total Reward: [-200.]
# Using cpu device
# Episode 21, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 22, Scenario Data/Training/Scenario_03, Total Reward: [-1880.]
# Using cpu device
# Episode 22, Scenario Data/Training/Scenario_04, Total Reward: [3050.]
# Using cpu device
# Episode 22, Scenario Data/Training/Scenario_05, Total Reward: [10705.]
# Using cpu device
# Episode 22, Scenario Data/Training/Scenario_02, Total Reward: [17745.]
# Using cpu device
# Episode 22, Scenario Data/Training/Scenario_10, Total Reward: [-11220.]
# Using cpu device
# Episode 22, Scenario Data/Training/Scenario_09, Total Reward: [-3475.]
# Using cpu device
# Episode 22, Scenario Data/Training/Scenario_07, Total Reward: [17290.]
# Using cpu device
# Episode 22, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 22, Scenario Data/Training/Scenario_06, Total Reward: [-9145.]
# Using cpu device
# Episode 22, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 23, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 23, Scenario Data/Training/Scenario_04, Total Reward: [3400.]
# Using cpu device
# Episode 23, Scenario Data/Training/Scenario_05, Total Reward: [-18615.]
# Using cpu device
# Episode 23, Scenario Data/Training/Scenario_02, Total Reward: [17745.]
# Using cpu device
# Episode 23, Scenario Data/Training/Scenario_10, Total Reward: [4685.]
# Using cpu device
# Episode 23, Scenario Data/Training/Scenario_09, Total Reward: [-1460.]
# Using cpu device
# Episode 23, Scenario Data/Training/Scenario_07, Total Reward: [16405.]
# Using cpu device
# Episode 23, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 23, Scenario Data/Training/Scenario_06, Total Reward: [-940.]
# Using cpu device
# Episode 23, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 24, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 24, Scenario Data/Training/Scenario_04, Total Reward: [-450.]
# Using cpu device
# Episode 24, Scenario Data/Training/Scenario_05, Total Reward: [10215.]
# Using cpu device
# Episode 24, Scenario Data/Training/Scenario_02, Total Reward: [17745.]
# Using cpu device
# Episode 24, Scenario Data/Training/Scenario_10, Total Reward: [-48000.]
# Using cpu device
# Episode 24, Scenario Data/Training/Scenario_09, Total Reward: [-28500.]
# Using cpu device
# Episode 24, Scenario Data/Training/Scenario_07, Total Reward: [3560.]
# Using cpu device
# Episode 24, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 24, Scenario Data/Training/Scenario_06, Total Reward: [-1155.]
# Using cpu device
# Episode 24, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 25, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 25, Scenario Data/Training/Scenario_04, Total Reward: [-450.]
# Using cpu device
# Episode 25, Scenario Data/Training/Scenario_05, Total Reward: [10705.]
# Using cpu device
# Episode 25, Scenario Data/Training/Scenario_02, Total Reward: [16225.]
# Using cpu device
# Episode 25, Scenario Data/Training/Scenario_10, Total Reward: [4685.]
# Using cpu device
# Episode 25, Scenario Data/Training/Scenario_09, Total Reward: [-3475.]
# Using cpu device
# Episode 25, Scenario Data/Training/Scenario_07, Total Reward: [-21320.]
# Using cpu device
# Episode 25, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 25, Scenario Data/Training/Scenario_06, Total Reward: [-1955.]
# Using cpu device
# Episode 25, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 26, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 26, Scenario Data/Training/Scenario_04, Total Reward: [-45000.]
# Using cpu device
# Episode 26, Scenario Data/Training/Scenario_05, Total Reward: [-40710.]
# Using cpu device
# Episode 26, Scenario Data/Training/Scenario_02, Total Reward: [16625.]
# Using cpu device
# Episode 26, Scenario Data/Training/Scenario_10, Total Reward: [4940.]
# Using cpu device
# Episode 26, Scenario Data/Training/Scenario_09, Total Reward: [-28500.]
# Using cpu device
# Episode 26, Scenario Data/Training/Scenario_07, Total Reward: [16735.]
# Using cpu device
# Episode 26, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 26, Scenario Data/Training/Scenario_06, Total Reward: [-200.]
# Using cpu device
# Episode 26, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 27, Scenario Data/Training/Scenario_03, Total Reward: [-395.]
# Using cpu device
# Episode 27, Scenario Data/Training/Scenario_04, Total Reward: [-20000.]
# Using cpu device
# Episode 27, Scenario Data/Training/Scenario_05, Total Reward: [-29440.]
# Using cpu device
# Episode 27, Scenario Data/Training/Scenario_02, Total Reward: [-90000.]
# Using cpu device
# Episode 27, Scenario Data/Training/Scenario_10, Total Reward: [3455.]
# Using cpu device
# Episode 27, Scenario Data/Training/Scenario_09, Total Reward: [0.]
# Using cpu device
# Episode 27, Scenario Data/Training/Scenario_07, Total Reward: [16785.]
# Using cpu device
# Episode 27, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 27, Scenario Data/Training/Scenario_06, Total Reward: [-200.]
# Using cpu device
# Episode 27, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 28, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 28, Scenario Data/Training/Scenario_04, Total Reward: [3050.]
# Using cpu device
# Episode 28, Scenario Data/Training/Scenario_05, Total Reward: [9425.]
# Using cpu device
# Episode 28, Scenario Data/Training/Scenario_02, Total Reward: [17745.]
# Using cpu device
# Episode 28, Scenario Data/Training/Scenario_10, Total Reward: [5260.]
# Using cpu device
# Episode 28, Scenario Data/Training/Scenario_09, Total Reward: [-65.]
# Using cpu device
# Episode 28, Scenario Data/Training/Scenario_07, Total Reward: [-10995.]
# Using cpu device
# Episode 28, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 28, Scenario Data/Training/Scenario_06, Total Reward: [-645.]
# Using cpu device
# Episode 28, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 29, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 29, Scenario Data/Training/Scenario_04, Total Reward: [3925.]
# Using cpu device
# Episode 29, Scenario Data/Training/Scenario_05, Total Reward: [-72000.]
# Using cpu device
# Episode 29, Scenario Data/Training/Scenario_02, Total Reward: [-26370.]
# Using cpu device
# Episode 29, Scenario Data/Training/Scenario_10, Total Reward: [3455.]
# Using cpu device
# Episode 29, Scenario Data/Training/Scenario_09, Total Reward: [-3840.]
# Using cpu device
# Episode 29, Scenario Data/Training/Scenario_07, Total Reward: [16785.]
# Using cpu device
# Episode 29, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 29, Scenario Data/Training/Scenario_06, Total Reward: [-285.]
# Using cpu device
# Episode 29, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 30, Scenario Data/Training/Scenario_03, Total Reward: [-1505.]
# Using cpu device
# Episode 30, Scenario Data/Training/Scenario_04, Total Reward: [-2650.]
# Using cpu device
# Episode 30, Scenario Data/Training/Scenario_05, Total Reward: [10705.]
# Using cpu device
# Episode 30, Scenario Data/Training/Scenario_02, Total Reward: [-90000.]
# Using cpu device
# Episode 30, Scenario Data/Training/Scenario_10, Total Reward: [3325.]
# Using cpu device
# Episode 30, Scenario Data/Training/Scenario_09, Total Reward: [-365.]
# Using cpu device
# Episode 30, Scenario Data/Training/Scenario_07, Total Reward: [16490.]
# Using cpu device
# Episode 30, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 30, Scenario Data/Training/Scenario_06, Total Reward: [-200.]
# Using cpu device
# Episode 30, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 31, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 31, Scenario Data/Training/Scenario_04, Total Reward: [4970.]
# Using cpu device
# Episode 31, Scenario Data/Training/Scenario_05, Total Reward: [9680.]
# Using cpu device
# Episode 31, Scenario Data/Training/Scenario_02, Total Reward: [-10395.]
# Using cpu device
# Episode 31, Scenario Data/Training/Scenario_10, Total Reward: [3190.]
# Using cpu device
# Episode 31, Scenario Data/Training/Scenario_09, Total Reward: [-3475.]
# Using cpu device
# Episode 31, Scenario Data/Training/Scenario_07, Total Reward: [-24930.]
# Using cpu device
# Episode 31, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 31, Scenario Data/Training/Scenario_06, Total Reward: [-940.]
# Using cpu device
# Episode 31, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 32, Scenario Data/Training/Scenario_03, Total Reward: [-1505.]
# Using cpu device
# Episode 32, Scenario Data/Training/Scenario_04, Total Reward: [1115.]
# Using cpu device
# Episode 32, Scenario Data/Training/Scenario_05, Total Reward: [-1090.]
# Using cpu device
# Episode 32, Scenario Data/Training/Scenario_02, Total Reward: [-15265.]
# Using cpu device
# Episode 32, Scenario Data/Training/Scenario_10, Total Reward: [4570.]
# Using cpu device
# Episode 32, Scenario Data/Training/Scenario_09, Total Reward: [-375.]
# Using cpu device
# Episode 32, Scenario Data/Training/Scenario_07, Total Reward: [16855.]
# Using cpu device
# Episode 32, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 32, Scenario Data/Training/Scenario_06, Total Reward: [-285.]
# Using cpu device
# Episode 32, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 33, Scenario Data/Training/Scenario_03, Total Reward: [-395.]
# Using cpu device
# Episode 33, Scenario Data/Training/Scenario_04, Total Reward: [4875.]
# Using cpu device
# Episode 33, Scenario Data/Training/Scenario_05, Total Reward: [-4925.]
# Using cpu device
# Episode 33, Scenario Data/Training/Scenario_02, Total Reward: [16825.]
# Using cpu device
# Episode 33, Scenario Data/Training/Scenario_10, Total Reward: [4835.]
# Using cpu device
# Episode 33, Scenario Data/Training/Scenario_09, Total Reward: [-28500.]
# Using cpu device
# Episode 33, Scenario Data/Training/Scenario_07, Total Reward: [-84000.]
# Using cpu device
# Episode 33, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 33, Scenario Data/Training/Scenario_06, Total Reward: [-645.]
# Using cpu device
# Episode 33, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 34, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 34, Scenario Data/Training/Scenario_04, Total Reward: [3400.]
# Using cpu device
# Episode 34, Scenario Data/Training/Scenario_05, Total Reward: [-18615.]
# Using cpu device
# Episode 34, Scenario Data/Training/Scenario_02, Total Reward: [17745.]
# Using cpu device
# Episode 34, Scenario Data/Training/Scenario_10, Total Reward: [3970.]
# Using cpu device
# Episode 34, Scenario Data/Training/Scenario_09, Total Reward: [0.]
# Using cpu device
# Episode 34, Scenario Data/Training/Scenario_07, Total Reward: [-84000.]
# Using cpu device
# Episode 34, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 34, Scenario Data/Training/Scenario_06, Total Reward: [-200.]
# Using cpu device
# Episode 34, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 35, Scenario Data/Training/Scenario_03, Total Reward: [-22500.]
# Using cpu device
# Episode 35, Scenario Data/Training/Scenario_04, Total Reward: [-6365.]
# Using cpu device
# Episode 35, Scenario Data/Training/Scenario_05, Total Reward: [-24795.]
# Using cpu device
# Episode 35, Scenario Data/Training/Scenario_02, Total Reward: [16625.]
# Using cpu device
# Episode 35, Scenario Data/Training/Scenario_10, Total Reward: [-11220.]
# Using cpu device
# Episode 35, Scenario Data/Training/Scenario_09, Total Reward: [-28500.]
# Using cpu device
# Episode 35, Scenario Data/Training/Scenario_07, Total Reward: [-14145.]
# Using cpu device
# Episode 35, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 35, Scenario Data/Training/Scenario_06, Total Reward: [-940.]
# Using cpu device
# Episode 35, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 36, Scenario Data/Training/Scenario_03, Total Reward: [-1880.]
# Using cpu device
# Episode 36, Scenario Data/Training/Scenario_04, Total Reward: [-45000.]
# Using cpu device
# Episode 36, Scenario Data/Training/Scenario_05, Total Reward: [9830.]
# Using cpu device
# Episode 36, Scenario Data/Training/Scenario_02, Total Reward: [16825.]
# Using cpu device
# Episode 36, Scenario Data/Training/Scenario_10, Total Reward: [4785.]
# Using cpu device
# Episode 36, Scenario Data/Training/Scenario_09, Total Reward: [-28500.]
# Using cpu device
# Episode 36, Scenario Data/Training/Scenario_07, Total Reward: [16870.]
# Using cpu device
# Episode 36, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 36, Scenario Data/Training/Scenario_06, Total Reward: [-645.]
# Using cpu device
# Episode 36, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 37, Scenario Data/Training/Scenario_03, Total Reward: [-395.]
# Using cpu device
# Episode 37, Scenario Data/Training/Scenario_04, Total Reward: [4970.]
# Using cpu device
# Episode 37, Scenario Data/Training/Scenario_05, Total Reward: [-11850.]
# Using cpu device
# Episode 37, Scenario Data/Training/Scenario_02, Total Reward: [16625.]
# Using cpu device
# Episode 37, Scenario Data/Training/Scenario_10, Total Reward: [3455.]
# Using cpu device
# Episode 37, Scenario Data/Training/Scenario_09, Total Reward: [-2990.]
# Using cpu device
# Episode 37, Scenario Data/Training/Scenario_07, Total Reward: [16575.]
# Using cpu device
# Episode 37, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 37, Scenario Data/Training/Scenario_06, Total Reward: [-1155.]
# Using cpu device
# Episode 37, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 38, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 38, Scenario Data/Training/Scenario_04, Total Reward: [-9415.]
# Using cpu device
# Episode 38, Scenario Data/Training/Scenario_05, Total Reward: [10705.]
# Using cpu device
# Episode 38, Scenario Data/Training/Scenario_02, Total Reward: [17125.]
# Using cpu device
# Episode 38, Scenario Data/Training/Scenario_10, Total Reward: [-2545.]
# Using cpu device
# Episode 38, Scenario Data/Training/Scenario_09, Total Reward: [-1460.]
# Using cpu device
# Episode 38, Scenario Data/Training/Scenario_07, Total Reward: [17150.]
# Using cpu device
# Episode 38, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 38, Scenario Data/Training/Scenario_06, Total Reward: [-22500.]
# Using cpu device
# Episode 38, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 39, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 39, Scenario Data/Training/Scenario_04, Total Reward: [4970.]
# Using cpu device
# Episode 39, Scenario Data/Training/Scenario_05, Total Reward: [-3645.]
# Using cpu device
# Episode 39, Scenario Data/Training/Scenario_02, Total Reward: [-26370.]
# Using cpu device
# Episode 39, Scenario Data/Training/Scenario_10, Total Reward: [3970.]
# Using cpu device
# Episode 39, Scenario Data/Training/Scenario_09, Total Reward: [-2935.]
# Using cpu device
# Episode 39, Scenario Data/Training/Scenario_07, Total Reward: [-24930.]
# Using cpu device
# Episode 39, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 39, Scenario Data/Training/Scenario_06, Total Reward: [-940.]
# Using cpu device
# Episode 39, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 40, Scenario Data/Training/Scenario_03, Total Reward: [-15380.]
# Using cpu device
# Episode 40, Scenario Data/Training/Scenario_04, Total Reward: [4970.]
# Using cpu device
# Episode 40, Scenario Data/Training/Scenario_05, Total Reward: [-51620.]
# Using cpu device
# Episode 40, Scenario Data/Training/Scenario_02, Total Reward: [-12065.]
# Using cpu device
# Episode 40, Scenario Data/Training/Scenario_10, Total Reward: [-11220.]
# Using cpu device
# Episode 40, Scenario Data/Training/Scenario_09, Total Reward: [-3475.]
# Using cpu device
# Episode 40, Scenario Data/Training/Scenario_07, Total Reward: [16820.]
# Using cpu device
# Episode 40, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 40, Scenario Data/Training/Scenario_06, Total Reward: [-940.]
# Using cpu device
# Episode 40, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 41, Scenario Data/Training/Scenario_03, Total Reward: [-22500.]
# Using cpu device
# Episode 41, Scenario Data/Training/Scenario_04, Total Reward: [4970.]
# Using cpu device
# Episode 41, Scenario Data/Training/Scenario_05, Total Reward: [9680.]
# Using cpu device
# Episode 41, Scenario Data/Training/Scenario_02, Total Reward: [-26370.]
# Using cpu device
# Episode 41, Scenario Data/Training/Scenario_10, Total Reward: [3455.]
# Using cpu device
# Episode 41, Scenario Data/Training/Scenario_09, Total Reward: [-375.]
# Using cpu device
# Episode 41, Scenario Data/Training/Scenario_07, Total Reward: [16785.]
# Using cpu device
# Episode 41, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 41, Scenario Data/Training/Scenario_06, Total Reward: [-200.]
# Using cpu device
# Episode 41, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 42, Scenario Data/Training/Scenario_03, Total Reward: [-1880.]
# Using cpu device
# Episode 42, Scenario Data/Training/Scenario_04, Total Reward: [-2650.]
# Using cpu device
# Episode 42, Scenario Data/Training/Scenario_05, Total Reward: [8990.]
# Using cpu device
# Episode 42, Scenario Data/Training/Scenario_02, Total Reward: [16825.]
# Using cpu device
# Episode 42, Scenario Data/Training/Scenario_10, Total Reward: [4835.]
# Using cpu device
# Episode 42, Scenario Data/Training/Scenario_09, Total Reward: [-375.]
# Using cpu device
# Episode 42, Scenario Data/Training/Scenario_07, Total Reward: [16785.]
# Using cpu device
# Episode 42, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 42, Scenario Data/Training/Scenario_06, Total Reward: [-22500.]
# Using cpu device
# Episode 42, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 43, Scenario Data/Training/Scenario_03, Total Reward: [-395.]
# Using cpu device
# Episode 43, Scenario Data/Training/Scenario_04, Total Reward: [-2650.]
# Using cpu device
# Episode 43, Scenario Data/Training/Scenario_05, Total Reward: [-18615.]
# Using cpu device
# Episode 43, Scenario Data/Training/Scenario_02, Total Reward: [16225.]
# Using cpu device
# Episode 43, Scenario Data/Training/Scenario_10, Total Reward: [4835.]
# Using cpu device
# Episode 43, Scenario Data/Training/Scenario_09, Total Reward: [-28500.]
# Using cpu device
# Episode 43, Scenario Data/Training/Scenario_07, Total Reward: [4390.]
# Using cpu device
# Episode 43, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 43, Scenario Data/Training/Scenario_06, Total Reward: [-1675.]
# Using cpu device
# Episode 43, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 44, Scenario Data/Training/Scenario_03, Total Reward: [-1880.]
# Using cpu device
# Episode 44, Scenario Data/Training/Scenario_04, Total Reward: [4970.]
# Using cpu device
# Episode 44, Scenario Data/Training/Scenario_05, Total Reward: [10270.]
# Using cpu device
# Episode 44, Scenario Data/Training/Scenario_02, Total Reward: [16825.]
# Using cpu device
# Episode 44, Scenario Data/Training/Scenario_10, Total Reward: [3455.]
# Using cpu device
# Episode 44, Scenario Data/Training/Scenario_09, Total Reward: [-2990.]
# Using cpu device
# Episode 44, Scenario Data/Training/Scenario_07, Total Reward: [16990.]
# Using cpu device
# Episode 44, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 44, Scenario Data/Training/Scenario_06, Total Reward: [-1155.]
# Using cpu device
# Episode 44, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 45, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 45, Scenario Data/Training/Scenario_04, Total Reward: [3370.]
# Using cpu device
# Episode 45, Scenario Data/Training/Scenario_05, Total Reward: [-44095.]
# Using cpu device
# Episode 45, Scenario Data/Training/Scenario_02, Total Reward: [15355.]
# Using cpu device
# Episode 45, Scenario Data/Training/Scenario_10, Total Reward: [3455.]
# Using cpu device
# Episode 45, Scenario Data/Training/Scenario_09, Total Reward: [-28500.]
# Using cpu device
# Episode 45, Scenario Data/Training/Scenario_07, Total Reward: [-10700.]
# Using cpu device
# Episode 45, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 45, Scenario Data/Training/Scenario_06, Total Reward: [-1200.]
# Using cpu device
# Episode 45, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 46, Scenario Data/Training/Scenario_03, Total Reward: [-22500.]
# Using cpu device
# Episode 46, Scenario Data/Training/Scenario_04, Total Reward: [1115.]
# Using cpu device
# Episode 46, Scenario Data/Training/Scenario_05, Total Reward: [-1295.]
# Using cpu device
# Episode 46, Scenario Data/Training/Scenario_02, Total Reward: [-90000.]
# Using cpu device
# Episode 46, Scenario Data/Training/Scenario_10, Total Reward: [3970.]
# Using cpu device
# Episode 46, Scenario Data/Training/Scenario_09, Total Reward: [-2990.]
# Using cpu device
# Episode 46, Scenario Data/Training/Scenario_07, Total Reward: [16095.]
# Using cpu device
# Episode 46, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 46, Scenario Data/Training/Scenario_06, Total Reward: [-1675.]
# Using cpu device
# Episode 46, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 47, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 47, Scenario Data/Training/Scenario_04, Total Reward: [-12895.]
# Using cpu device
# Episode 47, Scenario Data/Training/Scenario_05, Total Reward: [-18615.]
# Using cpu device
# Episode 47, Scenario Data/Training/Scenario_02, Total Reward: [17745.]
# Using cpu device
# Episode 47, Scenario Data/Training/Scenario_10, Total Reward: [5260.]
# Using cpu device
# Episode 47, Scenario Data/Training/Scenario_09, Total Reward: [-785.]
# Using cpu device
# Episode 47, Scenario Data/Training/Scenario_07, Total Reward: [16785.]
# Using cpu device
# Episode 47, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 47, Scenario Data/Training/Scenario_06, Total Reward: [-820.]
# Using cpu device
# Episode 47, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 48, Scenario Data/Training/Scenario_03, Total Reward: [-1505.]
# Using cpu device
# Episode 48, Scenario Data/Training/Scenario_04, Total Reward: [3925.]
# Using cpu device
# Episode 48, Scenario Data/Training/Scenario_05, Total Reward: [9425.]
# Using cpu device
# Episode 48, Scenario Data/Training/Scenario_02, Total Reward: [-90000.]
# Using cpu device
# Episode 48, Scenario Data/Training/Scenario_10, Total Reward: [4885.]
# Using cpu device
# Episode 48, Scenario Data/Training/Scenario_09, Total Reward: [-1460.]
# Using cpu device
# Episode 48, Scenario Data/Training/Scenario_07, Total Reward: [16590.]
# Using cpu device
# Episode 48, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 48, Scenario Data/Training/Scenario_06, Total Reward: [-645.]
# Using cpu device
# Episode 48, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 49, Scenario Data/Training/Scenario_03, Total Reward: [-395.]
# Using cpu device
# Episode 49, Scenario Data/Training/Scenario_04, Total Reward: [-2650.]
# Using cpu device
# Episode 49, Scenario Data/Training/Scenario_05, Total Reward: [10270.]
# Using cpu device
# Episode 49, Scenario Data/Training/Scenario_02, Total Reward: [16825.]
# Using cpu device
# Episode 49, Scenario Data/Training/Scenario_10, Total Reward: [-11220.]
# Using cpu device
# Episode 49, Scenario Data/Training/Scenario_09, Total Reward: [-2990.]
# Using cpu device
# Episode 49, Scenario Data/Training/Scenario_07, Total Reward: [-84000.]
# Using cpu device
# Episode 49, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 49, Scenario Data/Training/Scenario_06, Total Reward: [-1155.]
# Using cpu device
# Episode 49, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 50, Scenario Data/Training/Scenario_03, Total Reward: [-22500.]
# Using cpu device
# Episode 50, Scenario Data/Training/Scenario_04, Total Reward: [4875.]
# Using cpu device
# Episode 50, Scenario Data/Training/Scenario_05, Total Reward: [9425.]
# Using cpu device
# Episode 50, Scenario Data/Training/Scenario_02, Total Reward: [16225.]
# Using cpu device
# Episode 50, Scenario Data/Training/Scenario_10, Total Reward: [-23060.]
# Using cpu device
# Episode 50, Scenario Data/Training/Scenario_09, Total Reward: [-2935.]
# Using cpu device
# Episode 50, Scenario Data/Training/Scenario_07, Total Reward: [16575.]
# Using cpu device
# Episode 50, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 50, Scenario Data/Training/Scenario_06, Total Reward: [-820.]
# Using cpu device
# Episode 50, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 51, Scenario Data/Training/Scenario_03, Total Reward: [-395.]
# Using cpu device
# Episode 51, Scenario Data/Training/Scenario_04, Total Reward: [3925.]
# Using cpu device
# Episode 51, Scenario Data/Training/Scenario_05, Total Reward: [-10640.]
# Using cpu device
# Episode 51, Scenario Data/Training/Scenario_02, Total Reward: [16225.]
# Using cpu device
# Episode 51, Scenario Data/Training/Scenario_10, Total Reward: [4835.]
# Using cpu device
# Episode 51, Scenario Data/Training/Scenario_09, Total Reward: [-65.]
# Using cpu device
# Episode 51, Scenario Data/Training/Scenario_07, Total Reward: [17430.]
# Using cpu device
# Episode 51, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 51, Scenario Data/Training/Scenario_06, Total Reward: [-645.]
# Using cpu device
# Episode 51, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 52, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 52, Scenario Data/Training/Scenario_04, Total Reward: [3050.]
# Using cpu device
# Episode 52, Scenario Data/Training/Scenario_05, Total Reward: [-72000.]
# Using cpu device
# Episode 52, Scenario Data/Training/Scenario_02, Total Reward: [16625.]
# Using cpu device
# Episode 52, Scenario Data/Training/Scenario_10, Total Reward: [-48000.]
# Using cpu device
# Episode 52, Scenario Data/Training/Scenario_09, Total Reward: [-2045.]
# Using cpu device
# Episode 52, Scenario Data/Training/Scenario_07, Total Reward: [-24930.]
# Using cpu device
# Episode 52, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 52, Scenario Data/Training/Scenario_06, Total Reward: [-645.]
# Using cpu device
# Episode 52, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 53, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 53, Scenario Data/Training/Scenario_04, Total Reward: [-20000.]
# Using cpu device
# Episode 53, Scenario Data/Training/Scenario_05, Total Reward: [9680.]
# Using cpu device
# Episode 53, Scenario Data/Training/Scenario_02, Total Reward: [16225.]
# Using cpu device
# Episode 53, Scenario Data/Training/Scenario_10, Total Reward: [5400.]
# Using cpu device
# Episode 53, Scenario Data/Training/Scenario_09, Total Reward: [-2935.]
# Using cpu device
# Episode 53, Scenario Data/Training/Scenario_07, Total Reward: [17205.]
# Using cpu device
# Episode 53, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 53, Scenario Data/Training/Scenario_06, Total Reward: [-820.]
# Using cpu device
# Episode 53, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 54, Scenario Data/Training/Scenario_03, Total Reward: [-1505.]
# Using cpu device
# Episode 54, Scenario Data/Training/Scenario_04, Total Reward: [-2650.]
# Using cpu device
# Episode 54, Scenario Data/Training/Scenario_05, Total Reward: [-18615.]
# Using cpu device
# Episode 54, Scenario Data/Training/Scenario_02, Total Reward: [-10395.]
# Using cpu device
# Episode 54, Scenario Data/Training/Scenario_10, Total Reward: [5400.]
# Using cpu device
# Episode 54, Scenario Data/Training/Scenario_09, Total Reward: [-1460.]
# Using cpu device
# Episode 54, Scenario Data/Training/Scenario_07, Total Reward: [17000.]
# Using cpu device
# Episode 54, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 54, Scenario Data/Training/Scenario_06, Total Reward: [-820.]
# Using cpu device
# Episode 54, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# ...
# Using cpu device
# Episode 281, Scenario Data/Training/Scenario_06, Total Reward: [-285.]
# Using cpu device
# Episode 281, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 282, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 282, Scenario Data/Training/Scenario_04, Total Reward: [3400.]
# Using cpu device
# Episode 282, Scenario Data/Training/Scenario_05, Total Reward: [-58595.]
# Using cpu device
# Episode 282, Scenario Data/Training/Scenario_02, Total Reward: [-90000.]
# Using cpu device
# Episode 282, Scenario Data/Training/Scenario_10, Total Reward: [5135.]
# Using cpu device
# Episode 282, Scenario Data/Training/Scenario_09, Total Reward: [0.]
# Using cpu device
# Episode 282, Scenario Data/Training/Scenario_07, Total Reward: [17000.]
# Using cpu device
# Episode 282, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 282, Scenario Data/Training/Scenario_06, Total Reward: [-1155.]
# Using cpu device
# Episode 282, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 283, Scenario Data/Training/Scenario_03, Total Reward: [-1505.]
# Using cpu device
# Episode 283, Scenario Data/Training/Scenario_04, Total Reward: [-2650.]
# Using cpu device
# Episode 283, Scenario Data/Training/Scenario_05, Total Reward: [-72000.]
# Using cpu device
# Episode 283, Scenario Data/Training/Scenario_02, Total Reward: [16225.]
# Using cpu device
# Episode 283, Scenario Data/Training/Scenario_10, Total Reward: [-11220.]
# Using cpu device
# Episode 283, Scenario Data/Training/Scenario_09, Total Reward: [-3475.]
# Using cpu device
# Episode 283, Scenario Data/Training/Scenario_07, Total Reward: [16575.]
# Using cpu device
# Episode 283, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 283, Scenario Data/Training/Scenario_06, Total Reward: [-940.]
# Using cpu device
# Episode 283, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 284, Scenario Data/Training/Scenario_03, Total Reward: [-395.]
# Using cpu device
# Episode 284, Scenario Data/Training/Scenario_04, Total Reward: [3050.]
# Using cpu device
# Episode 284, Scenario Data/Training/Scenario_05, Total Reward: [9335.]
# Using cpu device
# Episode 284, Scenario Data/Training/Scenario_02, Total Reward: [-90000.]
# Using cpu device
# Episode 284, Scenario Data/Training/Scenario_10, Total Reward: [-48000.]
# Using cpu device
# Episode 284, Scenario Data/Training/Scenario_09, Total Reward: [-2045.]
# Using cpu device
# Episode 284, Scenario Data/Training/Scenario_07, Total Reward: [17000.]
# Using cpu device
# Episode 284, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 284, Scenario Data/Training/Scenario_06, Total Reward: [-22500.]
# Using cpu device
# Episode 284, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 285, Scenario Data/Training/Scenario_03, Total Reward: [-1505.]
# Using cpu device
# Episode 285, Scenario Data/Training/Scenario_04, Total Reward: [-2650.]
# Using cpu device
# Episode 285, Scenario Data/Training/Scenario_05, Total Reward: [9680.]
# Using cpu device
# Episode 285, Scenario Data/Training/Scenario_02, Total Reward: [17745.]
# Using cpu device
# Episode 285, Scenario Data/Training/Scenario_10, Total Reward: [4835.]
# Using cpu device
# Episode 285, Scenario Data/Training/Scenario_09, Total Reward: [-2990.]
# Using cpu device
# Episode 285, Scenario Data/Training/Scenario_07, Total Reward: [16855.]
# Using cpu device
# Episode 285, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 285, Scenario Data/Training/Scenario_06, Total Reward: [-1675.]
# Using cpu device
# Episode 285, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 286, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 286, Scenario Data/Training/Scenario_04, Total Reward: [-45000.]
# Using cpu device
# Episode 286, Scenario Data/Training/Scenario_05, Total Reward: [-18615.]
# Using cpu device
# Episode 286, Scenario Data/Training/Scenario_02, Total Reward: [-61870.]
# Using cpu device
# Episode 286, Scenario Data/Training/Scenario_10, Total Reward: [4570.]
# Using cpu device
# Episode 286, Scenario Data/Training/Scenario_09, Total Reward: [-375.]
# Using cpu device
# Episode 286, Scenario Data/Training/Scenario_07, Total Reward: [16100.]
# Using cpu device
# Episode 286, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 286, Scenario Data/Training/Scenario_06, Total Reward: [-820.]
# Using cpu device
# Episode 286, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 287, Scenario Data/Training/Scenario_03, Total Reward: [-1880.]
# Using cpu device
# Episode 287, Scenario Data/Training/Scenario_04, Total Reward: [4525.]
# Using cpu device
# Episode 287, Scenario Data/Training/Scenario_05, Total Reward: [10540.]
# Using cpu device
# Episode 287, Scenario Data/Training/Scenario_02, Total Reward: [-90000.]
# Using cpu device
# Episode 287, Scenario Data/Training/Scenario_10, Total Reward: [4685.]
# Using cpu device
# Episode 287, Scenario Data/Training/Scenario_09, Total Reward: [-2990.]
# Using cpu device
# Episode 287, Scenario Data/Training/Scenario_07, Total Reward: [9860.]
# Using cpu device
# Episode 287, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 287, Scenario Data/Training/Scenario_06, Total Reward: [-645.]
# Using cpu device
# Episode 287, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 288, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 288, Scenario Data/Training/Scenario_04, Total Reward: [4085.]
# Using cpu device
# Episode 288, Scenario Data/Training/Scenario_05, Total Reward: [9425.]
# Using cpu device
# Episode 288, Scenario Data/Training/Scenario_02, Total Reward: [16625.]
# Using cpu device
# Episode 288, Scenario Data/Training/Scenario_10, Total Reward: [-41220.]
# Using cpu device
# Episode 288, Scenario Data/Training/Scenario_09, Total Reward: [-3840.]
# Using cpu device
# Episode 288, Scenario Data/Training/Scenario_07, Total Reward: [-24930.]
# Using cpu device
# Episode 288, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 288, Scenario Data/Training/Scenario_06, Total Reward: [-285.]
# Using cpu device
# Episode 288, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 289, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 289, Scenario Data/Training/Scenario_04, Total Reward: [4970.]
# Using cpu device
# Episode 289, Scenario Data/Training/Scenario_05, Total Reward: [-72000.]
# Using cpu device
# Episode 289, Scenario Data/Training/Scenario_02, Total Reward: [17390.]
# Using cpu device
# Episode 289, Scenario Data/Training/Scenario_10, Total Reward: [4940.]
# Using cpu device
# Episode 289, Scenario Data/Training/Scenario_09, Total Reward: [-3475.]
# Using cpu device
# Episode 289, Scenario Data/Training/Scenario_07, Total Reward: [-84000.]
# Using cpu device
# Episode 289, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 289, Scenario Data/Training/Scenario_06, Total Reward: [-1675.]
# Using cpu device
# Episode 289, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 290, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 290, Scenario Data/Training/Scenario_04, Total Reward: [1115.]
# Using cpu device
# Episode 290, Scenario Data/Training/Scenario_05, Total Reward: [10705.]
# Using cpu device
# Episode 290, Scenario Data/Training/Scenario_02, Total Reward: [16625.]
# Using cpu device
# Episode 290, Scenario Data/Training/Scenario_10, Total Reward: [3970.]
# Using cpu device
# Episode 290, Scenario Data/Training/Scenario_09, Total Reward: [-375.]
# Using cpu device
# Episode 290, Scenario Data/Training/Scenario_07, Total Reward: [-24930.]
# Using cpu device
# Episode 290, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 290, Scenario Data/Training/Scenario_06, Total Reward: [-940.]
# Using cpu device
# Episode 290, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 291, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 291, Scenario Data/Training/Scenario_04, Total Reward: [3925.]
# Using cpu device
# Episode 291, Scenario Data/Training/Scenario_05, Total Reward: [9425.]
# Using cpu device
# Episode 291, Scenario Data/Training/Scenario_02, Total Reward: [-33000.]
# Using cpu device
# Episode 291, Scenario Data/Training/Scenario_10, Total Reward: [4835.]
# Using cpu device
# Episode 291, Scenario Data/Training/Scenario_09, Total Reward: [-3475.]
# Using cpu device
# Episode 291, Scenario Data/Training/Scenario_07, Total Reward: [16820.]
# Using cpu device
# Episode 291, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 291, Scenario Data/Training/Scenario_06, Total Reward: [-22500.]
# Using cpu device
# Episode 291, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 292, Scenario Data/Training/Scenario_03, Total Reward: [-1505.]
# Using cpu device
# Episode 292, Scenario Data/Training/Scenario_04, Total Reward: [-450.]
# Using cpu device
# Episode 292, Scenario Data/Training/Scenario_05, Total Reward: [9830.]
# Using cpu device
# Episode 292, Scenario Data/Training/Scenario_02, Total Reward: [-90000.]
# Using cpu device
# Episode 292, Scenario Data/Training/Scenario_10, Total Reward: [3940.]
# Using cpu device
# Episode 292, Scenario Data/Training/Scenario_09, Total Reward: [-2045.]
# Using cpu device
# Episode 292, Scenario Data/Training/Scenario_07, Total Reward: [16960.]
# Using cpu device
# Episode 292, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 292, Scenario Data/Training/Scenario_06, Total Reward: [-200.]
# Using cpu device
# Episode 292, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 293, Scenario Data/Training/Scenario_03, Total Reward: [-395.]
# Using cpu device
# Episode 293, Scenario Data/Training/Scenario_04, Total Reward: [3050.]
# Using cpu device
# Episode 293, Scenario Data/Training/Scenario_05, Total Reward: [10000.]
# Using cpu device
# Episode 293, Scenario Data/Training/Scenario_02, Total Reward: [-26775.]
# Using cpu device
# Episode 293, Scenario Data/Training/Scenario_10, Total Reward: [4635.]
# Using cpu device
# Episode 293, Scenario Data/Training/Scenario_09, Total Reward: [-2935.]
# Using cpu device
# Episode 293, Scenario Data/Training/Scenario_07, Total Reward: [-84000.]
# Using cpu device
# Episode 293, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 293, Scenario Data/Training/Scenario_06, Total Reward: [-1925.]
# Using cpu device
# Episode 293, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 294, Scenario Data/Training/Scenario_03, Total Reward: [-1880.]
# Using cpu device
# Episode 294, Scenario Data/Training/Scenario_04, Total Reward: [4085.]
# Using cpu device
# Episode 294, Scenario Data/Training/Scenario_05, Total Reward: [-18615.]
# Using cpu device
# Episode 294, Scenario Data/Training/Scenario_02, Total Reward: [16930.]
# Using cpu device
# Episode 294, Scenario Data/Training/Scenario_10, Total Reward: [3455.]
# Using cpu device
# Episode 294, Scenario Data/Training/Scenario_09, Total Reward: [-2045.]
# Using cpu device
# Episode 294, Scenario Data/Training/Scenario_07, Total Reward: [16630.]
# Using cpu device
# Episode 294, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 294, Scenario Data/Training/Scenario_06, Total Reward: [-200.]
# Using cpu device
# Episode 294, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 295, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 295, Scenario Data/Training/Scenario_04, Total Reward: [1115.]
# Using cpu device
# Episode 295, Scenario Data/Training/Scenario_05, Total Reward: [10270.]
# Using cpu device
# Episode 295, Scenario Data/Training/Scenario_02, Total Reward: [-26370.]
# Using cpu device
# Episode 295, Scenario Data/Training/Scenario_10, Total Reward: [5135.]
# Using cpu device
# Episode 295, Scenario Data/Training/Scenario_09, Total Reward: [-2935.]
# Using cpu device
# Episode 295, Scenario Data/Training/Scenario_07, Total Reward: [16870.]
# Using cpu device
# Episode 295, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 295, Scenario Data/Training/Scenario_06, Total Reward: [-820.]
# Using cpu device
# Episode 295, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_03, Total Reward: [-395.]
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_04, Total Reward: [-450.]
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_05, Total Reward: [-72000.]
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_02, Total Reward: [15545.]
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_10, Total Reward: [3455.]
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_09, Total Reward: [0.]
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_07, Total Reward: [16855.]
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_06, Total Reward: [-1675.]
# Using cpu device
# Episode 296, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_03, Total Reward: [-22500.]
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_04, Total Reward: [-2650.]
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_05, Total Reward: [10270.]
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_02, Total Reward: [16625.]
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_10, Total Reward: [4685.]
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_09, Total Reward: [-2990.]
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_07, Total Reward: [-33930.]
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_06, Total Reward: [-820.]
# Using cpu device
# Episode 297, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_03, Total Reward: [0.]
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_04, Total Reward: [3925.]
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_05, Total Reward: [-18615.]
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_02, Total Reward: [-32545.]
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_10, Total Reward: [3455.]
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_09, Total Reward: [1935.]
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_07, Total Reward: [16745.]
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_06, Total Reward: [-1155.]
# Using cpu device
# Episode 298, Scenario Data/Training/Scenario_08, Total Reward: [0.]
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_03, Total Reward: [-22500.]
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_04, Total Reward: [1115.]
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_05, Total Reward: [9680.]
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_02, Total Reward: [-90000.]
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_10, Total Reward: [4795.]
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_09, Total Reward: [-1460.]
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_07, Total Reward: [16785.]
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_01, Total Reward: [0.]
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_06, Total Reward: [-285.]
# Using cpu device
# Episode 299, Scenario Data/Training/Scenario_08, Total Reward: [0.]

# %%
print(len(rewards))

avg_rewards = []

# avg_rewards contains N_EPISODES elements, each element is the average reward for a given iteration of the ten scenarios
for i in range(0, len(rewards), 10):
    avg_rewards.append(np.mean([reward for _, _, reward in rewards[i:i+10]]))
    
# Plot the average rewards over the episodes
plt.plot(range(N_EPISODES), avg_rewards)
plt.xlabel('Batch of Episodes')
plt.ylabel('Average Reward')
plt.title(f'Average Reward per batch of {num_days_trained_on} episodes')
plt.show()
# Out:
# 3000
